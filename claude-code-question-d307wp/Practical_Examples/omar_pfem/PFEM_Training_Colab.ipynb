# %% [markdown]
# # PFEM/Transolver Training -- B1 x {NH, MR, AB}, B2 x {NH, MR, AB}
# **Colab GPU runtime required (Runtime > Change runtime type > GPU)**
#
# Runs the full PFEM pipeline (Wang et al., "Pretrain finite element method",
# JMPS 214 (2026) 106682) for all 6 benchmark cases: B1 (unit square,
# top-edge traction, fixed bottom) and B2 (quarter ring, R_in=1/R_out=2,
# internal pressure, symmetry BCs), each with three hyperelastic energy
# densities (Neo-Hookean, Mooney-Rivlin, Arruda-Boyce).
#
# For each case this notebook:
# 1. Generates a FEM ground-truth dataset (Total-Lagrangian Newton-Raphson,
#    Q4 elements) via `omar_pfem/data/data_generate_B{1,2}.py`, parallelized
#    across CPU cores -- skipped if the dataset already exists on disk.
# 2. Converts it to the Transolver NPZ format via `convert_B{1,2}_quad.py`.
# 3. Trains a physics-informed Transolver (`omar_pfem/train_B{1,2}.py`) by
#    minimizing total potential energy (Pi = U - W, no labeled-data loss),
#    matching PFEM's own reference hyperparameters (n_hidden=256, n_layers=4,
#    n_heads=8, slice_num=128, batch_size=1, epochs=10000).
#
# **Scale note**: PFEM's own reference script defaults to ntrain=800,
# ntest=200, 10000 epochs, batch_size=1 -- i.e. up to 8,000,000 single-sample
# gradient steps per case, 48,000,000 across all 6. This is a genuinely
# large campaign, on both ends of the pipeline:
# - **Data generation**: measured on a 4-core CPU at the reference 21x21 Q4
#   mesh, generating each sample (a 10-step Newton-Raphson solve) took
#   ~8s/sample with 4 parallel workers -- so a 1000-sample dataset
#   (NTRAIN+NTEST) is roughly 2-2.5 CPU-hours per case, ~14 hours for all 6.
#   Colab's own CPU allocation may differ from this benchmark.
# - **Training**: 10000 epochs x 800 training samples x batch_size=1 is a
#   genuinely large number of individual gradient steps; whether it
#   completes in one session depends entirely on Colab's GPU throughput,
#   which this notebook doesn't try to predict in advance.
#
# Given that, it will very likely NOT finish within one Colab session.
# That's expected and handled: every case checkpoints its model every
# `SAVE_EVERY` epochs and **resumes from its own latest checkpoint** if this
# notebook is re-run (whether because the runtime disconnected mid-case, or
# because you're continuing across multiple sessions) -- so re-running
# `Runtime > Run all` after a disconnect always makes forward progress
# instead of starting over. Finished cases (a `model_final.pt` on disk) are
# skipped entirely, and finished datasets (an NPZ already on disk) are never
# regenerated.
#
# If you'd rather trade fidelity for a faster full 6-case pass, lower
# `TARGET_SAMPLES` / `EPOCHS` in the config cell below -- everything else
# adapts automatically.

# %% [markdown]
# ## Cell 1 - Install dependencies
#
# Colab's preinstalled `torch` already has CUDA support -- it is deliberately
# NOT reinstalled here (a bare `pip install torch` risks silently replacing
# it with a CPU-only wheel). Only the packages PFEM's Transolver model and
# this pipeline actually need on top of Colab's base image are installed:
# `einops`/`timm` (Transolver architecture), `h5py` (FEM dataset storage),
# `jax` (autodiff-derived PK1 stress/tangent for Mooney-Rivlin/Arruda-Boyce
# in the FEM generator -- CPU-only use, small dense tensors, no GPU needed).
#
# Uses `{sys.executable} -m pip` rather than bare `!pip` -- on some Colab
# runtimes the shell's `pip` has been observed to resolve to a different
# Python than the notebook kernel itself, which makes packages "install
# successfully" yet still fail to import.

# %%
import sys
# !{sys.executable} -m pip install -q einops timm h5py jax tqdm
print('Done - continue to Cell 2')
# Out:
# Done - continue to Cell 2

# %% [markdown]
# ## Cell 2 - Clone the repo
#
# If the repo is private, paste a GitHub personal access token as the value
# of `GITHUB_TOKEN` below. Leave it as `""` if the repo is public -- never
# type a literal `<TOKEN>` placeholder into the URL (`<`/`>` are bash
# redirection operators and will break the clone before git even runs).
#
# Always does a clean re-clone of the CODE (removes any previous
# `/content/OMAR` first) so a broken partial clone can't linger -- but
# generated datasets and results live elsewhere (local disk / Google Drive,
# see Cells 3-4), **outside** the cloned repo, so re-cloning never discards
# training progress.

# %%
import os
import shutil
import sys

os.chdir('/content')

GITHUB_TOKEN = ""  # <-- paste your token between the quotes if the repo is private; leave "" if public
BRANCH = "claude/claude-code-question-d307wp"
REPO_URL = (f"https://{GITHUB_TOKEN}@github.com/suhibamro/omar.git" if GITHUB_TOKEN
            else "https://github.com/suhibamro/omar.git")

if os.path.exists('/content/OMAR'):
    shutil.rmtree('/content/OMAR')

# !git clone -b {BRANCH} {REPO_URL} /content/OMAR

WORK_DIR = '/content/OMAR/Practical_Examples'
if not os.path.isdir(WORK_DIR):
    raise SystemExit(
        'ERROR: clone failed -- /content/OMAR/Practical_Examples does not exist.\n'
        'Scroll up to the "git clone" output above for the actual error.\n'
        'Common cause: the repo is private and GITHUB_TOKEN is still "".'
    )

os.chdir(WORK_DIR)
sys.path.insert(0, WORK_DIR)

pfem_ok = os.path.isdir(os.path.join(WORK_DIR, 'omar_pfem'))
if pfem_ok:
    print('Clone OK: omar_pfem/ found under Practical_Examples/.')
else:
    raise SystemExit('ERROR: omar_pfem/ not found -- clone looks incomplete or wrong branch.')

import torch
print(f'torch {torch.__version__} | cuda available={torch.cuda.is_available()}', end=' ')
if torch.cuda.is_available():
    print(f'| device={torch.cuda.get_device_name(0)}')
else:
    print()
    print('WARNING: no GPU detected -- go to Runtime > Change runtime type and select a GPU, '
          'then Runtime > Restart session and re-run from Cell 1.')
# Out:
# Cloning into '/content/OMAR'...
# remote: Enumerating objects: 228, done.
# remote: Counting objects: 100% (228/228), done.
# remote: Compressing objects: 100% (158/158), done.
# remote: Total 228 (delta 119), reused 177 (delta 68), pack-reused 0 (from 0)
# Receiving objects: 100% (228/228), 925.70 KiB | 6.71 MiB/s, done.
# Resolving deltas: 100% (119/119), done.
# Clone OK: omar_pfem/ found under Practical_Examples/.
# torch 2.11.0+cu128 | cuda available=True | device=NVIDIA A100-SXM4-40GB

# %% [markdown]
# ## Cell 3 - Mount Google Drive (persist training progress across full disconnects)
#
# Colab's local `/content` disk only survives a *reconnect* to the same
# runtime -- it does NOT survive a full runtime reset/reassignment (hitting
# the session time limit, "Factory reset runtime", or Colab reclaiming an
# idle VM). Given this pipeline can realistically run for many hours to
# multiple days across several sessions, that's a real risk for the
# expensive part of the run: GPU training checkpoints.
#
# So results (`RESULTS_DIR` below) are written to Google Drive, which
# survives any of the above. FEM datasets (`DATA_DIR`) stay on local
# `/content` disk instead -- deliberately NOT on Drive -- because Drive is
# FUSE-mounted (each file write is a network round-trip), and the data
# generator does hundreds of small sequential writes into one HDF5 file per
# case; on Drive that overhead would meaningfully slow down the part of the
# pipeline that's cheap to just regenerate if lost (a bounded few CPU-hours,
# deterministic given the same seed), whereas losing GPU training progress
# is not cheap to redo. If prompted, click through the Google auth flow --
# this notebook will not work with your data without that authorization.

# %%
from google.colab import drive
drive.mount('/content/drive')
print('Drive mounted -- continue to Cell 4')
# Out:
# Mounted at /content/drive
# Drive mounted -- continue to Cell 4

# %% [markdown]
# ## Cell 4 - Configuration
#
# Edit these to trade off dataset/training scale against wall-clock time.
# `TARGET_SAMPLES` splits into `NTRAIN`/`NTEST` the same way as PFEM's own
# reference script (800/200 by default -- lower this if a full 1000-sample
# FEM generation pass is too slow on your Colab CPU allocation).

# %%
import os

DATA_DIR = '/content/pfem_data'                                  # local disk: fast, regenerable if lost
RESULTS_DIR = '/content/drive/MyDrive/pfem_run/results'          # Google Drive: durable across full resets
os.makedirs(DATA_DIR, exist_ok=True)
os.makedirs(RESULTS_DIR, exist_ok=True)

# ---- Dataset scale (PFEM's own reference: ntrain=800, ntest=200) ----
NTRAIN = 800
NTEST = 200
TARGET_SAMPLES = NTRAIN + NTEST   # total FEM samples generated per case

# ---- Mesh resolution (PFEM's own reference default for the beam case) ----
MESH_N = 21   # Nx=Ny=21 for B1; Ntheta=Nr=21 for B2

# ---- Training scale (PFEM's own reference default) ----
EPOCHS = 10000
SAVE_EVERY = 250      # checkpoint + eval cadence (40 checkpoints over a full run)
PRINT_EVERY = 999999  # larger than NTRAIN -> exactly one progress line per epoch

N_WORKERS = os.cpu_count()

GEOMETRIES = ["B1", "B2"]
MATERIALS = ["neo_hookean", "mooney_rivlin", "arruda_boyce"]
CASES = [(g, m) for g in GEOMETRIES for m in MATERIALS]

print(f'CPU workers for data generation: {N_WORKERS}')
print(f'Target samples/case: {TARGET_SAMPLES} (ntrain={NTRAIN}, ntest={NTEST})')
print(f'Epochs/case: {EPOCHS}, save_every={SAVE_EVERY}')
print(f'Cases: {CASES}')
# Out:
# CPU workers for data generation: 12
# Target samples/case: 1000 (ntrain=800, ntest=200)
# Epochs/case: 10000, save_every=250
# Cases: [('B1', 'neo_hookean'), ('B1', 'mooney_rivlin'), ('B1', 'arruda_boyce'), ('B2', 'neo_hookean'), ('B2', 'mooney_rivlin'), ('B2', 'arruda_boyce')]

# %% [markdown]
# ## Cell 5 - Helpers: streaming subprocess runner + per-case pipeline
#
# `run_streaming` runs a command as a subprocess and prints its stdout live
# (unbuffered, `python -u`) instead of buffering until the process exits --
# essential for a run that may take hours, so progress is visible the whole
# time instead of appearing in one dump at the end (or not at all, if the
# cell is interrupted).

# %%
import subprocess
import time
import json as _json

def run_streaming(cmd, cwd=None):
    print(f"$ {' '.join(cmd)}")
    proc = subprocess.Popen(
        cmd, cwd=cwd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT,
        text=True, bufsize=1
    )
    for line in proc.stdout:
        print(line, end='')
    proc.wait()
    if proc.returncode != 0:
        raise RuntimeError(f"Command failed (exit {proc.returncode}): {' '.join(cmd)}")


def case_name(geometry, material):
    return f"{geometry}_{material}"


def run_one_case(geometry, material):
    name = case_name(geometry, material)
    h5_dir = os.path.join(DATA_DIR, f"fem_{name}")
    npz_dir = os.path.join(DATA_DIR, f"npz_{name}")
    npz_path = os.path.join(npz_dir, "hyperelastic_training_data_q4.npz")
    out_dir = os.path.join(RESULTS_DIR, name)
    final_model = os.path.join(out_dir, "model_final.pt")

    print(f"\n{'='*80}\n===== CASE: {name} =====\n{'='*80}")

    if os.path.exists(final_model):
        print(f"[{name}] model_final.pt already exists -- case fully done, skipping entirely.")
        return

    t0 = time.time()

    # ---- Step 1: FEM dataset generation (skipped if already present) ----
    if os.path.exists(npz_path):
        print(f"[{name}] NPZ dataset already exists at {npz_path}, skipping generation.")
    else:
        if geometry == "B1":
            gen_module = "omar_pfem.data.data_generate_B1"
            gen_args = ["--Nx", str(MESH_N), "--Ny", str(MESH_N)]
            conv_module = "omar_pfem.data.convert_B1_quad"
        else:
            gen_module = "omar_pfem.data.data_generate_B2"
            gen_args = ["--Ntheta", str(MESH_N), "--Nr", str(MESH_N)]
            conv_module = "omar_pfem.data.convert_B2_quad"

        run_streaming([
            sys.executable, "-u", "-m", gen_module,
            "--num_index", "1", "--num_samples", str(TARGET_SAMPLES),
            *gen_args, "--material", material,
            "--n_workers", str(N_WORKERS),
            "--out_dir", h5_dir,
        ], cwd=WORK_DIR)

        run_streaming([
            sys.executable, "-u", "-m", conv_module,
            "--h5_dir", h5_dir, "--out_dir", npz_dir,
        ], cwd=WORK_DIR)

        print(f"[{name}] Dataset ready after {time.time()-t0:.0f}s")

    # ---- Step 2: Training (resumes from its own latest checkpoint) ----
    train_module = "omar_pfem.train_B1" if geometry == "B1" else "omar_pfem.train_B2"
    t1 = time.time()
    run_streaming([
        sys.executable, "-u", "-m", train_module,
        "--path", npz_path,
        "--material", material,
        "--ntrain", str(NTRAIN), "--ntest", str(NTEST),
        "--epochs", str(EPOCHS),
        "--save_every", str(SAVE_EVERY),
        "--print_every", str(PRINT_EVERY),
        "--out_dir", out_dir,
    ], cwd=WORK_DIR)
    print(f"[{name}] Training finished after {time.time()-t1:.0f}s (total {time.time()-t0:.0f}s)")

# %% [markdown]
# ## Cell 6 - Run all 6 cases
#
# Cases run one at a time (each already uses all CPU cores for its own data
# generation and the whole GPU for its own training, so there's no benefit
# to overlapping them). If this cell is interrupted (disconnect, manual
# stop) and re-run, already-finished cases are skipped instantly and the
# case that was interrupted resumes from its latest epoch checkpoint instead
# of restarting -- see Cell 3's config and the "Scale note" in the intro.

# %% [markdown]
# ## Cell 7 - Summary: metrics + loss curves across all 6 cases
#
# Reads each case's `metrics_history.json` (written every `SAVE_EVERY`
# epochs during training) -- works even for cases that are still mid-run or
# were only partially completed before a disconnect.

# %%
for geometry, material in CASES:
    run_one_case(geometry, material)

print("\nAll cases either completed or already were -- see per-case status above.")
# Out:
# Streaming output truncated to the last 5000 lines.
# [step 7/10] converged in 2 iters, ||R||=1.729e-10
# [step 7/10] converged in 2 iters, ||R||=1.051e-10
# [step 8/10] converged in 2 iters, ||R||=1.335e-11
# [step 7/10] converged in 2 iters, ||R||=6.713e-11
# [step 8/10] converged in 2 iters, ||R||=7.509e-12
# [step 7/10] converged in 2 iters, ||R||=2.965e-11
# [step 8/10] converged in 2 iters, ||R||=2.961e-09
# [step 7/10] converged in 2 iters, ||R||=3.030e-10
# [step 7/10] converged in 2 iters, ||R||=6.097e-11
# [step 8/10] converged in 2 iters, ||R||=3.229e-11
# [step 8/10] converged in 2 iters, ||R||=3.821e-10
# [step 8/10] converged in 2 iters, ||R||=1.765e-10
# [step 7/10] converged in 2 iters, ||R||=2.753e-10
# [step 8/10] converged in 2 iters, ||R||=1.062e-10
# [step 8/10] converged in 2 iters, ||R||=6.788e-11
# [step 9/10] converged in 2 iters, ||R||=1.357e-11
# [step 9/10] converged in 2 iters, ||R||=7.497e-12
# [step 8/10] converged in 2 iters, ||R||=2.979e-11
# [step 9/10] converged in 2 iters, ||R||=3.056e-09
# [step 8/10] converged in 2 iters, ||R||=3.092e-10
# [step 8/10] converged in 2 iters, ||R||=6.175e-11
# [step 9/10] converged in 2 iters, ||R||=3.262e-11
# [step 9/10] converged in 2 iters, ||R||=1.803e-10
# [step 9/10] converged in 2 iters, ||R||=3.893e-10
# [step 8/10] converged in 2 iters, ||R||=2.797e-10
# [step 9/10] converged in 2 iters, ||R||=1.079e-10
# [step 9/10] converged in 2 iters, ||R||=6.870e-11
# [step 10/10] converged in 2 iters, ||R||=1.360e-11
#   Sample 697: max displacement=4.147e-03
# [step 10/10] converged in 2 iters, ||R||=7.402e-12
#   Sample 698: max displacement=4.360e-03
# [step 9/10] converged in 2 iters, ||R||=3.012e-11
# [step 10/10] converged in 2 iters, ||R||=3.155e-09
#   Sample 699: max displacement=1.263e-02
# [step 9/10] converged in 2 iters, ||R||=3.156e-10
# [step 10/10] converged in 2 iters, ||R||=3.311e-11
# Completed 700/1000 samples
#   Sample 700: max displacement=4.868e-03
# [step 9/10] converged in 2 iters, ||R||=6.293e-11
# [step 10/10] converged in 2 iters, ||R||=1.839e-10
#   Sample 701: max displacement=7.989e-03
# [step 10/10] converged in 2 iters, ||R||=3.970e-10
#   Sample 702: max displacement=7.477e-03
# [step 9/10] converged in 2 iters, ||R||=2.842e-10
# [step 10/10] converged in 2 iters, ||R||=1.098e-10
#   Sample 703: max displacement=5.750e-03
# [step 10/10] converged in 2 iters, ||R||=6.926e-11
#   Sample 704: max displacement=6.617e-03
# [step 1/10] converged in 2 iters, ||R||=7.155e-10
# [step 1/10] converged in 2 iters, ||R||=3.205e-11
# [step 10/10] converged in 2 iters, ||R||=3.043e-11
#   Sample 705: max displacement=5.180e-03
# [step 1/10] converged in 2 iters, ||R||=9.969e-11
# [step 10/10] converged in 2 iters, ||R||=3.221e-10
#   Sample 706: max displacement=6.600e-03
# [step 1/10] converged in 2 iters, ||R||=3.782e-11
# [step 10/10] converged in 2 iters, ||R||=6.400e-11
#   Sample 707: max displacement=6.107e-03
# [step 1/10] converged in 2 iters, ||R||=1.006e-11
# [step 1/10] converged in 2 iters, ||R||=2.593e-11
# [step 10/10] converged in 2 iters, ||R||=2.889e-10
#   Sample 708: max displacement=7.279e-03
# [step 1/10] converged in 2 iters, ||R||=1.181e-10
# [step 1/10] converged in 2 iters, ||R||=5.109e-10
# [step 2/10] converged in 2 iters, ||R||=7.314e-10
# [step 2/10] converged in 2 iters, ||R||=3.224e-11
# [step 1/10] converged in 2 iters, ||R||=1.472e-11
# [step 2/10] converged in 2 iters, ||R||=1.015e-10
# [step 1/10] converged in 2 iters, ||R||=5.339e-10
# [step 2/10] converged in 2 iters, ||R||=3.792e-11
# [step 1/10] converged in 2 iters, ||R||=8.505e-10
# [step 1/10] converged in 2 iters, ||R||=3.063e-10
# [step 2/10] converged in 2 iters, ||R||=1.024e-11
# [step 2/10] converged in 2 iters, ||R||=2.610e-11
# [step 2/10] converged in 2 iters, ||R||=1.197e-10
# [step 2/10] converged in 2 iters, ||R||=5.212e-10
# [step 3/10] converged in 2 iters, ||R||=7.472e-10
# [step 3/10] converged in 2 iters, ||R||=3.273e-11
# [step 2/10] converged in 2 iters, ||R||=1.501e-11
# [step 3/10] converged in 2 iters, ||R||=1.033e-10
# [step 3/10] converged in 2 iters, ||R||=3.784e-11
# [step 2/10] converged in 2 iters, ||R||=8.739e-10
# [step 2/10] converged in 2 iters, ||R||=5.442e-10
# [step 3/10] converged in 2 iters, ||R||=1.013e-11
# [step 2/10] converged in 2 iters, ||R||=3.135e-10
# [step 3/10] converged in 2 iters, ||R||=2.624e-11
# [step 3/10] converged in 2 iters, ||R||=1.212e-10
# [step 3/10] converged in 2 iters, ||R||=5.313e-10
# [step 4/10] converged in 2 iters, ||R||=3.334e-11
# [step 4/10] converged in 2 iters, ||R||=7.641e-10
# [step 3/10] converged in 2 iters, ||R||=1.495e-11
# [step 4/10] converged in 2 iters, ||R||=1.049e-10
# [step 4/10] converged in 2 iters, ||R||=3.810e-11
# [step 3/10] converged in 2 iters, ||R||=8.980e-10
# [step 3/10] converged in 2 iters, ||R||=5.546e-10
# [step 3/10] converged in 2 iters, ||R||=3.209e-10
# [step 4/10] converged in 2 iters, ||R||=1.033e-11
# [step 4/10] converged in 2 iters, ||R||=2.656e-11
# [step 4/10] converged in 2 iters, ||R||=1.222e-10
# [step 4/10] converged in 2 iters, ||R||=5.424e-10
# [step 5/10] converged in 2 iters, ||R||=3.362e-11
# [step 5/10] converged in 2 iters, ||R||=7.811e-10
# [step 4/10] converged in 2 iters, ||R||=1.507e-11
# [step 5/10] converged in 2 iters, ||R||=1.066e-10
# [step 5/10] converged in 2 iters, ||R||=3.750e-11
# [step 4/10] converged in 2 iters, ||R||=5.649e-10
# [step 4/10] converged in 2 iters, ||R||=9.232e-10
# [step 4/10] converged in 2 iters, ||R||=3.287e-10
# [step 5/10] converged in 2 iters, ||R||=2.640e-11
# [step 5/10] converged in 2 iters, ||R||=1.242e-10
# [step 5/10] converged in 2 iters, ||R||=1.041e-11
# [step 5/10] converged in 2 iters, ||R||=5.530e-10
# [step 6/10] converged in 2 iters, ||R||=3.434e-11
# [step 5/10] converged in 2 iters, ||R||=1.541e-11
# [step 6/10] converged in 2 iters, ||R||=7.987e-10
# [step 6/10] converged in 2 iters, ||R||=1.086e-10
# [step 6/10] converged in 2 iters, ||R||=3.797e-11
# [step 5/10] converged in 2 iters, ||R||=5.757e-10
# [step 5/10] converged in 2 iters, ||R||=9.490e-10
# [step 5/10] converged in 2 iters, ||R||=3.365e-10
# [step 6/10] converged in 2 iters, ||R||=2.644e-11
# [step 6/10] converged in 2 iters, ||R||=1.258e-10
# [step 6/10] converged in 2 iters, ||R||=1.067e-11
# [step 6/10] converged in 2 iters, ||R||=5.641e-10
# [step 7/10] converged in 2 iters, ||R||=3.460e-11
# [step 6/10] converged in 2 iters, ||R||=1.551e-11
# [step 7/10] converged in 2 iters, ||R||=8.170e-10
# [step 7/10] converged in 2 iters, ||R||=1.104e-10
# [step 7/10] converged in 2 iters, ||R||=3.768e-11
# [step 6/10] converged in 2 iters, ||R||=5.872e-10
# [step 6/10] converged in 2 iters, ||R||=9.756e-10
# [step 6/10] converged in 2 iters, ||R||=3.446e-10
# [step 7/10] converged in 2 iters, ||R||=2.657e-11
# [step 7/10] converged in 2 iters, ||R||=1.272e-10
# [step 7/10] converged in 2 iters, ||R||=1.064e-11
# [step 7/10] converged in 2 iters, ||R||=5.756e-10
# [step 8/10] converged in 2 iters, ||R||=3.510e-11
# [step 7/10] converged in 2 iters, ||R||=1.557e-11
# [step 8/10] converged in 2 iters, ||R||=8.356e-10
# [step 8/10] converged in 2 iters, ||R||=1.122e-10
# [step 8/10] converged in 2 iters, ||R||=3.789e-11
# [step 7/10] converged in 2 iters, ||R||=5.984e-10
# [step 7/10] converged in 2 iters, ||R||=1.003e-09
# [step 7/10] converged in 2 iters, ||R||=3.528e-10
# [step 8/10] converged in 2 iters, ||R||=2.689e-11
# [step 8/10] converged in 2 iters, ||R||=1.290e-10
# [step 8/10] converged in 2 iters, ||R||=1.053e-11
# [step 8/10] converged in 2 iters, ||R||=5.873e-10
# [step 9/10] converged in 2 iters, ||R||=3.548e-11
# [step 9/10] converged in 2 iters, ||R||=8.551e-10
# [step 8/10] converged in 2 iters, ||R||=1.572e-11
# [step 9/10] converged in 2 iters, ||R||=1.143e-10
# [step 9/10] converged in 2 iters, ||R||=3.763e-11
# [step 8/10] converged in 2 iters, ||R||=6.097e-10
# [step 8/10] converged in 2 iters, ||R||=1.032e-09
# [step 8/10] converged in 2 iters, ||R||=3.613e-10
# [step 9/10] converged in 2 iters, ||R||=2.711e-11
# [step 9/10] converged in 2 iters, ||R||=1.309e-10
# [step 9/10] converged in 2 iters, ||R||=1.083e-11
# [step 9/10] converged in 2 iters, ||R||=5.990e-10
# [step 10/10] converged in 2 iters, ||R||=3.620e-11
#   Sample 710: max displacement=5.246e-03
# [step 10/10] converged in 2 iters, ||R||=8.751e-10
# Completed 710/1000 samples
#   Sample 709: max displacement=1.009e-02
# [step 9/10] converged in 2 iters, ||R||=1.595e-11
# [step 10/10] converged in 2 iters, ||R||=1.163e-10
#   Sample 711: max displacement=6.067e-03
# [step 10/10] converged in 2 iters, ||R||=3.756e-11
#   Sample 712: max displacement=5.236e-03
# [step 9/10] converged in 2 iters, ||R||=6.218e-10
# [step 9/10] converged in 2 iters, ||R||=1.061e-09
# [step 9/10] converged in 2 iters, ||R||=3.701e-10
# [step 10/10] converged in 2 iters, ||R||=2.701e-11
#   Sample 714: max displacement=5.914e-03
# [step 10/10] converged in 2 iters, ||R||=1.323e-10
#   Sample 715: max displacement=7.034e-03
# [step 10/10] converged in 2 iters, ||R||=1.110e-11
#   Sample 713: max displacement=3.632e-03
# [step 10/10] converged in 2 iters, ||R||=6.116e-10
#   Sample 716: max displacement=7.631e-03
# [step 1/10] converged in 2 iters, ||R||=3.161e-10
# [step 1/10] converged in 2 iters, ||R||=1.403e-10
# [step 10/10] converged in 2 iters, ||R||=1.598e-11
#   Sample 717: max displacement=3.655e-03
# [step 1/10] converged in 2 iters, ||R||=1.154e-10
# [step 1/10] converged in 2 iters, ||R||=6.243e-10
# [step 10/10] converged in 2 iters, ||R||=6.339e-10
#   Sample 718: max displacement=7.981e-03
# [step 10/10] converged in 2 iters, ||R||=1.091e-09
#   Sample 719: max displacement=9.845e-03
# [step 10/10] converged in 2 iters, ||R||=3.789e-10
# Completed 720/1000 samples
#   Sample 720: max displacement=7.150e-03
# [step 1/10] converged in 2 iters, ||R||=4.368e-11
# [step 1/10] converged in 2 iters, ||R||=2.423e-11
# [step 1/10] converged in 2 iters, ||R||=3.876e-11
# [step 1/10] converged in 2 iters, ||R||=3.495e-12
# [step 2/10] converged in 2 iters, ||R||=3.230e-10
# [step 2/10] converged in 2 iters, ||R||=1.430e-10
# [step 1/10] converged in 2 iters, ||R||=6.007e-10
# [step 2/10] converged in 2 iters, ||R||=1.176e-10
# [step 1/10] converged in 2 iters, ||R||=5.605e-11
# [step 2/10] converged in 2 iters, ||R||=6.405e-10
# [step 1/10] converged in 2 iters, ||R||=9.475e-11
# [step 1/10] converged in 2 iters, ||R||=3.117e-10
# [step 2/10] converged in 2 iters, ||R||=4.434e-11
# [step 2/10] converged in 2 iters, ||R||=2.430e-11
# [step 2/10] converged in 2 iters, ||R||=3.919e-11
# [step 2/10] converged in 2 iters, ||R||=3.882e-12
# [step 3/10] converged in 2 iters, ||R||=3.300e-10
# [step 3/10] converged in 2 iters, ||R||=1.459e-10
# [step 2/10] converged in 2 iters, ||R||=6.118e-10
# [step 3/10] converged in 2 iters, ||R||=1.199e-10
# [step 2/10] converged in 2 iters, ||R||=5.698e-11
# [step 3/10] converged in 2 iters, ||R||=6.574e-10
# [step 2/10] converged in 2 iters, ||R||=9.624e-11
# [step 2/10] converged in 2 iters, ||R||=3.186e-10
# [step 3/10] converged in 2 iters, ||R||=4.470e-11
# [step 3/10] converged in 2 iters, ||R||=2.436e-11
# [step 3/10] converged in 2 iters, ||R||=3.963e-11
# [step 3/10] converged in 2 iters, ||R||=3.676e-12
# [step 4/10] converged in 2 iters, ||R||=3.371e-10
# [step 4/10] converged in 2 iters, ||R||=1.488e-10
# [step 3/10] converged in 2 iters, ||R||=6.225e-10
# [step 4/10] converged in 2 iters, ||R||=1.225e-10
# [step 4/10] converged in 2 iters, ||R||=6.752e-10
# [step 3/10] converged in 2 iters, ||R||=5.763e-11
# [step 3/10] converged in 2 iters, ||R||=9.749e-11
# [step 4/10] converged in 2 iters, ||R||=4.545e-11
# [step 3/10] converged in 2 iters, ||R||=3.259e-10
# [step 4/10] converged in 2 iters, ||R||=2.447e-11
# [step 4/10] converged in 2 iters, ||R||=4.032e-11
# [step 4/10] converged in 2 iters, ||R||=3.644e-12
# [step 5/10] converged in 2 iters, ||R||=3.446e-10
# [step 5/10] converged in 2 iters, ||R||=1.517e-10
# [step 4/10] converged in 2 iters, ||R||=6.339e-10
# [step 5/10] converged in 2 iters, ||R||=1.250e-10
# [step 5/10] converged in 2 iters, ||R||=6.932e-10
# [step 4/10] converged in 2 iters, ||R||=5.840e-11
# [step 4/10] converged in 2 iters, ||R||=9.891e-11
# [step 4/10] converged in 2 iters, ||R||=3.333e-10
# [step 5/10] converged in 2 iters, ||R||=4.624e-11
# [step 5/10] converged in 2 iters, ||R||=2.462e-11
# [step 5/10] converged in 2 iters, ||R||=4.065e-11
# [step 5/10] converged in 2 iters, ||R||=3.675e-12
# [step 6/10] converged in 2 iters, ||R||=3.521e-10
# [step 6/10] converged in 2 iters, ||R||=1.547e-10
# [step 5/10] converged in 2 iters, ||R||=6.452e-10
# [step 6/10] converged in 2 iters, ||R||=1.274e-10
# [step 6/10] converged in 2 iters, ||R||=7.120e-10
# [step 5/10] converged in 2 iters, ||R||=5.921e-11
# [step 5/10] converged in 2 iters, ||R||=9.993e-11
# [step 5/10] converged in 2 iters, ||R||=3.410e-10
# [step 6/10] converged in 2 iters, ||R||=4.699e-11
# [step 6/10] converged in 2 iters, ||R||=4.127e-11
# [step 6/10] converged in 2 iters, ||R||=2.458e-11
# [step 6/10] converged in 2 iters, ||R||=3.657e-12
# [step 7/10] converged in 2 iters, ||R||=3.599e-10
# [step 7/10] converged in 2 iters, ||R||=1.579e-10
# [step 6/10] converged in 2 iters, ||R||=6.570e-10
# [step 7/10] converged in 2 iters, ||R||=1.304e-10
# [step 7/10] converged in 2 iters, ||R||=7.317e-10
# [step 6/10] converged in 2 iters, ||R||=5.985e-11
# [step 6/10] converged in 2 iters, ||R||=1.013e-10
# [step 7/10] converged in 2 iters, ||R||=4.730e-11
# [step 6/10] converged in 2 iters, ||R||=3.489e-10
# [step 7/10] converged in 2 iters, ||R||=4.213e-11
# [step 7/10] converged in 2 iters, ||R||=2.484e-11
# [step 7/10] converged in 2 iters, ||R||=3.772e-12
# [step 8/10] converged in 2 iters, ||R||=3.678e-10
# [step 8/10] converged in 2 iters, ||R||=1.608e-10
# [step 7/10] converged in 2 iters, ||R||=6.689e-10
# [step 8/10] converged in 2 iters, ||R||=1.328e-10
# [step 8/10] converged in 2 iters, ||R||=7.516e-10
# [step 7/10] converged in 2 iters, ||R||=6.079e-11
# [step 7/10] converged in 2 iters, ||R||=1.028e-10
# [step 7/10] converged in 2 iters, ||R||=3.571e-10
# [step 8/10] converged in 2 iters, ||R||=4.800e-11
# [step 8/10] converged in 2 iters, ||R||=4.244e-11
# [step 8/10] converged in 2 iters, ||R||=2.478e-11
# [step 8/10] converged in 2 iters, ||R||=3.639e-12
# [step 9/10] converged in 2 iters, ||R||=3.760e-10
# [step 9/10] converged in 2 iters, ||R||=1.645e-10
# [step 8/10] converged in 2 iters, ||R||=6.808e-10
# [step 9/10] converged in 2 iters, ||R||=1.357e-10
# [step 9/10] converged in 2 iters, ||R||=7.726e-10
# [step 8/10] converged in 2 iters, ||R||=6.181e-11
# [step 8/10] converged in 2 iters, ||R||=1.043e-10
# [step 8/10] converged in 2 iters, ||R||=3.655e-10
# [step 9/10] converged in 2 iters, ||R||=4.906e-11
# [step 9/10] converged in 2 iters, ||R||=4.317e-11
# [step 9/10] converged in 2 iters, ||R||=2.478e-11
# [step 9/10] converged in 2 iters, ||R||=3.927e-12
# [step 10/10] converged in 2 iters, ||R||=3.842e-10
#   Sample 721: max displacement=8.501e-03
# [step 10/10] converged in 2 iters, ||R||=1.676e-10
#   Sample 722: max displacement=7.056e-03
# [step 9/10] converged in 2 iters, ||R||=6.936e-10
# [step 10/10] converged in 2 iters, ||R||=1.384e-10
#   Sample 723: max displacement=7.112e-03
# [step 10/10] converged in 2 iters, ||R||=7.942e-10
#   Sample 724: max displacement=1.047e-02
# [step 9/10] converged in 2 iters, ||R||=6.251e-11
# [step 9/10] converged in 2 iters, ||R||=1.057e-10
# [step 9/10] converged in 2 iters, ||R||=3.746e-10
# [step 10/10] converged in 2 iters, ||R||=4.984e-11
#   Sample 726: max displacement=6.569e-03
# [step 10/10] converged in 2 iters, ||R||=4.382e-11
#   Sample 727: max displacement=6.048e-03
# [step 10/10] converged in 2 iters, ||R||=2.520e-11
#   Sample 725: max displacement=5.208e-03
# [step 10/10] converged in 2 iters, ||R||=3.622e-12
#   Sample 728: max displacement=2.643e-03
# [step 1/10] converged in 2 iters, ||R||=4.221e-10
# [step 1/10] converged in 2 iters, ||R||=5.915e-10
# [step 10/10] converged in 2 iters, ||R||=7.065e-10
#   Sample 729: max displacement=8.163e-03
# [step 1/10] converged in 2 iters, ||R||=3.001e-10
# [step 1/10] converged in 2 iters, ||R||=1.248e-10
# [step 10/10] converged in 2 iters, ||R||=6.356e-11
# Completed 730/1000 samples
#   Sample 730: max displacement=5.574e-03
# [step 10/10] converged in 2 iters, ||R||=1.070e-10
#   Sample 731: max displacement=5.538e-03
# [step 10/10] converged in 2 iters, ||R||=3.832e-10
#   Sample 732: max displacement=8.281e-03
# [step 1/10] converged in 2 iters, ||R||=7.654e-11
# [step 1/10] converged in 2 iters, ||R||=9.604e-11
# [step 1/10] converged in 2 iters, ||R||=4.423e-11
# [step 1/10] converged in 2 iters, ||R||=7.962e-11
# [step 2/10] converged in 2 iters, ||R||=4.319e-10
# [step 2/10] converged in 2 iters, ||R||=6.041e-10
# [step 1/10] converged in 2 iters, ||R||=3.884e-12
# [step 2/10] converged in 2 iters, ||R||=3.063e-10
# [step 2/10] converged in 2 iters, ||R||=1.262e-10
# [step 1/10] converged in 2 iters, ||R||=1.308e-11
# [step 1/10] converged in 2 iters, ||R||=3.260e-10
# [step 1/10] converged in 2 iters, ||R||=6.573e-10
# [step 2/10] converged in 2 iters, ||R||=7.735e-11
# [step 2/10] converged in 2 iters, ||R||=9.709e-11
# [step 2/10] converged in 2 iters, ||R||=4.439e-11
# [step 2/10] converged in 2 iters, ||R||=8.144e-11
# [step 3/10] converged in 2 iters, ||R||=4.419e-10
# [step 3/10] converged in 2 iters, ||R||=6.166e-10
# [step 2/10] converged in 2 iters, ||R||=3.658e-12
# [step 3/10] converged in 2 iters, ||R||=3.130e-10
# [step 3/10] converged in 2 iters, ||R||=1.278e-10
# [step 2/10] converged in 2 iters, ||R||=1.295e-11
# [step 2/10] converged in 2 iters, ||R||=3.302e-10
# [step 2/10] converged in 2 iters, ||R||=6.749e-10
# [step 3/10] converged in 2 iters, ||R||=7.835e-11
# [step 3/10] converged in 2 iters, ||R||=9.849e-11
# [step 3/10] converged in 2 iters, ||R||=4.429e-11
# [step 3/10] converged in 2 iters, ||R||=8.290e-11
# [step 4/10] converged in 2 iters, ||R||=4.519e-10
# [step 4/10] converged in 2 iters, ||R||=6.301e-10
# [step 3/10] converged in 2 iters, ||R||=3.773e-12
# [step 4/10] converged in 2 iters, ||R||=1.295e-10
# [step 4/10] converged in 2 iters, ||R||=3.194e-10
# [step 3/10] converged in 2 iters, ||R||=1.303e-11
# [step 3/10] converged in 2 iters, ||R||=3.346e-10
# [step 3/10] converged in 2 iters, ||R||=6.932e-10
# [step 4/10] converged in 2 iters, ||R||=7.907e-11
# [step 4/10] converged in 2 iters, ||R||=9.989e-11
# [step 4/10] converged in 2 iters, ||R||=4.423e-11
# [step 4/10] converged in 2 iters, ||R||=8.410e-11
# [step 5/10] converged in 2 iters, ||R||=4.625e-10
# [step 5/10] converged in 2 iters, ||R||=6.437e-10
# [step 4/10] converged in 2 iters, ||R||=3.694e-12
# [step 5/10] converged in 2 iters, ||R||=1.314e-10
# [step 5/10] converged in 2 iters, ||R||=3.263e-10
# [step 4/10] converged in 2 iters, ||R||=1.275e-11
# [step 4/10] converged in 2 iters, ||R||=3.386e-10
# [step 4/10] converged in 2 iters, ||R||=7.119e-10
# [step 5/10] converged in 2 iters, ||R||=8.023e-11
# [step 5/10] converged in 2 iters, ||R||=1.015e-10
# [step 5/10] converged in 2 iters, ||R||=4.436e-11
# [step 5/10] converged in 2 iters, ||R||=8.560e-11
# [step 6/10] converged in 2 iters, ||R||=4.735e-10
# [step 6/10] converged in 2 iters, ||R||=6.572e-10
# [step 5/10] converged in 2 iters, ||R||=4.003e-12
# [step 6/10] converged in 2 iters, ||R||=1.334e-10
# [step 6/10] converged in 2 iters, ||R||=3.336e-10
# [step 5/10] converged in 2 iters, ||R||=1.293e-11
# [step 5/10] converged in 2 iters, ||R||=3.427e-10
# [step 5/10] converged in 2 iters, ||R||=7.312e-10
# [step 6/10] converged in 2 iters, ||R||=1.030e-10
# [step 6/10] converged in 2 iters, ||R||=8.127e-11
# [step 6/10] converged in 2 iters, ||R||=4.426e-11
# [step 6/10] converged in 2 iters, ||R||=8.723e-11
# [step 7/10] converged in 2 iters, ||R||=4.843e-10
# [step 7/10] converged in 2 iters, ||R||=6.717e-10
# [step 6/10] converged in 2 iters, ||R||=3.875e-12
# [step 7/10] converged in 2 iters, ||R||=3.407e-10
# [step 7/10] converged in 2 iters, ||R||=1.350e-10
# [step 6/10] converged in 2 iters, ||R||=1.299e-11
# [step 6/10] converged in 2 iters, ||R||=3.471e-10
# [step 6/10] converged in 2 iters, ||R||=7.515e-10
# [step 7/10] converged in 2 iters, ||R||=8.209e-11
# [step 7/10] converged in 2 iters, ||R||=1.045e-10
# [step 7/10] converged in 2 iters, ||R||=4.410e-11
# [step 7/10] converged in 2 iters, ||R||=8.870e-11
# [step 8/10] converged in 2 iters, ||R||=4.958e-10
# [step 8/10] converged in 2 iters, ||R||=6.862e-10
# [step 7/10] converged in 2 iters, ||R||=3.690e-12
# [step 8/10] converged in 2 iters, ||R||=3.479e-10
# [step 8/10] converged in 2 iters, ||R||=1.369e-10
# [step 7/10] converged in 2 iters, ||R||=1.304e-11
# [step 7/10] converged in 2 iters, ||R||=3.512e-10
# [step 7/10] converged in 2 iters, ||R||=7.720e-10
# [step 8/10] converged in 2 iters, ||R||=8.313e-11
# [step 8/10] converged in 2 iters, ||R||=1.061e-10
# [step 8/10] converged in 2 iters, ||R||=4.432e-11
# [step 8/10] converged in 2 iters, ||R||=9.032e-11
# [step 9/10] converged in 2 iters, ||R||=5.076e-10
# [step 9/10] converged in 2 iters, ||R||=7.011e-10
# [step 8/10] converged in 2 iters, ||R||=3.854e-12
# [step 9/10] converged in 2 iters, ||R||=3.553e-10
# [step 9/10] converged in 2 iters, ||R||=1.385e-10
# [step 8/10] converged in 2 iters, ||R||=1.278e-11
# [step 8/10] converged in 2 iters, ||R||=3.557e-10
# [step 8/10] converged in 2 iters, ||R||=7.934e-10
# [step 9/10] converged in 2 iters, ||R||=8.395e-11
# [step 9/10] converged in 2 iters, ||R||=1.074e-10
# [step 9/10] converged in 2 iters, ||R||=4.398e-11
# [step 9/10] converged in 2 iters, ||R||=9.205e-11
# [step 10/10] converged in 2 iters, ||R||=5.195e-10
#   Sample 733: max displacement=8.133e-03
# [step 10/10] converged in 2 iters, ||R||=7.168e-10
#   Sample 734: max displacement=9.248e-03
# [step 9/10] converged in 2 iters, ||R||=3.992e-12
# [step 10/10] converged in 2 iters, ||R||=3.635e-10
#   Sample 735: max displacement=8.714e-03
# [step 10/10] converged in 2 iters, ||R||=1.404e-10
#   Sample 736: max displacement=6.091e-03
# [step 9/10] converged in 2 iters, ||R||=1.271e-11
# [step 9/10] converged in 2 iters, ||R||=3.599e-10
# [step 9/10] converged in 2 iters, ||R||=8.157e-10
# [step 10/10] converged in 2 iters, ||R||=8.528e-11
#   Sample 737: max displacement=7.388e-03
# [step 10/10] converged in 2 iters, ||R||=1.092e-10
#   Sample 738: max displacement=5.945e-03
# [step 10/10] converged in 2 iters, ||R||=4.443e-11
#   Sample 739: max displacement=6.573e-03
# [step 10/10] converged in 2 iters, ||R||=9.348e-11
# Completed 740/1000 samples
#   Sample 740: max displacement=5.590e-03
# [step 1/10] converged in 2 iters, ||R||=1.216e-11
# [step 1/10] converged in 2 iters, ||R||=3.201e-10
# [step 10/10] converged in 2 iters, ||R||=3.955e-12
#   Sample 741: max displacement=2.136e-03
# [step 1/10] converged in 2 iters, ||R||=7.297e-10
# [step 1/10] converged in 2 iters, ||R||=5.108e-12
# [step 10/10] converged in 2 iters, ||R||=1.332e-11
#   Sample 742: max displacement=4.753e-03
# [step 10/10] converged in 2 iters, ||R||=3.644e-10
#   Sample 743: max displacement=6.347e-03
# [step 10/10] converged in 2 iters, ||R||=8.384e-10
#   Sample 744: max displacement=1.038e-02
# [step 1/10] converged in 2 iters, ||R||=1.465e-10
# [step 1/10] converged in 2 iters, ||R||=8.168e-11
# [step 1/10] converged in 2 iters, ||R||=2.845e-11
# [step 1/10] converged in 2 iters, ||R||=8.962e-11
# [step 2/10] converged in 2 iters, ||R||=1.226e-11
# [step 2/10] converged in 2 iters, ||R||=3.255e-10
# [step 1/10] converged in 2 iters, ||R||=1.305e-11
# [step 2/10] converged in 2 iters, ||R||=7.520e-10
# [step 2/10] converged in 2 iters, ||R||=5.255e-12
# [step 1/10] converged in 2 iters, ||R||=2.023e-11
# [step 1/10] converged in 2 iters, ||R||=1.512e-10
# [step 1/10] converged in 2 iters, ||R||=4.933e-11
# [step 2/10] converged in 2 iters, ||R||=1.482e-10
# [step 2/10] converged in 2 iters, ||R||=8.289e-11
# [step 2/10] converged in 2 iters, ||R||=2.857e-11
# [step 2/10] converged in 2 iters, ||R||=9.081e-11
# [step 3/10] converged in 2 iters, ||R||=1.203e-11
# [step 3/10] converged in 2 iters, ||R||=3.313e-10
# [step 2/10] converged in 2 iters, ||R||=1.303e-11
# [step 3/10] converged in 2 iters, ||R||=7.748e-10
# [step 3/10] converged in 2 iters, ||R||=5.484e-12
# [step 2/10] converged in 2 iters, ||R||=1.538e-10
# [step 2/10] converged in 2 iters, ||R||=2.070e-11
# [step 2/10] converged in 2 iters, ||R||=5.024e-11
# [step 3/10] converged in 2 iters, ||R||=1.501e-10
# [step 3/10] converged in 2 iters, ||R||=8.409e-11
# [step 3/10] converged in 2 iters, ||R||=2.862e-11
# [step 3/10] converged in 2 iters, ||R||=9.210e-11
# [step 4/10] converged in 2 iters, ||R||=1.218e-11
# [step 4/10] converged in 2 iters, ||R||=3.372e-10
# [step 3/10] converged in 2 iters, ||R||=1.279e-11
# [step 4/10] converged in 2 iters, ||R||=7.985e-10
# [step 4/10] converged in 2 iters, ||R||=5.543e-12
# [step 3/10] converged in 2 iters, ||R||=1.568e-10
# [step 3/10] converged in 2 iters, ||R||=2.110e-11
# [step 3/10] converged in 2 iters, ||R||=5.067e-11
# [step 4/10] converged in 2 iters, ||R||=1.519e-10
# [step 4/10] converged in 2 iters, ||R||=8.538e-11
# [step 4/10] converged in 2 iters, ||R||=2.845e-11
# [step 4/10] converged in 2 iters, ||R||=9.298e-11
# [step 5/10] converged in 2 iters, ||R||=1.203e-11
# [step 5/10] converged in 2 iters, ||R||=3.434e-10
# [step 4/10] converged in 2 iters, ||R||=1.309e-11
# [step 5/10] converged in 2 iters, ||R||=8.230e-10
# [step 5/10] converged in 2 iters, ||R||=5.222e-12
# [step 4/10] converged in 2 iters, ||R||=1.597e-10
# [step 4/10] converged in 2 iters, ||R||=2.112e-11
# [step 4/10] converged in 2 iters, ||R||=5.179e-11
# [step 5/10] converged in 2 iters, ||R||=1.539e-10
# [step 5/10] converged in 2 iters, ||R||=8.655e-11
# [step 5/10] converged in 2 iters, ||R||=2.859e-11
# [step 5/10] converged in 2 iters, ||R||=9.496e-11
# [step 6/10] converged in 2 iters, ||R||=1.194e-11
# [step 6/10] converged in 2 iters, ||R||=3.497e-10
# [step 5/10] converged in 2 iters, ||R||=1.296e-11
# [step 6/10] converged in 2 iters, ||R||=8.482e-10
# [step 6/10] converged in 2 iters, ||R||=5.390e-12
# [step 5/10] converged in 2 iters, ||R||=1.626e-10
# [step 5/10] converged in 2 iters, ||R||=2.150e-11
# [step 5/10] converged in 2 iters, ||R||=5.280e-11
# [step 6/10] converged in 2 iters, ||R||=1.555e-10
# [step 6/10] converged in 2 iters, ||R||=8.793e-11
# [step 6/10] converged in 2 iters, ||R||=2.852e-11
# [step 6/10] converged in 2 iters, ||R||=9.607e-11
# [step 7/10] converged in 2 iters, ||R||=1.190e-11
# [step 7/10] converged in 2 iters, ||R||=3.559e-10
# [step 6/10] converged in 2 iters, ||R||=1.312e-11
# [step 7/10] converged in 2 iters, ||R||=8.745e-10
# [step 7/10] converged in 2 iters, ||R||=5.586e-12
# [step 6/10] converged in 2 iters, ||R||=1.655e-10
# [step 6/10] converged in 2 iters, ||R||=2.147e-11
# [step 6/10] converged in 2 iters, ||R||=5.311e-11
# [step 7/10] converged in 2 iters, ||R||=1.577e-10
# [step 7/10] converged in 2 iters, ||R||=8.927e-11
# [step 7/10] converged in 2 iters, ||R||=2.853e-11
# [step 7/10] converged in 2 iters, ||R||=9.751e-11
# [step 8/10] converged in 2 iters, ||R||=1.191e-11
# [step 8/10] converged in 2 iters, ||R||=3.627e-10
# [step 7/10] converged in 2 iters, ||R||=1.300e-11
# [step 8/10] converged in 2 iters, ||R||=9.017e-10
# [step 8/10] converged in 2 iters, ||R||=5.368e-12
# [step 7/10] converged in 2 iters, ||R||=1.683e-10
# [step 7/10] converged in 2 iters, ||R||=2.169e-11
# [step 7/10] converged in 2 iters, ||R||=5.460e-11
# [step 8/10] converged in 2 iters, ||R||=1.595e-10
# [step 8/10] converged in 2 iters, ||R||=9.060e-11
# [step 8/10] converged in 2 iters, ||R||=2.859e-11
# [step 8/10] converged in 2 iters, ||R||=9.873e-11
# [step 9/10] converged in 2 iters, ||R||=1.226e-11
# [step 9/10] converged in 2 iters, ||R||=3.691e-10
# [step 8/10] converged in 2 iters, ||R||=1.320e-11
# [step 9/10] converged in 2 iters, ||R||=5.292e-12
# [step 9/10] converged in 2 iters, ||R||=9.296e-10
# [step 8/10] converged in 2 iters, ||R||=1.715e-10
# [step 8/10] converged in 2 iters, ||R||=2.187e-11
# [step 9/10] converged in 2 iters, ||R||=1.614e-10
# [step 8/10] converged in 2 iters, ||R||=5.602e-11
# [step 9/10] converged in 2 iters, ||R||=9.197e-11
# [step 9/10] converged in 2 iters, ||R||=2.865e-11
# [step 9/10] converged in 2 iters, ||R||=9.974e-11
# [step 10/10] converged in 2 iters, ||R||=1.195e-11
#   Sample 745: max displacement=4.794e-03
# [step 10/10] converged in 2 iters, ||R||=3.760e-10
#   Sample 746: max displacement=8.309e-03
# [step 9/10] converged in 2 iters, ||R||=1.313e-11
# [step 10/10] converged in 2 iters, ||R||=5.695e-12
#   Sample 748: max displacement=2.849e-03
# [step 10/10] converged in 2 iters, ||R||=9.587e-10
#   Sample 747: max displacement=1.029e-02
# [step 9/10] converged in 2 iters, ||R||=1.750e-10
# [step 9/10] converged in 2 iters, ||R||=2.226e-11
# [step 10/10] converged in 2 iters, ||R||=1.636e-10
#   Sample 749: max displacement=5.425e-03
# [step 9/10] converged in 2 iters, ||R||=5.641e-11
# [step 10/10] converged in 2 iters, ||R||=9.338e-11
# Completed 750/1000 samples
#   Sample 750: max displacement=5.535e-03
# [step 10/10] converged in 2 iters, ||R||=2.859e-11
#   Sample 751: max displacement=5.748e-03
# [step 10/10] converged in 2 iters, ||R||=1.013e-10
#   Sample 752: max displacement=5.324e-03
# [step 1/10] converged in 2 iters, ||R||=7.448e-10
# [step 1/10] converged in 2 iters, ||R||=1.649e-10
# [step 10/10] converged in 2 iters, ||R||=1.292e-11
#   Sample 753: max displacement=4.200e-03
# [step 1/10] converged in 2 iters, ||R||=2.697e-11
# [step 1/10] converged in 2 iters, ||R||=6.718e-10
# [step 10/10] converged in 2 iters, ||R||=1.781e-10
#   Sample 754: max displacement=6.265e-03
# [step 10/10] converged in 2 iters, ||R||=2.254e-11
#   Sample 755: max displacement=4.991e-03
# [step 1/10] converged in 2 iters, ||R||=2.208e-11
# [step 10/10] converged in 2 iters, ||R||=5.747e-11
#   Sample 756: max displacement=5.888e-03
# [step 1/10] converged in 2 iters, ||R||=8.908e-12
# [step 1/10] converged in 2 iters, ||R||=5.462e-11
# [step 1/10] converged in 2 iters, ||R||=6.740e-11
# [step 2/10] converged in 2 iters, ||R||=7.605e-10
# [step 2/10] converged in 2 iters, ||R||=1.649e-10
# [step 1/10] converged in 2 iters, ||R||=8.022e-11
# [step 2/10] converged in 2 iters, ||R||=2.694e-11
# [step 2/10] converged in 2 iters, ||R||=6.854e-10
# [step 1/10] converged in 2 iters, ||R||=1.479e-10
# [step 1/10] converged in 2 iters, ||R||=1.515e-11
# [step 1/10] converged in 2 iters, ||R||=2.067e-10
# [step 2/10] converged in 2 iters, ||R||=2.222e-11
# [step 2/10] converged in 2 iters, ||R||=8.811e-12
# [step 2/10] converged in 2 iters, ||R||=5.565e-11
# [step 2/10] converged in 2 iters, ||R||=6.819e-11
# [step 3/10] converged in 2 iters, ||R||=7.766e-10
# [step 3/10] converged in 2 iters, ||R||=1.647e-10
# [step 2/10] converged in 2 iters, ||R||=8.123e-11
# [step 3/10] converged in 2 iters, ||R||=2.731e-11
# [step 3/10] converged in 2 iters, ||R||=6.996e-10
# [step 2/10] converged in 2 iters, ||R||=1.496e-10
# [step 2/10] converged in 2 iters, ||R||=1.542e-11
# [step 2/10] converged in 2 iters, ||R||=2.103e-10
# [step 3/10] converged in 2 iters, ||R||=2.224e-11
# [step 3/10] converged in 2 iters, ||R||=8.930e-12
# [step 3/10] converged in 2 iters, ||R||=5.659e-11
# [step 3/10] converged in 2 iters, ||R||=6.894e-11
# [step 4/10] converged in 2 iters, ||R||=7.931e-10
# [step 4/10] converged in 2 iters, ||R||=1.648e-10
# [step 3/10] converged in 2 iters, ||R||=8.233e-11
# [step 4/10] converged in 2 iters, ||R||=2.738e-11
# [step 4/10] converged in 2 iters, ||R||=7.142e-10
# [step 3/10] converged in 2 iters, ||R||=1.516e-10
# [step 3/10] converged in 2 iters, ||R||=1.565e-11
# [step 3/10] converged in 2 iters, ||R||=2.146e-10
# [step 4/10] converged in 2 iters, ||R||=9.027e-12
# [step 4/10] converged in 2 iters, ||R||=2.256e-11
# [step 4/10] converged in 2 iters, ||R||=5.773e-11
# [step 4/10] converged in 2 iters, ||R||=6.963e-11
# [step 5/10] converged in 2 iters, ||R||=8.101e-10
# [step 5/10] converged in 2 iters, ||R||=1.647e-10
# [step 4/10] converged in 2 iters, ||R||=8.341e-11
# [step 5/10] converged in 2 iters, ||R||=2.748e-11
# [step 5/10] converged in 2 iters, ||R||=7.288e-10
# [step 4/10] converged in 2 iters, ||R||=1.536e-10
# [step 4/10] converged in 2 iters, ||R||=1.562e-11
# [step 4/10] converged in 2 iters, ||R||=2.185e-10
# [step 5/10] converged in 2 iters, ||R||=9.159e-12
# [step 5/10] converged in 2 iters, ||R||=2.266e-11
# [step 5/10] converged in 2 iters, ||R||=5.825e-11
# [step 5/10] converged in 2 iters, ||R||=7.054e-11
# [step 6/10] converged in 2 iters, ||R||=8.275e-10
# [step 6/10] converged in 2 iters, ||R||=1.647e-10
# [step 5/10] converged in 2 iters, ||R||=8.451e-11
# [step 6/10] converged in 2 iters, ||R||=2.777e-11
# [step 6/10] converged in 2 iters, ||R||=7.447e-10
# [step 5/10] converged in 2 iters, ||R||=1.558e-10
# [step 5/10] converged in 2 iters, ||R||=1.557e-11
# [step 5/10] converged in 2 iters, ||R||=2.226e-10
# [step 6/10] converged in 2 iters, ||R||=9.412e-12
# [step 6/10] converged in 2 iters, ||R||=2.284e-11
# [step 6/10] converged in 2 iters, ||R||=5.939e-11
# [step 6/10] converged in 2 iters, ||R||=7.109e-11
# [step 7/10] converged in 2 iters, ||R||=8.453e-10
# [step 7/10] converged in 2 iters, ||R||=1.647e-10
# [step 6/10] converged in 2 iters, ||R||=8.561e-11
# [step 7/10] converged in 2 iters, ||R||=2.792e-11
# [step 7/10] converged in 2 iters, ||R||=7.600e-10
# [step 6/10] converged in 2 iters, ||R||=1.575e-10
# [step 6/10] converged in 2 iters, ||R||=1.580e-11
# [step 6/10] converged in 2 iters, ||R||=2.267e-10
# [step 7/10] converged in 2 iters, ||R||=9.212e-12
# [step 7/10] converged in 2 iters, ||R||=2.283e-11
# [step 7/10] converged in 2 iters, ||R||=6.039e-11
# [step 7/10] converged in 2 iters, ||R||=7.187e-11
# [step 8/10] converged in 2 iters, ||R||=8.633e-10
# [step 8/10] converged in 2 iters, ||R||=1.645e-10
# [step 7/10] converged in 2 iters, ||R||=8.671e-11
# [step 8/10] converged in 2 iters, ||R||=2.831e-11
# [step 8/10] converged in 2 iters, ||R||=7.763e-10
# [step 7/10] converged in 2 iters, ||R||=1.584e-11
# [step 7/10] converged in 2 iters, ||R||=1.594e-10
# [step 8/10] converged in 2 iters, ||R||=9.483e-12
# [step 7/10] converged in 2 iters, ||R||=2.311e-10
# [step 8/10] converged in 2 iters, ||R||=6.135e-11
# [step 8/10] converged in 2 iters, ||R||=2.293e-11
# [step 8/10] converged in 2 iters, ||R||=7.242e-11
# [step 9/10] converged in 2 iters, ||R||=8.819e-10
# [step 9/10] converged in 2 iters, ||R||=1.645e-10
# [step 8/10] converged in 2 iters, ||R||=8.769e-11
# [step 9/10] converged in 2 iters, ||R||=2.855e-11
# [step 8/10] converged in 2 iters, ||R||=1.611e-11
# [step 9/10] converged in 2 iters, ||R||=7.925e-10
# [step 8/10] converged in 2 iters, ||R||=1.619e-10
# [step 9/10] converged in 2 iters, ||R||=9.382e-12
# [step 8/10] converged in 2 iters, ||R||=2.354e-10
# [step 9/10] converged in 2 iters, ||R||=6.265e-11
# [step 9/10] converged in 2 iters, ||R||=2.297e-11
# [step 9/10] converged in 2 iters, ||R||=7.348e-11
# [step 10/10] converged in 2 iters, ||R||=9.011e-10
#   Sample 757: max displacement=8.794e-03
# [step 10/10] converged in 2 iters, ||R||=1.644e-10
#   Sample 758: max displacement=8.344e-03
# [step 9/10] converged in 2 iters, ||R||=8.906e-11
# [step 10/10] converged in 2 iters, ||R||=2.844e-11
#   Sample 759: max displacement=4.845e-03
# [step 9/10] converged in 2 iters, ||R||=1.593e-11
# [step 10/10] converged in 2 iters, ||R||=8.097e-10
# Completed 760/1000 samples
#   Sample 760: max displacement=9.222e-03
# [step 9/10] converged in 2 iters, ||R||=1.641e-10
# [step 10/10] converged in 2 iters, ||R||=9.569e-12
#   Sample 763: max displacement=2.844e-03
# [step 9/10] converged in 2 iters, ||R||=2.398e-10
# [step 10/10] converged in 2 iters, ||R||=6.394e-11
#   Sample 762: max displacement=6.508e-03
# [step 10/10] converged in 2 iters, ||R||=2.342e-11
#   Sample 761: max displacement=5.019e-03
# [step 10/10] converged in 2 iters, ||R||=7.435e-11
#   Sample 764: max displacement=4.805e-03
# [step 1/10] converged in 2 iters, ||R||=9.280e-10
# [step 1/10] converged in 2 iters, ||R||=1.801e-10
# [step 10/10] converged in 2 iters, ||R||=9.017e-11
#   Sample 765: max displacement=5.894e-03
# [step 1/10] converged in 2 iters, ||R||=6.194e-11
# [step 1/10] converged in 2 iters, ||R||=2.564e-10
# [step 10/10] converged in 2 iters, ||R||=1.600e-11
#   Sample 767: max displacement=3.994e-03
# [step 10/10] converged in 2 iters, ||R||=1.662e-10
#   Sample 766: max displacement=6.621e-03
# [step 1/10] converged in 2 iters, ||R||=1.040e-10
# [step 10/10] converged in 2 iters, ||R||=2.445e-10
#   Sample 768: max displacement=6.997e-03
# [step 1/10] converged in 2 iters, ||R||=5.962e-11
# [step 1/10] converged in 2 iters, ||R||=5.791e-11
# [step 1/10] converged in 2 iters, ||R||=7.156e-10
# [step 2/10] converged in 2 iters, ||R||=9.511e-10
# [step 2/10] converged in 2 iters, ||R||=1.822e-10
# [step 1/10] converged in 2 iters, ||R||=1.558e-11
# [step 2/10] converged in 2 iters, ||R||=6.254e-11
# [step 2/10] converged in 2 iters, ||R||=2.631e-10
# [step 1/10] converged in 2 iters, ||R||=3.978e-11
# [step 1/10] converged in 2 iters, ||R||=4.415e-11
# [step 2/10] converged in 2 iters, ||R||=1.049e-10
# [step 1/10] converged in 2 iters, ||R||=1.452e-10
# [step 2/10] converged in 2 iters, ||R||=6.016e-11
# [step 2/10] converged in 2 iters, ||R||=5.836e-11
# [step 2/10] converged in 2 iters, ||R||=7.320e-10
# [step 3/10] converged in 2 iters, ||R||=9.746e-10
# [step 3/10] converged in 2 iters, ||R||=1.842e-10
# [step 2/10] converged in 2 iters, ||R||=1.588e-11
# [step 3/10] converged in 2 iters, ||R||=6.349e-11
# [step 3/10] converged in 2 iters, ||R||=2.699e-10
# [step 2/10] converged in 2 iters, ||R||=4.070e-11
# [step 2/10] converged in 2 iters, ||R||=4.393e-11
# [step 3/10] converged in 2 iters, ||R||=1.061e-10
# [step 2/10] converged in 2 iters, ||R||=1.471e-10
# [step 3/10] converged in 2 iters, ||R||=6.061e-11
# [step 3/10] converged in 2 iters, ||R||=5.885e-11
# [step 3/10] converged in 2 iters, ||R||=7.495e-10
# [step 4/10] converged in 2 iters, ||R||=9.989e-10
# [step 4/10] converged in 2 iters, ||R||=1.862e-10
# [step 3/10] converged in 2 iters, ||R||=1.595e-11
# [step 4/10] converged in 2 iters, ||R||=6.431e-11
# [step 4/10] converged in 2 iters, ||R||=2.775e-10
# [step 3/10] converged in 2 iters, ||R||=4.121e-11
# [step 3/10] converged in 2 iters, ||R||=4.376e-11
# [step 4/10] converged in 2 iters, ||R||=1.073e-10
# [step 3/10] converged in 2 iters, ||R||=1.488e-10
# [step 4/10] converged in 2 iters, ||R||=5.953e-11
# [step 4/10] converged in 2 iters, ||R||=6.177e-11
# [step 5/10] converged in 2 iters, ||R||=1.024e-09
# [step 4/10] converged in 2 iters, ||R||=7.670e-10
# [step 5/10] converged in 2 iters, ||R||=1.885e-10
# [step 4/10] converged in 2 iters, ||R||=1.614e-11
# [step 5/10] converged in 2 iters, ||R||=6.536e-11
# [step 5/10] converged in 2 iters, ||R||=2.849e-10
# [step 4/10] converged in 2 iters, ||R||=4.164e-11
# [step 4/10] converged in 2 iters, ||R||=4.399e-11
# [step 5/10] converged in 2 iters, ||R||=1.083e-10
# [step 5/10] converged in 2 iters, ||R||=5.998e-11
# [step 4/10] converged in 2 iters, ||R||=1.507e-10
# [step 5/10] converged in 2 iters, ||R||=6.212e-11
# [step 6/10] converged in 2 iters, ||R||=1.049e-09
# [step 5/10] converged in 2 iters, ||R||=7.852e-10
# [step 6/10] converged in 2 iters, ||R||=1.906e-10
# [step 5/10] converged in 2 iters, ||R||=1.623e-11
# [step 6/10] converged in 2 iters, ||R||=6.598e-11
# [step 6/10] converged in 2 iters, ||R||=2.927e-10
# [step 5/10] converged in 2 iters, ||R||=4.238e-11
# [step 5/10] converged in 2 iters, ||R||=4.361e-11
# [step 6/10] converged in 2 iters, ||R||=1.098e-10
# [step 6/10] converged in 2 iters, ||R||=6.055e-11
# [step 5/10] converged in 2 iters, ||R||=1.527e-10
# [step 6/10] converged in 2 iters, ||R||=6.294e-11
# [step 7/10] converged in 2 iters, ||R||=1.076e-09
# [step 6/10] converged in 2 iters, ||R||=8.036e-10
# [step 7/10] converged in 2 iters, ||R||=1.929e-10
# [step 6/10] converged in 2 iters, ||R||=1.632e-11
# [step 7/10] converged in 2 iters, ||R||=6.684e-11
# [step 6/10] converged in 2 iters, ||R||=4.313e-11
# [step 7/10] converged in 2 iters, ||R||=3.008e-10
# [step 6/10] converged in 2 iters, ||R||=4.366e-11
# [step 7/10] converged in 2 iters, ||R||=1.110e-10
# [step 7/10] converged in 2 iters, ||R||=6.351e-11
# [step 7/10] converged in 2 iters, ||R||=6.119e-11
# [step 6/10] converged in 2 iters, ||R||=1.546e-10
# [step 8/10] converged in 2 iters, ||R||=1.102e-09
# [step 7/10] converged in 2 iters, ||R||=8.225e-10
# [step 8/10] converged in 2 iters, ||R||=1.952e-10
# [step 7/10] converged in 2 iters, ||R||=1.635e-11
# [step 8/10] converged in 2 iters, ||R||=6.826e-11
# [step 7/10] converged in 2 iters, ||R||=4.336e-11
# [step 8/10] converged in 2 iters, ||R||=3.087e-10
# [step 7/10] converged in 2 iters, ||R||=4.376e-11
# [step 8/10] converged in 2 iters, ||R||=1.122e-10
# [step 8/10] converged in 2 iters, ||R||=6.439e-11
# [step 8/10] converged in 2 iters, ||R||=6.187e-11
# [step 7/10] converged in 2 iters, ||R||=1.567e-10
# [step 9/10] converged in 2 iters, ||R||=1.131e-09
# [step 8/10] converged in 2 iters, ||R||=8.426e-10
# [step 9/10] converged in 2 iters, ||R||=1.975e-10
# [step 8/10] converged in 2 iters, ||R||=1.667e-11
# [step 9/10] converged in 2 iters, ||R||=6.923e-11
# [step 8/10] converged in 2 iters, ||R||=4.383e-11
# [step 9/10] converged in 2 iters, ||R||=3.172e-10
# [step 8/10] converged in 2 iters, ||R||=4.393e-11
# [step 9/10] converged in 2 iters, ||R||=1.136e-10
# [step 9/10] converged in 2 iters, ||R||=6.510e-11
# [step 9/10] converged in 2 iters, ||R||=6.239e-11
# [step 8/10] converged in 2 iters, ||R||=1.587e-10
# [step 10/10] converged in 2 iters, ||R||=1.159e-09
#   Sample 769: max displacement=9.560e-03
# [step 9/10] converged in 2 iters, ||R||=8.627e-10
# [step 10/10] converged in 2 iters, ||R||=1.996e-10
# Completed 770/1000 samples
#   Sample 770: max displacement=8.264e-03
# [step 9/10] converged in 2 iters, ||R||=1.666e-11
# [step 10/10] converged in 2 iters, ||R||=7.011e-11
#   Sample 771: max displacement=5.724e-03
# [step 10/10] converged in 2 iters, ||R||=3.262e-10
#   Sample 772: max displacement=8.890e-03
# [step 9/10] converged in 2 iters, ||R||=4.460e-11
# [step 10/10] converged in 2 iters, ||R||=1.153e-10
#   Sample 773: max displacement=7.720e-03
# [step 9/10] converged in 2 iters, ||R||=4.367e-11
# [step 10/10] converged in 2 iters, ||R||=6.306e-11
#   Sample 774: max displacement=6.694e-03
# [step 10/10] converged in 2 iters, ||R||=6.579e-11
#   Sample 775: max displacement=4.881e-03
# [step 9/10] converged in 2 iters, ||R||=1.606e-10
# [step 1/10] converged in 2 iters, ||R||=1.555e-09
# [step 10/10] converged in 2 iters, ||R||=8.837e-10
#   Sample 776: max displacement=9.291e-03
# [step 10/10] converged in 2 iters, ||R||=1.685e-11
#   Sample 777: max displacement=3.636e-03
# [step 1/10] converged in 2 iters, ||R||=2.075e-10
# [step 1/10] converged in 2 iters, ||R||=2.349e-10
# [step 1/10] converged in 2 iters, ||R||=1.331e-10
# [step 10/10] converged in 2 iters, ||R||=4.542e-11
#   Sample 778: max displacement=4.847e-03
# [step 1/10] converged in 2 iters, ||R||=3.519e-11
# [step 10/10] converged in 2 iters, ||R||=4.358e-11
#   Sample 779: max displacement=6.291e-03
# [step 1/10] converged in 2 iters, ||R||=1.234e-09
# [step 1/10] converged in 2 iters, ||R||=1.067e-11
# [step 10/10] converged in 2 iters, ||R||=1.627e-10
# Completed 780/1000 samples
#   Sample 780: max displacement=5.771e-03
# [step 2/10] converged in 2 iters, ||R||=1.596e-09
# [step 1/10] converged in 2 iters, ||R||=1.960e-10
# [step 1/10] converged in 2 iters, ||R||=7.896e-11
# [step 2/10] converged in 2 iters, ||R||=2.124e-10
# [step 2/10] converged in 2 iters, ||R||=2.391e-10
# [step 2/10] converged in 2 iters, ||R||=1.354e-10
# [step 1/10] converged in 2 iters, ||R||=5.934e-11
# [step 2/10] converged in 2 iters, ||R||=3.541e-11
# [step 1/10] converged in 2 iters, ||R||=6.769e-11
# [step 2/10] converged in 2 iters, ||R||=1.266e-09
# [step 2/10] converged in 2 iters, ||R||=1.074e-11
# [step 1/10] converged in 2 iters, ||R||=9.774e-11
# [step 3/10] converged in 2 iters, ||R||=1.639e-09
# [step 2/10] converged in 2 iters, ||R||=1.993e-10
# [step 3/10] converged in 2 iters, ||R||=2.180e-10
# [step 2/10] converged in 2 iters, ||R||=7.962e-11
# [step 3/10] converged in 2 iters, ||R||=2.427e-10
# [step 3/10] converged in 2 iters, ||R||=1.377e-10
# [step 3/10] converged in 2 iters, ||R||=3.570e-11
# [step 2/10] converged in 2 iters, ||R||=6.028e-11
# [step 2/10] converged in 2 iters, ||R||=6.911e-11
# [step 3/10] converged in 2 iters, ||R||=1.300e-09
# [step 3/10] converged in 2 iters, ||R||=1.077e-11
# [step 2/10] converged in 2 iters, ||R||=9.889e-11
# [step 4/10] converged in 2 iters, ||R||=1.684e-09
# [step 3/10] converged in 2 iters, ||R||=2.027e-10
# [step 3/10] converged in 2 iters, ||R||=8.122e-11
# [step 4/10] converged in 2 iters, ||R||=2.236e-10
# [step 4/10] converged in 2 iters, ||R||=2.465e-10
# [step 4/10] converged in 2 iters, ||R||=1.405e-10
# [step 4/10] converged in 2 iters, ||R||=3.638e-11
# [step 3/10] converged in 2 iters, ||R||=6.122e-11
# [step 3/10] converged in 2 iters, ||R||=7.017e-11
# [step 4/10] converged in 2 iters, ||R||=1.334e-09
# [step 4/10] converged in 2 iters, ||R||=1.072e-11
# [step 3/10] converged in 2 iters, ||R||=9.986e-11
# [step 5/10] converged in 2 iters, ||R||=1.730e-09
# [step 4/10] converged in 2 iters, ||R||=2.058e-10
# [step 4/10] converged in 2 iters, ||R||=8.257e-11
# [step 5/10] converged in 2 iters, ||R||=2.292e-10
# [step 5/10] converged in 2 iters, ||R||=2.507e-10
# [step 5/10] converged in 2 iters, ||R||=1.426e-10
# [step 5/10] converged in 2 iters, ||R||=3.673e-11
# [step 4/10] converged in 2 iters, ||R||=6.234e-11
# [step 4/10] converged in 2 iters, ||R||=7.118e-11
# [step 5/10] converged in 2 iters, ||R||=1.370e-09
# [step 5/10] converged in 2 iters, ||R||=1.086e-11
# [step 4/10] converged in 2 iters, ||R||=1.010e-10
# [step 6/10] converged in 2 iters, ||R||=1.777e-09
# [step 5/10] converged in 2 iters, ||R||=2.096e-10
# [step 5/10] converged in 2 iters, ||R||=8.366e-11
# [step 6/10] converged in 2 iters, ||R||=2.351e-10
# [step 6/10] converged in 2 iters, ||R||=2.550e-10
# [step 6/10] converged in 2 iters, ||R||=1.452e-10
# [step 5/10] converged in 2 iters, ||R||=6.360e-11
# [step 6/10] converged in 2 iters, ||R||=3.704e-11
# [step 5/10] converged in 2 iters, ||R||=7.210e-11
# [step 6/10] converged in 2 iters, ||R||=1.406e-09
# [step 6/10] converged in 2 iters, ||R||=1.094e-11
# [step 5/10] converged in 2 iters, ||R||=1.028e-10
# [step 7/10] converged in 2 iters, ||R||=1.826e-09
# [step 6/10] converged in 2 iters, ||R||=2.126e-10
# [step 6/10] converged in 2 iters, ||R||=8.421e-11
# [step 7/10] converged in 2 iters, ||R||=2.413e-10
# [step 7/10] converged in 2 iters, ||R||=2.588e-10
# [step 7/10] converged in 2 iters, ||R||=1.476e-10
# [step 6/10] converged in 2 iters, ||R||=6.441e-11
# [step 7/10] converged in 2 iters, ||R||=3.752e-11
# [step 6/10] converged in 2 iters, ||R||=7.320e-11
# [step 7/10] converged in 2 iters, ||R||=1.445e-09
# [step 7/10] converged in 2 iters, ||R||=1.065e-11
# [step 6/10] converged in 2 iters, ||R||=1.042e-10
# [step 8/10] converged in 2 iters, ||R||=1.876e-09
# [step 7/10] converged in 2 iters, ||R||=2.167e-10
# [step 7/10] converged in 2 iters, ||R||=8.627e-11
# [step 8/10] converged in 2 iters, ||R||=2.473e-10
# [step 8/10] converged in 2 iters, ||R||=2.636e-10
# [step 8/10] converged in 2 iters, ||R||=1.503e-10
# [step 7/10] converged in 2 iters, ||R||=6.545e-11
# [step 8/10] converged in 2 iters, ||R||=3.787e-11
# [step 7/10] converged in 2 iters, ||R||=7.424e-11
# [step 8/10] converged in 2 iters, ||R||=1.484e-09
# [step 8/10] converged in 2 iters, ||R||=1.115e-11
# [step 7/10] converged in 2 iters, ||R||=1.056e-10
# [step 9/10] converged in 2 iters, ||R||=1.928e-09
# [step 8/10] converged in 2 iters, ||R||=2.200e-10
# [step 8/10] converged in 2 iters, ||R||=8.721e-11
# [step 9/10] converged in 2 iters, ||R||=2.537e-10
# [step 9/10] converged in 2 iters, ||R||=2.677e-10
# [step 9/10] converged in 2 iters, ||R||=1.530e-10
# [step 9/10] converged in 2 iters, ||R||=3.869e-11
# [step 8/10] converged in 2 iters, ||R||=6.676e-11
# [step 8/10] converged in 2 iters, ||R||=7.541e-11
# [step 9/10] converged in 2 iters, ||R||=1.524e-09
# [step 9/10] converged in 2 iters, ||R||=1.116e-11
# [step 8/10] converged in 2 iters, ||R||=1.070e-10
# [step 10/10] converged in 2 iters, ||R||=1.982e-09
#   Sample 781: max displacement=1.076e-02
# [step 9/10] converged in 2 iters, ||R||=2.237e-10
# [step 9/10] converged in 2 iters, ||R||=8.821e-11
# [step 10/10] converged in 2 iters, ||R||=2.603e-10
#   Sample 782: max displacement=8.722e-03
# [step 10/10] converged in 2 iters, ||R||=2.719e-10
#   Sample 783: max displacement=6.613e-03
# [step 10/10] converged in 2 iters, ||R||=1.556e-10
#   Sample 784: max displacement=6.985e-03
# [step 9/10] converged in 2 iters, ||R||=6.786e-11
# [step 9/10] converged in 2 iters, ||R||=7.701e-11
# [step 10/10] converged in 2 iters, ||R||=3.870e-11
#   Sample 785: max displacement=5.237e-03
# [step 10/10] converged in 2 iters, ||R||=1.566e-09
#   Sample 787: max displacement=9.856e-03
# [step 10/10] converged in 2 iters, ||R||=1.123e-11
#   Sample 786: max displacement=3.554e-03
# ...
# [     0] (epoch=1367) Pi=-4.438476e-02  U=4.321416e-02  W=8.759892e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1368) Pi=-4.450651e-02  U=4.094137e-02  W=8.544787e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1369) Pi=-4.449818e-02  U=4.106358e-02  W=8.556175e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1370) Pi=-4.444181e-02  U=4.769908e-02  W=9.214089e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1371) Pi=-4.447751e-02  U=4.306743e-02  W=8.754494e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1372) Pi=-4.446288e-02  U=4.213414e-02  W=8.659702e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1373) Pi=-4.454273e-02  U=4.550630e-02  W=9.004903e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1374) Pi=-4.451353e-02  U=4.199098e-02  W=8.650451e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1375) Pi=-4.450721e-02  U=4.119599e-02  W=8.570319e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1376) Pi=-4.456006e-02  U=4.607985e-02  W=9.063991e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1377) Pi=-4.432599e-02  U=3.839059e-02  W=8.271658e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1378) Pi=-4.452461e-02  U=4.265197e-02  W=8.717658e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1379) Pi=-4.456006e-02  U=4.521234e-02  W=8.977240e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1380) Pi=-4.457304e-02  U=4.651494e-02  W=9.108797e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1381) Pi=-4.439607e-02  U=3.953570e-02  W=8.393177e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1382) Pi=-4.454286e-02  U=4.342557e-02  W=8.796843e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1383) Pi=-4.456363e-02  U=4.232511e-02  W=8.688873e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1384) Pi=-4.446075e-02  U=4.831306e-02  W=9.277381e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1385) Pi=-4.441916e-02  U=3.930986e-02  W=8.372902e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1386) Pi=-4.457177e-02  U=4.577748e-02  W=9.034925e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1387) Pi=-4.456653e-02  U=4.543299e-02  W=8.999952e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1388) Pi=-4.438197e-02  U=4.879621e-02  W=9.317818e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1389) Pi=-4.439643e-02  U=3.959262e-02  W=8.398905e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1390) Pi=-4.457787e-02  U=4.561896e-02  W=9.019683e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1391) Pi=-4.458164e-02  U=4.378120e-02  W=8.836284e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1392) Pi=-4.456817e-02  U=4.312729e-02  W=8.769546e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1393) Pi=-4.456824e-02  U=4.471298e-02  W=8.928122e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1394) Pi=-4.454910e-02  U=4.292072e-02  W=8.746982e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1395) Pi=-4.459677e-02  U=4.377411e-02  W=8.837088e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1396) Pi=-4.452698e-02  U=4.127633e-02  W=8.580332e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1397) Pi=-4.452548e-02  U=4.143039e-02  W=8.595587e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1398) Pi=-4.454410e-02  U=4.686586e-02  W=9.140996e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1399) Pi=-4.450519e-02  U=4.611529e-02  W=9.062049e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1400) Pi=-4.454185e-02  U=4.177557e-02  W=8.631742e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1401) Pi=-4.460370e-02  U=4.306534e-02  W=8.766904e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1402) Pi=-4.454479e-02  U=4.739463e-02  W=9.193942e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1403) Pi=-4.456455e-02  U=4.642960e-02  W=9.099415e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1404) Pi=-4.453089e-02  U=4.176033e-02  W=8.629122e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1405) Pi=-4.444190e-02  U=4.050574e-02  W=8.494765e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1406) Pi=-4.457648e-02  U=4.211301e-02  W=8.668949e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1407) Pi=-4.453823e-02  U=4.205721e-02  W=8.659544e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1408) Pi=-4.447927e-02  U=4.668945e-02  W=9.116872e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1409) Pi=-4.457886e-02  U=4.476934e-02  W=8.934820e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1410) Pi=-4.455172e-02  U=4.158130e-02  W=8.613302e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1411) Pi=-4.453803e-02  U=4.093982e-02  W=8.547785e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1412) Pi=-4.453424e-02  U=4.630636e-02  W=9.084060e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1413) Pi=-4.450575e-02  U=4.797976e-02  W=9.248551e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1414) Pi=-4.456145e-02  U=4.243777e-02  W=8.699922e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1415) Pi=-4.451160e-02  U=4.376839e-02  W=8.827998e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1416) Pi=-4.458972e-02  U=4.434649e-02  W=8.893621e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1417) Pi=-4.458094e-02  U=4.333570e-02  W=8.791663e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1418) Pi=-4.456006e-02  U=4.529361e-02  W=8.985367e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1419) Pi=-4.459769e-02  U=4.378267e-02  W=8.838037e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1420) Pi=-4.459676e-02  U=4.529981e-02  W=8.989657e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1421) Pi=-4.457991e-02  U=4.350668e-02  W=8.808659e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1422) Pi=-4.443996e-02  U=3.969772e-02  W=8.413768e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1423) Pi=-4.455200e-02  U=4.554024e-02  W=9.009223e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1424) Pi=-4.442968e-02  U=4.004496e-02  W=8.447465e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1425) Pi=-4.442172e-02  U=4.094587e-02  W=8.536759e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1426) Pi=-4.455892e-02  U=4.683511e-02  W=9.139403e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1427) Pi=-4.456334e-02  U=4.545869e-02  W=9.002203e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1428) Pi=-4.457433e-02  U=4.356098e-02  W=8.813531e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1429) Pi=-4.442389e-02  U=4.012948e-02  W=8.455336e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1430) Pi=-4.447115e-02  U=4.028248e-02  W=8.475363e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1431) Pi=-4.457041e-02  U=4.375799e-02  W=8.832840e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1432) Pi=-4.412521e-02  U=3.663526e-02  W=8.076047e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1433) Pi=-4.452911e-02  U=4.158948e-02  W=8.611859e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1434) Pi=-4.454922e-02  U=4.612589e-02  W=9.067511e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1435) Pi=-4.454930e-02  U=4.160363e-02  W=8.615293e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1436) Pi=-4.455508e-02  U=4.451293e-02  W=8.906801e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1437) Pi=-4.449744e-02  U=4.594778e-02  W=9.044522e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1438) Pi=-4.447128e-02  U=4.101652e-02  W=8.548780e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1439) Pi=-4.443800e-02  U=4.114841e-02  W=8.558641e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1440) Pi=-4.436601e-02  U=4.059060e-02  W=8.495661e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1441) Pi=-4.441307e-02  U=4.115921e-02  W=8.557229e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1442) Pi=-4.434814e-02  U=3.882135e-02  W=8.316948e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1443) Pi=-4.453928e-02  U=4.664417e-02  W=9.118345e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1444) Pi=-4.424686e-02  U=3.807725e-02  W=8.232411e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1445) Pi=-4.454578e-02  U=4.259377e-02  W=8.713955e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1446) Pi=-4.452357e-02  U=4.565353e-02  W=9.017710e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1447) Pi=-4.457995e-02  U=4.586214e-02  W=9.044209e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1448) Pi=-4.367178e-02  U=3.497141e-02  W=7.864320e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.996
# [     0] (epoch=1449) Pi=-4.456370e-02  U=4.506475e-02  W=8.962845e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1450) Pi=-4.454824e-02  U=4.523589e-02  W=8.978412e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1451) Pi=-4.444969e-02  U=4.087926e-02  W=8.532895e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1452) Pi=-4.446232e-02  U=4.009401e-02  W=8.455633e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1453) Pi=-4.456240e-02  U=4.399431e-02  W=8.855671e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1454) Pi=-4.450314e-02  U=4.152591e-02  W=8.602905e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1455) Pi=-4.442292e-02  U=3.986557e-02  W=8.428849e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1456) Pi=-4.437556e-02  U=3.887184e-02  W=8.324740e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1457) Pi=-4.444583e-02  U=4.122762e-02  W=8.567344e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1458) Pi=-4.450184e-02  U=4.156678e-02  W=8.606862e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1459) Pi=-4.452931e-02  U=4.484016e-02  W=8.936947e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1460) Pi=-4.444517e-02  U=4.049994e-02  W=8.494511e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1461) Pi=-4.449394e-02  U=4.136905e-02  W=8.586299e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1462) Pi=-4.456310e-02  U=4.535726e-02  W=8.992036e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1463) Pi=-4.438601e-02  U=4.799037e-02  W=9.237638e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1464) Pi=-4.416892e-02  U=3.726395e-02  W=8.143287e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1465) Pi=-4.445599e-02  U=3.934038e-02  W=8.379637e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1466) Pi=-4.444254e-02  U=4.143263e-02  W=8.587517e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1467) Pi=-4.449513e-02  U=4.673230e-02  W=9.122743e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1468) Pi=-4.459712e-02  U=4.321491e-02  W=8.781203e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1469) Pi=-4.450392e-02  U=4.832552e-02  W=9.282944e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1470) Pi=-4.455764e-02  U=4.222961e-02  W=8.678725e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1471) Pi=-4.450466e-02  U=4.133336e-02  W=8.583802e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1472) Pi=-4.459421e-02  U=4.386110e-02  W=8.845531e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1473) Pi=-4.452024e-02  U=4.273703e-02  W=8.725727e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1474) Pi=-4.440037e-02  U=3.997155e-02  W=8.437192e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1475) Pi=-4.456332e-02  U=4.465831e-02  W=8.922163e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1476) Pi=-4.452728e-02  U=4.717109e-02  W=9.169836e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1477) Pi=-4.433027e-02  U=4.005405e-02  W=8.438431e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1478) Pi=-4.458974e-02  U=4.492181e-02  W=8.951154e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1479) Pi=-4.454540e-02  U=4.217929e-02  W=8.672469e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1480) Pi=-4.432573e-02  U=3.854196e-02  W=8.286769e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1481) Pi=-4.457053e-02  U=4.552843e-02  W=9.009895e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1482) Pi=-4.424608e-02  U=3.913655e-02  W=8.338263e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1483) Pi=-4.453558e-02  U=4.676609e-02  W=9.130167e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1484) Pi=-4.439697e-02  U=4.083776e-02  W=8.523472e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1485) Pi=-4.458475e-02  U=4.473087e-02  W=8.931562e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1486) Pi=-4.456959e-02  U=4.442348e-02  W=8.899307e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1487) Pi=-4.460360e-02  U=4.463915e-02  W=8.924275e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1488) Pi=-4.458983e-02  U=4.319295e-02  W=8.778278e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1489) Pi=-4.444879e-02  U=4.292779e-02  W=8.737659e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1490) Pi=-4.459549e-02  U=4.359261e-02  W=8.818810e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1491) Pi=-4.457042e-02  U=4.486240e-02  W=8.943282e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1492) Pi=-4.454701e-02  U=4.535563e-02  W=8.990264e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1493) Pi=-4.448499e-02  U=4.205444e-02  W=8.653942e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1494) Pi=-4.436310e-02  U=3.950888e-02  W=8.387198e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1495) Pi=-4.451573e-02  U=4.223077e-02  W=8.674651e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1496) Pi=-4.458023e-02  U=4.388371e-02  W=8.846394e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1497) Pi=-4.449876e-02  U=4.161731e-02  W=8.611607e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1498) Pi=-4.441286e-02  U=4.877327e-02  W=9.318613e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994
# [     0] (epoch=1499) Pi=-4.456380e-02  U=4.354899e-02  W=8.811279e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.995
# [     0] (epoch=1500) Pi=-4.444888e-02  U=4.807153e-02  W=9.252041e-02  E=1000.0  nu=0.300  Force=9.483  detF@GP=0.994

# %%
import numpy as np
from matplotlib import pyplot as plt

fig, axes = plt.subplots(2, 3, figsize=(16, 9))
summary_rows = []

for ax, (geometry, material) in zip(axes.flat, CASES):
    name = case_name(geometry, material)
    metrics_path = os.path.join(RESULTS_DIR, name, "metrics_history.json")
    if not os.path.exists(metrics_path):
        ax.set_title(f"{name}\n(no data yet)")
        continue

    with open(metrics_path) as f:
        history = _json.load(f)
    if not history:
        ax.set_title(f"{name}\n(empty history)")
        continue

    epochs = [h["epoch"] for h in history]
    l2u = [h["mean_rel_L2_u"] for h in history]
    l2v = [h["mean_rel_L2_v"] for h in history]

    ax.semilogy(epochs, l2u, label="Rel L2(u)")
    ax.semilogy(epochs, l2v, label="Rel L2(v)")
    ax.set_title(f"{name} (epoch {epochs[-1]}/{EPOCHS})")
    ax.set_xlabel("epoch")
    ax.legend()
    ax.grid(True, alpha=0.3)

    summary_rows.append((name, epochs[-1], l2u[-1], l2v[-1]))

plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "all_cases_loss_curves.png"), dpi=150)
plt.show()

print(f"{'case':<20s} {'last epoch':>10s} {'RelL2(u)':>12s} {'RelL2(v)':>12s}")
for name, ep, u, v in summary_rows:
    print(f"{name:<20s} {ep:>10d} {u:>12.3e} {v:>12.3e}")

# %% [markdown]
# ## Cell 8 - Zip and download all results (optional)
#
# Results already live on Google Drive (`RESULTS_DIR`), so this is just a
# convenience if you want a local zip copy too -- not required for safety.

# %%
import shutil
from google.colab import files

archive_path = shutil.make_archive('/content/pfem_results', 'zip', RESULTS_DIR)
print(f"Archived {RESULTS_DIR} -> {archive_path}")
files.download(archive_path)
