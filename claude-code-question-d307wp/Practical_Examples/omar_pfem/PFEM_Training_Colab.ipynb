# %% [markdown]
# # PFEM/Transolver Training -- B1 x {NH, MR, AB}, B2 x {NH, MR, AB}
# **Colab GPU runtime required (Runtime > Change runtime type > GPU)**
#
# Runs the full PFEM pipeline (Wang et al., "Pretrain finite element method",
# JMPS 214 (2026) 106682) for all 6 benchmark cases: B1 (unit square,
# top-edge traction, fixed bottom) and B2 (quarter ring, R_in=1/R_out=2,
# internal pressure, symmetry BCs), each with three hyperelastic energy
# densities (Neo-Hookean, Mooney-Rivlin, Arruda-Boyce).
#
# This notebook runs in two phases, per the advisor's guidance that blindly
# training all 6 cases for 10000 epochs each is neither necessary nor
# efficient (validation was too sparse to tell, and the best result so far
# came around epoch 1000, with later epochs possibly hurt by optimization
# instability or the LR schedule rather than genuine underfitting):
#
# - **Phase 1 (screening)**: on one representative case (B1 x Neo-Hookean),
#   screen a few real mini-batch sizes (a true parallel batch over samples
#   sharing the same mesh, not gradient accumulation) for a short, fixed
#   epoch budget, validating every 25-50 epochs and tracking wall-clock
#   time, GPU peak memory, and optimizer steps alongside validation error.
#   The most promising batch size is then continued to a larger epoch
#   budget with early stopping (on validation error, not a fixed epoch
#   count) -- producing a small comparison table and one concrete,
#   automatically-chosen training protocol.
# - **Phase 2 (the other 5 cases)**: that same protocol (batch size,
#   validation cadence, early-stopping patience) is applied uniformly to
#   the remaining cases -- no manual per-case tuning, per the advisor's
#   explicit goal of "a robust and efficient procedure," not one-off tuning.
#
# For each case, the pipeline is:
# 1. Generate a FEM ground-truth dataset (Total-Lagrangian Newton-Raphson,
#    Q4 elements) via `omar_pfem/data/data_generate_B{1,2}.py`, parallelized
#    across CPU cores -- skipped if the dataset already exists on disk.
# 2. Convert it to the Transolver NPZ format via `convert_B{1,2}_quad.py`.
# 3. Train a physics-informed Transolver (`omar_pfem/train_B{1,2}.py`) by
#    minimizing total potential energy (Pi = U - W, no labeled-data loss),
#    with n_hidden=256, n_layers=4, n_heads=8, slice_num=128 (PFEM's own
#    architecture defaults) -- batch size and epoch budget now come from
#    Phase 1 instead of being fixed in advance.
#
# **Scale note**: PFEM's own reference script defaults to ntrain=800,
# ntest=200 -- generating that many samples per case is still a real cost
# independent of the training-protocol question above:
# - **Data generation**: measured on a 4-core CPU at the reference 21x21 Q4
#   mesh, generating each sample (a 10-step Newton-Raphson solve) took
#   ~8s/sample with 4 parallel workers -- so a 1000-sample dataset
#   (NTRAIN+NTEST) is roughly 2-2.5 CPU-hours per case, ~14 hours for all 6.
#   Colab's own CPU allocation may differ from this benchmark.
#
# Given that, this will likely span multiple Colab sessions. That's expected
# and handled: every case checkpoints its model periodically and **resumes
# from its own latest checkpoint** if this notebook is re-run (whether
# because the runtime disconnected mid-case, or because you're continuing
# across multiple sessions) -- so re-running `Runtime > Run all` after a
# disconnect always makes forward progress instead of starting over.
# Finished cases (`model_final.pt` or an `EARLY_STOPPED` marker on disk) are
# skipped entirely, finished datasets (an NPZ already on disk) are never
# regenerated, and a completed Phase 1 (a saved `training_protocol.json`)
# is never re-screened.
#
# If you'd rather trade fidelity for a faster full pass, lower
# `TARGET_SAMPLES` in the config cell below -- everything else adapts
# automatically.

# %% [markdown]
# ## Cell 1 - Install dependencies
#
# Colab's preinstalled `torch` already has CUDA support -- it is deliberately
# NOT reinstalled here (a bare `pip install torch` risks silently replacing
# it with a CPU-only wheel). Only the packages PFEM's Transolver model and
# this pipeline actually need on top of Colab's base image are installed:
# `einops`/`timm` (Transolver architecture), `h5py` (FEM dataset storage),
# `jax` (autodiff-derived PK1 stress/tangent for Mooney-Rivlin/Arruda-Boyce
# in the FEM generator -- CPU-only use, small dense tensors, no GPU needed).
#
# Uses `{sys.executable} -m pip` rather than bare `!pip` -- on some Colab
# runtimes the shell's `pip` has been observed to resolve to a different
# Python than the notebook kernel itself, which makes packages "install
# successfully" yet still fail to import.

# %%
import sys
# !{sys.executable} -m pip install -q einops timm h5py jax tqdm
print('Done - continue to Cell 2')
# Out:
# Done - continue to Cell 2

# %% [markdown]
# ## Cell 2 - Clone the repo
#
# If the repo is private, paste a GitHub personal access token as the value
# of `GITHUB_TOKEN` below. Leave it as `""` if the repo is public -- never
# type a literal `<TOKEN>` placeholder into the URL (`<`/`>` are bash
# redirection operators and will break the clone before git even runs).
#
# Always does a clean re-clone of the CODE (removes any previous
# `/content/OMAR` first) so a broken partial clone can't linger -- but
# generated datasets and results live elsewhere (local disk / Google Drive,
# see Cells 3-4), **outside** the cloned repo, so re-cloning never discards
# training progress.

# %%
import os
import shutil
import sys

os.chdir('/content')

GITHUB_TOKEN = ""  # <-- paste your token between the quotes if the repo is private; leave "" if public
BRANCH = "claude/claude-code-question-d307wp"
REPO_URL = (f"https://{GITHUB_TOKEN}@github.com/suhibamro/omar.git" if GITHUB_TOKEN
            else "https://github.com/suhibamro/omar.git")

if os.path.exists('/content/OMAR'):
    shutil.rmtree('/content/OMAR')

# !git clone -b {BRANCH} {REPO_URL} /content/OMAR

WORK_DIR = '/content/OMAR/Practical_Examples'
if not os.path.isdir(WORK_DIR):
    raise SystemExit(
        'ERROR: clone failed -- /content/OMAR/Practical_Examples does not exist.\n'
        'Scroll up to the "git clone" output above for the actual error.\n'
        'Common cause: the repo is private and GITHUB_TOKEN is still "".'
    )

os.chdir(WORK_DIR)
sys.path.insert(0, WORK_DIR)

pfem_ok = os.path.isdir(os.path.join(WORK_DIR, 'omar_pfem'))
if pfem_ok:
    print('Clone OK: omar_pfem/ found under Practical_Examples/.')
else:
    raise SystemExit('ERROR: omar_pfem/ not found -- clone looks incomplete or wrong branch.')

import torch
print(f'torch {torch.__version__} | cuda available={torch.cuda.is_available()}', end=' ')
if torch.cuda.is_available():
    print(f'| device={torch.cuda.get_device_name(0)}')
else:
    print()
    print('WARNING: no GPU detected -- go to Runtime > Change runtime type and select a GPU, '
          'then Runtime > Restart session and re-run from Cell 1.')
# Out:
# Cloning into '/content/OMAR'...
# remote: Enumerating objects: 357, done.
# remote: Counting objects: 100% (357/357), done.
# remote: Compressing objects: 100% (247/247), done.
# remote: Total 357 (delta 213), reused 245 (delta 106), pack-reused 0 (from 0)
# Receiving objects: 100% (357/357), 1.05 MiB | 10.67 MiB/s, done.
# Resolving deltas: 100% (213/213), done.
# Clone OK: omar_pfem/ found under Practical_Examples/.
# torch 2.11.0+cu128 | cuda available=True | device=NVIDIA A100-SXM4-80GB

# %% [markdown]
# ## Cell 3 - Mount Google Drive (persist training progress across full disconnects)
#
# Colab's local `/content` disk only survives a *reconnect* to the same
# runtime -- it does NOT survive a full runtime reset/reassignment (hitting
# the session time limit, "Factory reset runtime", or Colab reclaiming an
# idle VM). Given this pipeline can realistically run for many hours to
# multiple days across several sessions, that's a real risk for the
# expensive part of the run: GPU training checkpoints.
#
# So results (`RESULTS_DIR` below) are written to Google Drive, which
# survives any of the above. Every artifact this notebook produces ends up
# under `RESULTS_DIR`: checkpoints, metrics, images, execution logs,
# per-case manifests, and (see `ensure_dataset` in Cell 5) an archived copy
# of each case's final NPZ dataset. Nothing that took real compute to
# produce is left only on ephemeral local disk.
#
# The one deliberate exception is the *scratch* work of FEM data generation
# itself (`DATA_DIR`): the raw generation loop stays on local `/content`
# disk, because Drive is FUSE-mounted (each file write is a network
# round-trip) and the generator does hundreds of small sequential writes per
# case -- on Drive that overhead would meaningfully slow down generation.
# The moment generation finishes, its *result* (the converted NPZ) is copied
# to `DATASETS_ARCHIVE_DIR` on Drive, so only the intermediate scratch work
# is local and disposable, never the result. If prompted, click through the
# Google auth flow -- this notebook will not work with your data without
# that authorization.

# %%
from google.colab import drive
drive.mount('/content/drive')
print('Drive mounted -- continue to Cell 4')
# Out:
# Mounted at /content/drive
# Drive mounted -- continue to Cell 4

# %% [markdown]
# ## Cell 4 - Configuration
#
# Edit these to trade off dataset/training scale against wall-clock time.
# `TARGET_SAMPLES` splits into `NTRAIN`/`NTEST` the same way as PFEM's own
# reference script (800/200 by default -- lower this if a full 1000-sample
# FEM generation pass is too slow on your Colab CPU allocation).
#
# The screening-study settings (`SCREEN_*`) control Phase 1 only; its
# outcome (`training_protocol.json`) then drives every case in Phase 2, so
# there's nothing to configure per-case beyond dataset scale.

# %%
import os

DATA_DIR = '/content/pfem_data'                                  # local disk: fast scratch during generation
RESULTS_DIR = '/content/drive/MyDrive/pfem_run/results'          # Google Drive: durable, holds every result
DATASETS_ARCHIVE_DIR = os.path.join(RESULTS_DIR, 'datasets')     # Google Drive: durable copy of each case's NPZ
os.makedirs(DATA_DIR, exist_ok=True)
os.makedirs(RESULTS_DIR, exist_ok=True)
os.makedirs(DATASETS_ARCHIVE_DIR, exist_ok=True)

# ---- Dataset scale (PFEM's own reference: ntrain=800, ntest=200) ----
NTRAIN = 800
NTEST = 200
TARGET_SAMPLES = NTRAIN + NTEST   # total FEM samples generated per case

# ---- Mesh resolution (PFEM's own reference default for the beam case) ----
MESH_N = 21                      # Nx=Ny=21 for B1; Ntheta=Nr=21 for B2
GAUSS_POINTS_PER_ELEMENT = 4     # fixed by the FEM formulation: full 2x2 Gauss quadrature

# Reference cost of one native FE solve at this mesh resolution (10-step
# Newton-Raphson, 4-core CPU) -- the baseline the advisor asked training
# cost per sample to be compared against. Re-measure and update this if
# MESH_N changes.
NATIVE_FEM_SECONDS_PER_SAMPLE = 8.0

N_WORKERS = os.cpu_count()

# ---- Phase 1 (screening study on B1 x Neo-Hookean) ----
# Per the advisor's follow-up ("why stop at 16? continue until GPU memory
# becomes limiting or quality deteriorates"), the sweep no longer stops at
# a fixed upper size: screening_study.py tries these in ascending order
# and stops itself (reporting status="OOM" for the size that failed) the
# moment one doesn't fit on the GPU, rather than crashing the whole run --
# see screening_study.py's Phase 1 loop and is_oom_error().
SCREEN_BATCH_SIZES = "4,8,16,32,64,128,256"   # comma string, passed straight to screening_study.py
SCREEN_EPOCHS = 400             # short, fixed budget per batch size (advisor: ~250-500)
VALIDATE_EVERY = 25             # advisor: validate every 25-50 epochs
CONTINUE_EPOCHS = 2000          # upper bound for the winning config (advisor: ~1000-2000)
EARLY_STOP_PATIENCE = 8         # validation events with no improvement before stopping
EARLY_STOP_MIN_DELTA = 1e-4

GEOMETRIES = ["B1", "B2"]
MATERIALS = ["neo_hookean", "mooney_rivlin", "arruda_boyce"]
CASES = [(g, m) for g in GEOMETRIES for m in MATERIALS]
SCREENING_CASE = ("B1", "neo_hookean")

print(f'CPU workers for data generation: {N_WORKERS}')
print(f'Target samples/case: {TARGET_SAMPLES} (ntrain={NTRAIN}, ntest={NTEST})')
print(f'Screening case: {SCREENING_CASE}, batch_sizes={SCREEN_BATCH_SIZES}, '
      f'screen_epochs={SCREEN_EPOCHS}, validate_every={VALIDATE_EVERY}')
print(f'Cases: {CASES}')
# Out:
# CPU workers for data generation: 12
# Target samples/case: 1000 (ntrain=800, ntest=200)
# Screening case: ('B1', 'neo_hookean'), batch_sizes=4,8,16,32,64,128,256, screen_epochs=400, validate_every=25
# Cases: [('B1', 'neo_hookean'), ('B1', 'mooney_rivlin'), ('B1', 'arruda_boyce'), ('B2', 'neo_hookean'), ('B2', 'mooney_rivlin'), ('B2', 'arruda_boyce')]

# %% [markdown]
# ## Cell 5 - Helpers: everything this notebook produces is saved to Drive
#
# Five helpers, all built around one rule -- **nothing that took real compute
# to produce is ever left only on ephemeral local disk**:
#
# - `run_streaming(cmd, cwd, log_path=None)` runs a command as a subprocess
#   and prints its stdout live (unbuffered, `python -u`). When `log_path` is
#   given (always, below -- pointed at `RESULTS_DIR`), every line is *also*
#   appended to that file, so the full raw execution log of every data
#   generation, conversion, screening, and training step survives a Colab
#   disconnect even if the notebook's own output pane does not.
# - `ensure_dataset(geometry, material)` generates a case's FEM dataset on
#   fast local scratch disk, then immediately archives the resulting NPZ to
#   `DATASETS_ARCHIVE_DIR` on Drive; on a later call (even in a fresh
#   session, after local disk was wiped) it restores the archived copy
#   instead of regenerating from scratch. Data generation is CPU-hours of
#   work -- it is treated exactly as durably as training results, not as
#   disposable scratch.
# - `count_trainable_params()` instantiates the Transolver model with the
#   exact architecture hyperparameters Cell 7 trains with, and returns its
#   trainable-parameter count -- computed once, from the real model, not a
#   hand-typed number that could drift out of sync with the architecture.
# - `mesh_facts(mesh_n)` returns the exact node/element/integration-point
#   counts for a given mesh resolution (structured Q4 grid, full 2x2 Gauss
#   quadrature), so the discretization reported anywhere is always derived
#   from `MESH_N`, never hand-typed.
# - `write_case_manifest(name, geometry, material)` writes one always-current
#   JSON per case (`RESULTS_DIR/{case}/case_manifest.json`) collecting every
#   quantity needed for the written report in one place: architecture,
#   trainable parameters, discretization, dataset size, the training
#   protocol used, and (once available) final validation error, wall-clock
#   time, optimizer steps, and peak GPU memory (allocated and reserved).
#   Overwritten every time a case's status is checked, so it always reflects
#   the current state, including for a case that is still mid-training.
# - `save_completion_snapshot(name)` additionally writes one permanent,
#   timestamped record (`RESULTS_DIR/completed_runs/{case}_{timestamp}.json`)
#   the first time a case is found finished -- never overwritten, so it is
#   an audit trail of exactly when each case completed, independent of the
#   always-current manifest above.

# %%
import subprocess
import time
import json as _json
import datetime as _dt

def run_streaming(cmd, cwd=None, log_path=None):
    """Runs cmd, streaming its stdout live. If log_path is given (always,
    below), every line is also appended there -- log_path should point at
    a Drive-backed (RESULTS_DIR) location so the raw log survives a
    disconnect even when the notebook's own cell output does not."""
    print(f"$ {' '.join(cmd)}")
    log_f = open(log_path, "a") if log_path else None
    if log_f:
        log_f.write(f"\n===== {_dt.datetime.now().isoformat()} =====\n$ {' '.join(cmd)}\n")
        log_f.flush()
    proc = subprocess.Popen(
        cmd, cwd=cwd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT,
        text=True, bufsize=1
    )
    for line in proc.stdout:
        print(line, end='')
        if log_f:
            log_f.write(line)
    proc.wait()
    if log_f:
        log_f.write(f"[exit code {proc.returncode}] {_dt.datetime.now().isoformat()}\n")
        log_f.close()
    if proc.returncode != 0:
        raise RuntimeError(f"Command failed (exit {proc.returncode}): {' '.join(cmd)}")


def case_name(geometry, material):
    return f"{geometry}_{material}"


def case_log_path(name, step):
    log_dir = os.path.join(RESULTS_DIR, name, "logs")
    os.makedirs(log_dir, exist_ok=True)
    return os.path.join(log_dir, f"{step}.log")


_TRAINABLE_PARAMS_CACHE = {}

def count_trainable_params():
    """Instantiates the exact Transolver architecture Cell 7 trains with
    and counts its trainable parameters -- computed once and cached, so
    the number reported in every manifest is guaranteed to match the real
    model, not a hand-typed constant that could silently drift."""
    if "n" in _TRAINABLE_PARAMS_CACHE:
        return _TRAINABLE_PARAMS_CACHE["n"]
    from omar_pfem.model.Transolver_Irregular_Mesh import Model
    m = Model(space_dim=2, n_layers=4, n_hidden=256, dropout=0.1, n_head=8,
              Time_Input=False, mlp_ratio=2, fun_dim=4, out_dim=2,
              slice_num=128, ref=16, unified_pos=0)
    n = sum(p.numel() for p in m.parameters() if p.requires_grad)
    _TRAINABLE_PARAMS_CACHE["n"] = n
    return n


def mesh_facts(mesh_n):
    """Structured Q4 mesh facts for an mesh_n x mesh_n node grid (B1's
    Nx=Ny or B2's Ntheta=Nr), full 2x2 Gauss quadrature."""
    n_nodes = mesh_n * mesh_n
    n_elements = (mesh_n - 1) * (mesh_n - 1)
    return {
        "nodes_per_side": mesh_n,
        "n_nodes": n_nodes,
        "n_elements": n_elements,
        "gauss_points_per_element": GAUSS_POINTS_PER_ELEMENT,
        "integration_points_per_sample": n_elements * GAUSS_POINTS_PER_ELEMENT,
    }


def write_case_manifest(name, geometry, material):
    """Writes/overwrites one always-current, comprehensive record for a
    case: architecture, discretization, dataset size, protocol, and (once
    available) final training outcome -- every quantity needed for the
    written report, in one place, always in sync with the real run."""
    out_dir = os.path.join(RESULTS_DIR, name)
    os.makedirs(out_dir, exist_ok=True)

    if os.path.exists(os.path.join(out_dir, "EARLY_STOPPED")):
        status = "EARLY_STOPPED"
    elif os.path.exists(os.path.join(out_dir, "model_final.pt")):
        status = "model_final"
    else:
        status = "in_progress"

    metrics_path = os.path.join(out_dir, "metrics_history.json")
    history = []
    if os.path.exists(metrics_path):
        with open(metrics_path) as f:
            history = _json.load(f)
    best_meta = {}
    best_meta_path = os.path.join(out_dir, "best_checkpoint_meta.json")
    if os.path.exists(best_meta_path):
        with open(best_meta_path) as f:
            best_meta = _json.load(f)

    inference_stats = {}
    inference_path = os.path.join(out_dir, "inference_latency.json")
    if os.path.exists(inference_path):
        with open(inference_path) as f:
            inference_stats = _json.load(f)

    final_rec = history[-1] if history else None
    protocol_used = PROTOCOL if "PROTOCOL" in globals() else None

    manifest = {
        "case": name,
        "geometry": geometry,
        "material": material,
        "status": status,
        "last_updated": _dt.datetime.now().isoformat(),
        "architecture": {
            "n_layers": 4, "n_hidden": 256, "n_heads": 8, "mlp_ratio": 2,
            "dropout": 0.1, "slice_num": 128, "fun_dim": 4,
            "trainable_parameters": count_trainable_params(),
        },
        "discretization": mesh_facts(MESH_N),
        "dataset": {
            "ntrain": NTRAIN, "ntest": NTEST, "total_samples": NTRAIN + NTEST,
            "native_fem_seconds_per_sample": NATIVE_FEM_SECONDS_PER_SAMPLE,
        },
        "protocol_used": protocol_used,
        "training_outcome": {
            "best_val_error": best_meta.get("best_val_error"),
            "best_epoch": best_meta.get("best_epoch"),
            "final_epoch": final_rec["epoch"] if final_rec else None,
            "num_validation_events": len(history),
            "total_wall_clock_s": final_rec["cumulative_wall_clock_s"] if final_rec else None,
            "total_opt_steps": final_rec["opt_steps"] if final_rec else None,
            "gpu_peak_mem_allocated_mb": max((r.get("gpu_peak_mem_mb", 0.0) for r in history), default=None),
            "gpu_peak_mem_reserved_mb": max((r.get("gpu_peak_mem_reserved_mb", 0.0) for r in history), default=None),
            # Whole-device usage (torch.cuda.mem_get_info(), nvidia-smi-like)
            # -- distinct from the two PyTorch-allocator figures above, which
            # exclude the CUDA context's own fixed overhead and any other
            # process sharing the GPU. See train_B1.py/train_B2.py.
            "gpu_peak_mem_device_mb": max((r.get("gpu_peak_mem_device_mb", 0.0) for r in history), default=None),
            "gpu_device_total_mb": max((r.get("gpu_device_total_mb", 0.0) for r in history), default=None),
            "training_cost_per_sample_epoch_s": (
                final_rec["cumulative_wall_clock_s"] / (final_rec["epoch"] * NTRAIN)
                if final_rec else None
            ),
            # Pure forward-pass latency (batch_size=1, no backward pass, no
            # energy assembly) measured once at the end of training -- see
            # benchmark_inference_latency_Q4 in train_B1.py/train_B2.py.
            "inference_ms_per_sample": inference_stats.get("inference_ms_per_sample"),
        },
    }
    manifest_path = os.path.join(out_dir, "case_manifest.json")
    with open(manifest_path, "w") as f:
        _json.dump(manifest, f, indent=2)
    return manifest


def save_completion_snapshot(name):
    """Writes one permanent timestamped summary the first time `name` is
    found finished. Safe to call every time a case is checked (skips if a
    snapshot already exists), so re-running the notebook never spams
    duplicates for cases that were already done."""
    out_dir = os.path.join(RESULTS_DIR, name)
    if os.path.exists(os.path.join(out_dir, "EARLY_STOPPED")):
        status = "EARLY_STOPPED"
    elif os.path.exists(os.path.join(out_dir, "model_final.pt")):
        status = "model_final"
    else:
        return  # not finished yet -- nothing permanent to record

    metrics_path = os.path.join(out_dir, "metrics_history.json")
    if not os.path.exists(metrics_path):
        return

    snap_dir = os.path.join(RESULTS_DIR, "completed_runs")
    os.makedirs(snap_dir, exist_ok=True)
    if any(f.startswith(name + "_") for f in os.listdir(snap_dir)):
        return  # already have a permanent record for this case

    with open(metrics_path) as f:
        history = _json.load(f)
    best_meta = {}
    best_meta_path = os.path.join(out_dir, "best_checkpoint_meta.json")
    if os.path.exists(best_meta_path):
        with open(best_meta_path) as f:
            best_meta = _json.load(f)

    timestamp = _dt.datetime.now().strftime("%Y%m%d_%H%M%S")
    snapshot = {
        "case": name,
        "status": status,
        "snapshot_taken_at": timestamp,
        "best_checkpoint": best_meta,
        "last_validation_record": history[-1] if history else None,
        "num_validation_events": len(history),
    }
    snap_path = os.path.join(snap_dir, f"{name}_{timestamp}.json")
    with open(snap_path, "w") as f:
        _json.dump(snapshot, f, indent=2)
    print(f"[{name}] permanent completion snapshot saved -> {snap_path}")


def ensure_dataset(geometry, material):
    """Generates + converts the FEM dataset for one case on fast local
    scratch disk if it isn't already there, then archives the result to
    Drive (DATASETS_ARCHIVE_DIR) so it survives a full disk wipe. On a
    later call (this session or a fresh one), restores the archived copy
    instead of regenerating. Returns the (local) NPZ path."""
    name = case_name(geometry, material)
    h5_dir = os.path.join(DATA_DIR, f"fem_{name}")
    npz_dir = os.path.join(DATA_DIR, f"npz_{name}")
    npz_path = os.path.join(npz_dir, "hyperelastic_training_data_q4.npz")
    archive_path = os.path.join(DATASETS_ARCHIVE_DIR, name, "hyperelastic_training_data_q4.npz")

    if os.path.exists(npz_path):
        print(f"[{name}] NPZ dataset already exists locally at {npz_path}, skipping generation.")
        return npz_path

    if os.path.exists(archive_path):
        print(f"[{name}] Restoring archived NPZ dataset from Drive ({archive_path}) -- no regeneration needed.")
        os.makedirs(npz_dir, exist_ok=True)
        shutil.copy2(archive_path, npz_path)
        return npz_path

    t0 = time.time()
    if geometry == "B1":
        gen_module = "omar_pfem.data.data_generate_B1"
        gen_args = ["--Nx", str(MESH_N), "--Ny", str(MESH_N)]
        conv_module = "omar_pfem.data.convert_B1_quad"
    else:
        gen_module = "omar_pfem.data.data_generate_B2"
        gen_args = ["--Ntheta", str(MESH_N), "--Nr", str(MESH_N)]
        conv_module = "omar_pfem.data.convert_B2_quad"

    run_streaming([
        sys.executable, "-u", "-m", gen_module,
        "--num_index", "1", "--num_samples", str(TARGET_SAMPLES),
        *gen_args, "--material", material,
        "--n_workers", str(N_WORKERS),
        "--out_dir", h5_dir,
    ], cwd=WORK_DIR, log_path=case_log_path(name, "data_generation"))

    run_streaming([
        sys.executable, "-u", "-m", conv_module,
        "--h5_dir", h5_dir, "--out_dir", npz_dir,
    ], cwd=WORK_DIR, log_path=case_log_path(name, "npz_conversion"))

    os.makedirs(os.path.dirname(archive_path), exist_ok=True)
    shutil.copy2(npz_path, archive_path)
    print(f"[{name}] Dataset ready after {time.time()-t0:.0f}s -- archived to Drive at {archive_path}")
    return npz_path

# %% [markdown]
# ## Cell 6 - Phase 1: screening study (B1 x Neo-Hookean)
#
# Runs `omar_pfem/screening_study.py`, which:
# 1. Trains B1 x Neo-Hookean at each of `SCREEN_BATCH_SIZES` for a short,
#    fixed `SCREEN_EPOCHS` budget, validating every `VALIDATE_EVERY` epochs
#    and logging validation error, wall-clock time, GPU peak memory, and
#    optimizer-step count for each.
# 2. Picks the batch size with the lowest best validation error and
#    continues *that same run* (resumed from its own screening checkpoint)
#    to `CONTINUE_EPOCHS`, this time with early stopping
#    (`EARLY_STOP_PATIENCE` validation events with no improvement).
#
# `--final_out_dir` points the continuation directly at this case's real
# results directory, so it doubles as B1 x Neo-Hookean's actual training run
# -- Cell 7's main loop later finds it already done and skips it, no
# duplicated work.
#
# If a previous run already finished Phase 1 (`training_protocol.json`
# exists), this cell loads that instead of re-screening -- so a Colab
# disconnect never repeats the screening study itself. To force a fresh
# Phase 1 run (e.g. to regenerate a comparison table that was lost before
# the Drive-persistence fix below), delete `training_protocol.json` from
# `RESULTS_DIR` before running this cell -- Phase 2 will then write into
# B1 x Neo-Hookean's real results directory exactly as it always has, so a
# fresh run replaces whatever was there before.
#
# The screening runs (`bs4`/`bs8`/`bs16` + the comparison table) are written
# under `RESULTS_DIR` (Google Drive), not `DATA_DIR` (local disk): unlike the
# FEM datasets, this comparison took real training compute to produce, so it
# belongs with the other things that must survive a disconnect, not with the
# data that's cheap to regenerate.

# %%
protocol_path = os.path.join(RESULTS_DIR, "training_protocol.json")

if os.path.exists(protocol_path):
    with open(protocol_path) as f:
        PROTOCOL = _json.load(f)
    print(f"Phase 1 already completed -- loaded protocol from {protocol_path}:")
    print(_json.dumps(PROTOCOL, indent=2))
else:
    screen_geometry, screen_material = SCREENING_CASE
    screen_npz_path = ensure_dataset(screen_geometry, screen_material)
    screen_out_dir = os.path.join(RESULTS_DIR, "screening_" + case_name(*SCREENING_CASE))
    final_out_dir = os.path.join(RESULTS_DIR, case_name(*SCREENING_CASE))

    run_streaming([
        sys.executable, "-u", "-m", "omar_pfem.screening_study",
        "--path", screen_npz_path,
        "--geometry", screen_geometry, "--material", screen_material,
        "--ntrain", str(NTRAIN), "--ntest", str(NTEST),
        "--batch_sizes", SCREEN_BATCH_SIZES,
        "--screen_epochs", str(SCREEN_EPOCHS),
        "--validate_every", str(VALIDATE_EVERY),
        "--continue_epochs", str(CONTINUE_EPOCHS),
        "--continue_early_stop_patience", str(EARLY_STOP_PATIENCE),
        "--continue_early_stop_min_delta", str(EARLY_STOP_MIN_DELTA),
        "--final_out_dir", final_out_dir,
        "--out_dir", screen_out_dir,
    ], cwd=WORK_DIR, log_path=case_log_path(case_name(*SCREENING_CASE), "screening_driver"))

    with open(os.path.join(screen_out_dir, "screening_summary.json")) as f:
        screening_rows = _json.load(f)
    # Only rows that actually completed the screening budget (status=="OK")
    # are eligible to win -- a row with status=="OOM" or "FAILED" can still
    # have some validation history (it may have crashed after several
    # validation events, not on the very first one), so filtering on
    # best_val_error alone is not enough to exclude it. screening_study.py's
    # own Phase 2 selection uses this same filter internally.
    ok_rows = [r for r in screening_rows if r.get("status") == "OK" and r["best_val_error"] is not None]
    oom_rows = [r for r in screening_rows if r.get("status") == "OOM"]
    if oom_rows:
        print(f"Batch size(s) that ran out of GPU memory during screening: "
              f"{[r['batch_size'] for r in oom_rows]} -- excluded from winner selection.")
    winner_bs = min(ok_rows, key=lambda r: r["best_val_error"])["batch_size"]

    PROTOCOL = {
        "batch_size": winner_bs,
        "validate_every": VALIDATE_EVERY,
        "early_stop_patience": EARLY_STOP_PATIENCE,
        "early_stop_min_delta": EARLY_STOP_MIN_DELTA,
        "epochs": CONTINUE_EPOCHS,
    }
    with open(protocol_path, "w") as f:
        _json.dump(PROTOCOL, f, indent=2)

    print("\nPhase 1 done. Screening summary:")
    with open(os.path.join(screen_out_dir, "screening_summary.md")) as f:
        print(f.read())
    print(f"\nChosen protocol (saved to {protocol_path}):")
    print(_json.dumps(PROTOCOL, indent=2))

write_case_manifest(case_name(*SCREENING_CASE), *SCREENING_CASE)
save_completion_snapshot(case_name(*SCREENING_CASE))
# Out:
# Phase 1 already completed -- loaded protocol from /content/drive/MyDrive/pfem_run/results/training_protocol.json:
# {
#   "batch_size": 8,
#   "validate_every": 25,
#   "early_stop_patience": 8,
#   "early_stop_min_delta": 0.0001,
#   "epochs": 2000
# }
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
extended_screen_npz_path = ensure_dataset(*SCREENING_CASE)
extended_screen_out_dir = os.path.join(RESULTS_DIR, "screening_extended_" + case_name(*SCREENING_CASE))
os.makedirs(extended_screen_out_dir, exist_ok=True)

if os.path.exists(os.path.join(extended_screen_out_dir, "screening_summary.json")):
    print(f"Extended screening already done -> {extended_screen_out_dir}, skipping.")
else:
    run_streaming([
        sys.executable, "-u", "-m", "omar_pfem.screening_study",
        "--path", extended_screen_npz_path,
        "--geometry", SCREENING_CASE[0], "--material", SCREENING_CASE[1],
        "--ntrain", str(NTRAIN), "--ntest", str(NTEST),
        "--batch_sizes", SCREEN_BATCH_SIZES,
        "--screen_epochs", str(SCREEN_EPOCHS),
        "--validate_every", str(VALIDATE_EVERY),
        "--continue_epochs", str(CONTINUE_EPOCHS),
        "--continue_early_stop_patience", str(EARLY_STOP_PATIENCE),
        "--continue_early_stop_min_delta", str(EARLY_STOP_MIN_DELTA),
        "--out_dir", extended_screen_out_dir,
    ], cwd=WORK_DIR, log_path=os.path.join(extended_screen_out_dir, "run.log"))

with open(os.path.join(extended_screen_out_dir, "screening_summary.md")) as f:
    print(f.read())
# Out:
# [B1_neo_hookean] Restoring archived NPZ dataset from Drive (/content/drive/MyDrive/pfem_run/results/datasets/B1_neo_hookean/hyperelastic_training_data_q4.npz) -- no regeneration needed.
# Extended screening already done -> /content/drive/MyDrive/pfem_run/results/screening_extended_B1_neo_hookean, skipping.
# # Batch-size screening summary
#
# | batch_size | status | epochs_run | opt_steps | wall_clock_s | gpu_peak_mem_mb | gpu_peak_mem_reserved_mb | gpu_peak_mem_device_mb | gpu_device_total_mb | cost_per_sample_epoch_ms | final_val_error | best_val_error | best_epoch |
# |---|---|---|---|---|---|---|---|---|---|---|---|---|
# | 4 | OK | 400 | 80000 | 3015 | 239.6 | 463.5 | 1013 | 8.509e+04 | 9.422 | 0.1265 | 0.1076 | 375 |
# | 8 | OK | 400 | 40000 | 1533 | 425 | 679.5 | 1227 | 8.509e+04 | 4.792 | 0.1469 | 0.09734 | 375 | **(winner)**
# | 16 | OK | 400 | 20000 | 871.7 | 813.5 | 1078 | 1627 | 8.509e+04 | 2.724 | 0.1858 | 0.1489 | 325 |
# | 32 | OK | 400 | 10000 | 567.7 | 1581 | 2005 | 2554 | 8.509e+04 | 1.774 | 0.3455 | 0.3455 | 400 |
# | 64 | OK | 400 | 5200 | 421.5 | 3094 | 3811 | 4360 | 8.509e+04 | 1.317 | 0.6263 | 0.5849 | 300 |
# | 128 | OK | 400 | 2800 | 341.9 | 6129 | 7298 | 7847 | 8.509e+04 | 1.068 | 1.058 | 0.5848 | 375 |
# | 256 | OK | 400 | 1600 | 299.2 | 1.218e+04 | 1.436e+04 | 1.491e+04 | 8.509e+04 | 0.9349 | 0.6026 | 0.6026 | 400 |
#
# Winner: batch_size=8 (lowest best_val_error)

# %% [markdown]
# ## Cell 7 - Run the remaining 5 cases with the chosen protocol
#
# Applies `PROTOCOL` from Phase 1 uniformly -- no per-case tuning, per the
# advisor's explicit goal. B1 x Neo-Hookean is skipped here since Phase 1
# already trained it (its `model_final.pt`/`EARLY_STOPPED` marker is
# already in place).
#
# For every case (skipped or freshly trained), `write_case_manifest` updates
# `RESULTS_DIR/{case}/case_manifest.json` with the current architecture,
# discretization, dataset size, protocol, and training outcome, and the full
# raw training log is appended to `RESULTS_DIR/{case}/logs/training.log`.

# %%
def run_one_case(geometry, material):
    name = case_name(geometry, material)
    out_dir = os.path.join(RESULTS_DIR, name)

    print(f"\n{'='*80}\n===== CASE: {name} =====\n{'='*80}")

    if os.path.exists(os.path.join(out_dir, "model_final.pt")) or \
       os.path.exists(os.path.join(out_dir, "EARLY_STOPPED")):
        print(f"[{name}] already fully trained (model_final.pt or EARLY_STOPPED found), skipping.")
        write_case_manifest(name, geometry, material)
        save_completion_snapshot(name)
        return

    npz_path = ensure_dataset(geometry, material)

    train_module = "omar_pfem.train_B1" if geometry == "B1" else "omar_pfem.train_B2"
    t1 = time.time()
    run_streaming([
        sys.executable, "-u", "-m", train_module,
        "--path", npz_path,
        "--material", material,
        "--ntrain", str(NTRAIN), "--ntest", str(NTEST),
        "--epochs", str(PROTOCOL["epochs"]),
        "--batch_size", str(PROTOCOL["batch_size"]),
        "--validate_every", str(PROTOCOL["validate_every"]),
        "--save_every", str(PROTOCOL["validate_every"]),
        "--early_stop_patience", str(PROTOCOL["early_stop_patience"]),
        "--early_stop_min_delta", str(PROTOCOL["early_stop_min_delta"]),
        "--print_every", "999999",
        "--out_dir", out_dir,
    ], cwd=WORK_DIR, log_path=case_log_path(name, "training"))
    print(f"[{name}] Training finished after {time.time()-t1:.0f}s")
    write_case_manifest(name, geometry, material)
    save_completion_snapshot(name)


for geometry, material in CASES:
    if (geometry, material) == SCREENING_CASE:
        continue  # already trained as part of Phase 1
    run_one_case(geometry, material)

print("\nAll cases either completed or already were -- see per-case status above.")
# Out:
# ================================================================================
# ===== CASE: B1_mooney_rivlin =====
# ================================================================================
# [B1_mooney_rivlin] already fully trained (model_final.pt or EARLY_STOPPED found), skipping.
#
# ================================================================================
# ===== CASE: B1_arruda_boyce =====
# ================================================================================
# [B1_arruda_boyce] already fully trained (model_final.pt or EARLY_STOPPED found), skipping.
#
# ================================================================================
# ===== CASE: B2_neo_hookean =====
# ================================================================================
# [B2_neo_hookean] already fully trained (model_final.pt or EARLY_STOPPED found), skipping.
#
# ================================================================================
# ===== CASE: B2_mooney_rivlin =====
# ================================================================================
# [B2_mooney_rivlin] already fully trained (model_final.pt or EARLY_STOPPED found), skipping.
#
# ================================================================================
# ===== CASE: B2_arruda_boyce =====
# ================================================================================
# [B2_arruda_boyce] already fully trained (model_final.pt or EARLY_STOPPED found), skipping.
#
# All cases either completed or already were -- see per-case status above.

# %%
MEMORY_PROFILE_EPOCHS = 3   # short + throwaway -- just enough to observe real peak GPU memory
memory_profile_dir = os.path.join(RESULTS_DIR, "memory_profile_reruns")
os.makedirs(memory_profile_dir, exist_ok=True)

for geometry, material in CASES:
    name = case_name(geometry, material)
    case_dir = os.path.join(RESULTS_DIR, name)
    checkpoint = os.path.join(case_dir, "model_best.pt")
    if not os.path.exists(checkpoint):
        checkpoint = os.path.join(case_dir, "model_final.pt")
    if not os.path.exists(checkpoint):
        print(f"[{name}] no checkpoint yet -- run Cell 6/7 first, skipping backfill.")
        continue
    dataset_path = os.path.join(DATASETS_ARCHIVE_DIR, name, "hyperelastic_training_data_q4.npz")

    # 1) Inference latency: safe, additive, no retraining.
    inf_json = os.path.join(case_dir, "inference_latency.json")
    if os.path.exists(inf_json):
        print(f"[{name}] inference_latency.json already present, skipping.")
    else:
        inf_log_dir = os.path.join(case_dir, "logs")
        os.makedirs(inf_log_dir, exist_ok=True)
        run_streaming([
            sys.executable, "-u", "-m", "omar_pfem.measure_inference_latency",
            "--geometry", geometry, "--material", material,
            "--checkpoint", checkpoint, "--dataset", dataset_path,
            "--ntrain", str(NTRAIN), "--ntest", str(NTEST),
            "--out_json", inf_json,
        ], cwd=WORK_DIR, log_path=os.path.join(inf_log_dir, "inference_latency_backfill.log"))

    # 2) GPU memory profile: short, throwaway training run to a SEPARATE
    # directory -- never touches the real case's model_final.pt/metrics.
    profile_out = os.path.join(memory_profile_dir, name)
    os.makedirs(profile_out, exist_ok=True)
    profile_metrics = os.path.join(profile_out, "metrics_history.json")
    if os.path.exists(profile_metrics):
        print(f"[{name}] memory profile already exists -> {profile_metrics}, skipping.")
        continue
    train_module = "omar_pfem.train_B1" if geometry == "B1" else "omar_pfem.train_B2"
    run_streaming([
        sys.executable, "-u", "-m", train_module,
        "--path", dataset_path, "--material", material,
        "--ntrain", str(NTRAIN), "--ntest", str(NTEST),
        "--batch_size", str(PROTOCOL["batch_size"]),
        "--epochs", str(MEMORY_PROFILE_EPOCHS), "--validate_every", "1", "--save_every", "1",
        "--early_stop_patience", "0", "--print_every", "999999",
        "--out_dir", profile_out,
    ], cwd=WORK_DIR, log_path=os.path.join(profile_out, "run.log"))

print("\nBackfill pass complete.")
print("Inference latency: written directly into each case's own directory (RESULTS_DIR/{case}/inference_latency.json).")
print(f"GPU memory profiles ({MEMORY_PROFILE_EPOCHS}-epoch throwaway runs at the real batch size): "
      f"see {memory_profile_dir}/{{case}}/metrics_history.json for gpu_peak_mem_device_mb / gpu_device_total_mb.")
# Out:
# $ /usr/bin/python3 -u -m omar_pfem.measure_inference_latency --geometry B1 --material neo_hookean --checkpoint /content/drive/MyDrive/pfem_run/results/B1_neo_hookean/model_best.pt --dataset /content/drive/MyDrive/pfem_run/results/datasets/B1_neo_hookean/hyperelastic_training_data_q4.npz --ntrain 800 --ntest 200 --out_json /content/drive/MyDrive/pfem_run/results/B1_neo_hookean/inference_latency.json
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Loaded checkpoint: /content/drive/MyDrive/pfem_run/results/B1_neo_hookean/model_best.pt
#
# Material statistics in training set:
#   E: mean=1000.00, std=200.00, min=142.41, max=1750.16
#   nu: mean=0.3000, std=0.0483, min=0.2000, max=0.4000
#
# Force statistics in training set:
#   Force: mean=4.994, std=2.023, min=0.002, max=12.228
#   Nodes with force: 16800 / 352800
# Test samples: 200
# Inference latency: 4.5858 ms/sample (batch_size=1, 200 repeats, device=cuda)
# Written to /content/drive/MyDrive/pfem_run/results/B1_neo_hookean/inference_latency.json
# $ /usr/bin/python3 -u -m omar_pfem.train_B1 --path /content/drive/MyDrive/pfem_run/results/datasets/B1_neo_hookean/hyperelastic_training_data_q4.npz --material neo_hookean --ntrain 800 --ntest 200 --batch_size 8 --epochs 3 --validate_every 1 --save_every 1 --early_stop_patience 0 --print_every 999999 --out_dir /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_neo_hookean
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Using dataset: /content/drive/MyDrive/pfem_run/results/datasets/B1_neo_hookean/hyperelastic_training_data_q4.npz
# Output dir: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_neo_hookean
# Material: neo_hookean
# fun_dim=4  (3->[E,nu,fy], 4->[E,nu,fx,fy])
#
# Material statistics in training set:
#   E: mean=1000.00, std=200.00, min=142.41, max=1750.16
#   nu: mean=0.3000, std=0.0483, min=0.2000, max=0.4000
#
# Force statistics in training set:
#   Force: mean=4.994, std=2.023, min=0.002, max=12.228
#   Nodes with force: 16800 / 352800
# Loaded Q4 dataset: ntrain=800, ntest=200
# Sample 0: nodes=441, quads=400, E_mean=1000.0, nu_mean=0.300, Force_mean=9.483, Force_nodes=21
# Sample 1: nodes=441, quads=400, E_mean=1000.0, nu_mean=0.300, Force_mean=5.556, Force_nodes=21
# Sample 2: nodes=441, quads=400, E_mean=1000.0, nu_mean=0.299, Force_mean=6.843, Force_nodes=21
# [Saved] mesh_materials_forces_train_sample0_sid0.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_neo_hookean
# [Saved] mesh_materials_forces_test_sample0_sid0.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_neo_hookean
# [batch     0] (epoch=1) Pi_mean=4.605431e+01  E=1000.0  nu=0.300  Force=5.667  detF@GP=0.818  opt_steps=1
# [viz sid=571 tag=epoch1] Pi=1.105e+00  U=1.199e+00  W=9.427e-02
#                 L2(u)=5.012e+01  L2(v)=6.038e+00  Linf(|e|)=6.920e-02
#                 E_mean=1000.0  nu_mean=0.300  Force_mean=3.716
#                 det(F)@GP: mean=0.976, min=0.971, max=0.979
# ===== Test-set Evaluation =====
# Mean Rel L2(u): 5.311e+01
# Mean Rel L2(v): 5.180e+00
# Std  Rel L2(u): 2.238e+01
# Std  Rel L2(v): 3.742e+00
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 5.033
# Val error (mean of Rel L2 u,v): 2.915e+01  epoch_time=4.75s  cum_wall_clock=4.8s  gpu_peak_mem_allocated=425.0MB  gpu_peak_mem_reserved=562.0MB  gpu_peak_mem_device=1109.3MB/85094.8MB  opt_steps=100
# [best] New best val_error=2.915e+01 at epoch=1 -> model_best.pt
# [batch     0] (epoch=2) Pi_mean=1.059522e+00  E=1000.0  nu=0.300  Force=5.667  detF@GP=0.976  opt_steps=101
# [viz sid=84 tag=epoch2] Pi=6.758e-01  U=5.277e-01  W=-1.482e-01
#                 L2(u)=1.271e+01  L2(v)=6.349e+00  Linf(|e|)=3.548e-02
#                 E_mean=1000.0  nu_mean=0.299  Force_mean=5.384
#                 det(F)@GP: mean=1.026, min=1.025, max=1.028
# ===== Test-set Evaluation =====
# Mean Rel L2(u): 1.454e+01
# Mean Rel L2(v): 7.647e+00
# Std  Rel L2(u): 6.157e+00
# Std  Rel L2(v): 4.006e+00
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 5.033
# Val error (mean of Rel L2 u,v): 1.109e+01  epoch_time=3.86s  cum_wall_clock=8.6s  gpu_peak_mem_allocated=425.0MB  gpu_peak_mem_reserved=679.5MB  gpu_peak_mem_device=1226.8MB/85094.8MB  opt_steps=200
# [best] New best val_error=1.109e+01 at epoch=2 -> model_best.pt
# [batch     0] (epoch=3) Pi_mean=6.892902e-01  E=1000.0  nu=0.300  Force=5.667  detF@GP=1.026  opt_steps=201
# [viz sid=661 tag=epoch3] Pi=5.395e-01  U=4.622e-01  W=-7.728e-02
#                 L2(u)=1.564e+01  L2(v)=9.110e+00  Linf(|e|)=3.317e-02
#                 E_mean=1000.0  nu_mean=0.300  Force_mean=3.103
#                 det(F)@GP: mean=1.024, min=1.023, max=1.025
# ===== Test-set Evaluation =====
# Mean Rel L2(u): 1.658e+01
# Mean Rel L2(v): 7.006e+00
# Std  Rel L2(u): 7.011e+00
# Std  Rel L2(v): 3.618e+00
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 5.033
# Val error (mean of Rel L2 u,v): 1.179e+01  epoch_time=3.90s  cum_wall_clock=12.5s  gpu_peak_mem_allocated=425.0MB  gpu_peak_mem_reserved=679.5MB  gpu_peak_mem_device=1226.8MB/85094.8MB  opt_steps=300
#
# ================================================================================
# FINAL RESULTS:
# Mean Rel L2(u): 1.658e+01
# Mean Rel L2(v): 7.006e+00
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 5.033
# Best val_error: 1.109e+01 at epoch 2 (see model_best.pt)
# Total wall clock: 12.5s over 300 optimizer steps (batch_size=8)
# ================================================================================
# Inference latency (batch_size=1, forward pass only, no training): 4.7894 ms/sample (averaged over 200 calls, cuda)
#
# Training completed!
# Results saved to: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_neo_hookean
# $ /usr/bin/python3 -u -m omar_pfem.measure_inference_latency --geometry B1 --material mooney_rivlin --checkpoint /content/drive/MyDrive/pfem_run/results/B1_mooney_rivlin/model_best.pt --dataset /content/drive/MyDrive/pfem_run/results/datasets/B1_mooney_rivlin/hyperelastic_training_data_q4.npz --ntrain 800 --ntest 200 --out_json /content/drive/MyDrive/pfem_run/results/B1_mooney_rivlin/inference_latency.json
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Loaded checkpoint: /content/drive/MyDrive/pfem_run/results/B1_mooney_rivlin/model_best.pt
#
# Material statistics in training set:
#   E: mean=1000.00, std=200.00, min=142.41, max=1750.16
#   nu: mean=0.3000, std=0.0483, min=0.2000, max=0.4000
#
# Force statistics in training set:
#   Force: mean=4.994, std=2.023, min=0.002, max=12.228
#   Nodes with force: 16800 / 352800
# Test samples: 200
# Inference latency: 4.6931 ms/sample (batch_size=1, 200 repeats, device=cuda)
# Written to /content/drive/MyDrive/pfem_run/results/B1_mooney_rivlin/inference_latency.json
# $ /usr/bin/python3 -u -m omar_pfem.train_B1 --path /content/drive/MyDrive/pfem_run/results/datasets/B1_mooney_rivlin/hyperelastic_training_data_q4.npz --material mooney_rivlin --ntrain 800 --ntest 200 --batch_size 8 --epochs 3 --validate_every 1 --save_every 1 --early_stop_patience 0 --print_every 999999 --out_dir /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_mooney_rivlin
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Using dataset: /content/drive/MyDrive/pfem_run/results/datasets/B1_mooney_rivlin/hyperelastic_training_data_q4.npz
# Output dir: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_mooney_rivlin
# Material: mooney_rivlin
# fun_dim=4  (3->[E,nu,fy], 4->[E,nu,fx,fy])
#
# Material statistics in training set:
#   E: mean=1000.00, std=200.00, min=142.41, max=1750.16
#   nu: mean=0.3000, std=0.0483, min=0.2000, max=0.4000
#
# Force statistics in training set:
#   Force: mean=4.994, std=2.023, min=0.002, max=12.228
#   Nodes with force: 16800 / 352800
# Loaded Q4 dataset: ntrain=800, ntest=200
# Sample 0: nodes=441, quads=400, E_mean=1000.0, nu_mean=0.300, Force_mean=9.483, Force_nodes=21
# Sample 1: nodes=441, quads=400, E_mean=1000.0, nu_mean=0.300, Force_mean=5.556, Force_nodes=21
# Sample 2: nodes=441, quads=400, E_mean=1000.0, nu_mean=0.299, Force_mean=6.843, Force_nodes=21
# [Saved] mesh_materials_forces_train_sample0_sid0.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_mooney_rivlin
# [Saved] mesh_materials_forces_test_sample0_sid0.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_mooney_rivlin
# [batch     0] (epoch=1) Pi_mean=6.762318e+01  E=1000.0  nu=0.300  Force=5.667  detF@GP=0.818  opt_steps=1
# [viz sid=571 tag=epoch1] Pi=3.130e+00  U=2.938e+00  W=-1.926e-01
#                 L2(u)=4.132e+01  L2(v)=2.278e+01  Linf(|e|)=6.366e-02
#                 E_mean=1000.0  nu_mean=0.300  Force_mean=3.716
#                 det(F)@GP: mean=1.049, min=1.049, max=1.050
# ===== Test-set Evaluation =====
# Mean Rel L2(u): 4.267e+01
# Mean Rel L2(v): 2.026e+01
# Std  Rel L2(u): 1.792e+01
# Std  Rel L2(v): 1.168e+01
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 5.033
# Val error (mean of Rel L2 u,v): 3.146e+01  epoch_time=4.54s  cum_wall_clock=4.5s  gpu_peak_mem_allocated=425.0MB  gpu_peak_mem_reserved=559.9MB  gpu_peak_mem_device=1107.2MB/85094.8MB  opt_steps=100
# [best] New best val_error=3.146e+01 at epoch=1 -> model_best.pt
# [batch     0] (epoch=2) Pi_mean=3.260286e+00  E=1000.0  nu=0.300  Force=5.667  detF@GP=1.049  opt_steps=101
# [viz sid=84 tag=epoch2] Pi=3.098e+00  U=3.413e+00  W=3.141e-01
#                 L2(u)=1.159e+01  L2(v)=1.621e+01  Linf(|e|)=5.418e-02
#                 E_mean=1000.0  nu_mean=0.299  Force_mean=5.384
#                 det(F)@GP: mean=0.944, min=0.944, max=0.945
# ===== Test-set Evaluation =====
# Mean Rel L2(u): 1.280e+01
# Mean Rel L2(v): 2.074e+01
# Std  Rel L2(u): 5.377e+00
# Std  Rel L2(v): 1.321e+01
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 5.033
# Val error (mean of Rel L2 u,v): 1.677e+01  epoch_time=3.93s  cum_wall_clock=8.5s  gpu_peak_mem_allocated=425.0MB  gpu_peak_mem_reserved=677.4MB  gpu_peak_mem_device=1224.7MB/85094.8MB  opt_steps=200
# [best] New best val_error=1.677e+01 at epoch=2 -> model_best.pt
# [batch     0] (epoch=3) Pi_mean=3.104358e+00  E=1000.0  nu=0.300  Force=5.667  detF@GP=0.944  opt_steps=201
# [viz sid=661 tag=epoch3] Pi=9.198e-01  U=8.303e-01  W=-8.954e-02
#                 L2(u)=1.006e+01  L2(v)=1.535e+01  Linf(|e|)=3.100e-02
#                 E_mean=1000.0  nu_mean=0.300  Force_mean=3.103
#                 det(F)@GP: mean=1.027, min=1.026, max=1.028
# ===== Test-set Evaluation =====
# Mean Rel L2(u): 1.071e+01
# Mean Rel L2(v): 1.170e+01
# Std  Rel L2(u): 4.531e+00
# Std  Rel L2(v): 6.488e+00
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 5.033
# Val error (mean of Rel L2 u,v): 1.120e+01  epoch_time=4.04s  cum_wall_clock=12.5s  gpu_peak_mem_allocated=425.0MB  gpu_peak_mem_reserved=677.4MB  gpu_peak_mem_device=1224.7MB/85094.8MB  opt_steps=300
# [best] New best val_error=1.120e+01 at epoch=3 -> model_best.pt
#
# ================================================================================
# FINAL RESULTS:
# Mean Rel L2(u): 1.071e+01
# Mean Rel L2(v): 1.170e+01
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 5.033
# Best val_error: 1.120e+01 at epoch 3 (see model_best.pt)
# Total wall clock: 12.5s over 300 optimizer steps (batch_size=8)
# ================================================================================
# Inference latency (batch_size=1, forward pass only, no training): 4.7428 ms/sample (averaged over 200 calls, cuda)
#
# Training completed!
# Results saved to: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_mooney_rivlin
# $ /usr/bin/python3 -u -m omar_pfem.measure_inference_latency --geometry B1 --material arruda_boyce --checkpoint /content/drive/MyDrive/pfem_run/results/B1_arruda_boyce/model_best.pt --dataset /content/drive/MyDrive/pfem_run/results/datasets/B1_arruda_boyce/hyperelastic_training_data_q4.npz --ntrain 800 --ntest 200 --out_json /content/drive/MyDrive/pfem_run/results/B1_arruda_boyce/inference_latency.json
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Loaded checkpoint: /content/drive/MyDrive/pfem_run/results/B1_arruda_boyce/model_best.pt
#
# Material statistics in training set:
#   E: mean=1000.00, std=200.00, min=142.41, max=1750.16
#   nu: mean=0.3000, std=0.0483, min=0.2000, max=0.4000
#
# Force statistics in training set:
#   Force: mean=4.994, std=2.023, min=0.002, max=12.228
#   Nodes with force: 16800 / 352800
# Test samples: 200
# Inference latency: 4.7451 ms/sample (batch_size=1, 200 repeats, device=cuda)
# Written to /content/drive/MyDrive/pfem_run/results/B1_arruda_boyce/inference_latency.json
# $ /usr/bin/python3 -u -m omar_pfem.train_B1 --path /content/drive/MyDrive/pfem_run/results/datasets/B1_arruda_boyce/hyperelastic_training_data_q4.npz --material arruda_boyce --ntrain 800 --ntest 200 --batch_size 8 --epochs 3 --validate_every 1 --save_every 1 --early_stop_patience 0 --print_every 999999 --out_dir /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Using dataset: /content/drive/MyDrive/pfem_run/results/datasets/B1_arruda_boyce/hyperelastic_training_data_q4.npz
# Output dir: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
# Material: arruda_boyce
# fun_dim=4  (3->[E,nu,fy], 4->[E,nu,fx,fy])
#
# Material statistics in training set:
#   E: mean=1000.00, std=200.00, min=142.41, max=1750.16
#   nu: mean=0.3000, std=0.0483, min=0.2000, max=0.4000
#
# Force statistics in training set:
#   Force: mean=4.994, std=2.023, min=0.002, max=12.228
#   Nodes with force: 16800 / 352800
# Loaded Q4 dataset: ntrain=800, ntest=200
# Sample 0: nodes=441, quads=400, E_mean=1000.0, nu_mean=0.300, Force_mean=9.483, Force_nodes=21
# Sample 1: nodes=441, quads=400, E_mean=1000.0, nu_mean=0.300, Force_mean=5.556, Force_nodes=21
# Sample 2: nodes=441, quads=400, E_mean=1000.0, nu_mean=0.299, Force_mean=6.843, Force_nodes=21
# [Saved] mesh_materials_forces_train_sample0_sid0.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
# [Saved] mesh_materials_forces_test_sample0_sid0.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
# [batch     0] (epoch=1) Pi_mean=4.963097e+01  E=1000.0  nu=0.300  Force=5.667  detF@GP=0.818  opt_steps=1
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it16_sid19.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=16, sid(in split)=19, gid(in original npz)=19
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce/bad_case_nonfinite_epoch1_it16_sid19_gid19.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it24_sid24.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=24, sid(in split)=24, gid(in original npz)=24
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce/bad_case_nonfinite_epoch1_it24_sid24_gid24.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it24_sid25.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=24, sid(in split)=25, gid(in original npz)=25
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce/bad_case_nonfinite_epoch1_it24_sid25_gid25.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it24_sid26.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=24, sid(in split)=26, gid(in original npz)=26
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce/bad_case_nonfinite_epoch1_it24_sid26_gid26.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it24_sid27.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=24, sid(in split)=27, gid(in original npz)=27
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce/bad_case_nonfinite_epoch1_it24_sid27_gid27.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it24_sid29.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=24, sid(in split)=29, gid(in original npz)=29
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce/bad_case_nonfinite_epoch1_it24_sid29_gid29.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it24_sid30.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=24, sid(in split)=30, gid(in original npz)=30
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce/bad_case_nonfinite_epoch1_it24_sid30_gid30.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it24_sid31.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=24, sid(in split)=31, gid(in original npz)=31
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce/bad_case_nonfinite_epoch1_it24_sid31_gid31.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it40_sid42.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=40, sid(in split)=42, gid(in original npz)=42
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce/bad_case_nonfinite_epoch1_it40_sid42_gid42.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it40_sid45.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=40, sid(in split)=45, gid(in original npz)=45
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce/bad_case_nonfinite_epoch1_it40_sid45_gid45.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it72_sid73.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=72, sid(in split)=73, gid(in original npz)=73
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce/bad_case_nonfinite_epoch1_it72_sid73_gid73.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it72_sid78.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=72, sid(in split)=78, gid(in original npz)=78
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce/bad_case_nonfinite_epoch1_it72_sid78_gid78.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it80_sid80.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=80, sid(in split)=80, gid(in original npz)=80
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce/bad_case_nonfinite_epoch1_it80_sid80_gid80.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it80_sid82.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=80, sid(in split)=82, gid(in original npz)=82
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce/bad_case_nonfinite_epoch1_it80_sid82_gid82.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it80_sid83.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=80, sid(in split)=83, gid(in original npz)=83
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce/bad_case_nonfinite_epoch1_it80_sid83_gid83.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it88_sid90.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=88, sid(in split)=90, gid(in original npz)=90
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce/bad_case_nonfinite_epoch1_it88_sid90_gid90.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it88_sid92.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=88, sid(in split)=92, gid(in original npz)=92
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce/bad_case_nonfinite_epoch1_it88_sid92_gid92.npz
# ================================================================================
#
# [epoch 1] skipped=17 bad samples
# [viz sid=571 tag=epoch1] Pi=3.050e+00  U=2.793e+00  W=-2.571e-01
#                 L2(u)=1.224e+01  L2(v)=2.010e+01  Linf(|e|)=7.194e-02
#                 E_mean=1000.0  nu_mean=0.300  Force_mean=3.716
#                 det(F)@GP: mean=1.066, min=1.065, max=1.067
# ===== Test-set Evaluation =====
# Mean Rel L2(u): 1.567e+01
# Mean Rel L2(v): 1.780e+01
# Std  Rel L2(u): 6.993e+00
# Std  Rel L2(v): 1.013e+01
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 5.033
# Val error (mean of Rel L2 u,v): 1.674e+01  epoch_time=44.19s  cum_wall_clock=44.2s  gpu_peak_mem_allocated=425.0MB  gpu_peak_mem_reserved=562.0MB  gpu_peak_mem_device=1109.3MB/85094.8MB  opt_steps=100
# [best] New best val_error=1.674e+01 at epoch=1 -> model_best.pt
# [batch     0] (epoch=2) Pi_mean=3.233165e+00  E=1000.0  nu=0.300  Force=5.667  detF@GP=1.066  opt_steps=101
# [viz sid=84 tag=epoch2] Pi=3.253e-01  U=2.226e-01  W=-1.027e-01
#                 L2(u)=6.168e+00  L2(v)=4.748e+00  Linf(|e|)=2.430e-02
#                 E_mean=1000.0  nu_mean=0.299  Force_mean=5.384
#                 det(F)@GP: mean=1.018, min=1.017, max=1.018
# ===== Test-set Evaluation =====
# Mean Rel L2(u): 6.921e+00
# Mean Rel L2(v): 5.622e+00
# Std  Rel L2(u): 3.144e+00
# Std  Rel L2(v): 2.778e+00
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 5.033
# Val error (mean of Rel L2 u,v): 6.272e+00  epoch_time=4.20s  cum_wall_clock=48.4s  gpu_peak_mem_allocated=425.0MB  gpu_peak_mem_reserved=679.5MB  gpu_peak_mem_device=1228.9MB/85094.8MB  opt_steps=200
# [best] New best val_error=6.272e+00 at epoch=2 -> model_best.pt
# [batch     0] (epoch=3) Pi_mean=3.338159e-01  E=1000.0  nu=0.300  Force=5.667  detF@GP=1.018  opt_steps=201
# [viz sid=661 tag=epoch3] Pi=2.993e-01  U=2.449e-01  W=-5.441e-02
#                 L2(u)=1.458e+01  L2(v)=6.751e+00  Linf(|e|)=2.624e-02
#                 E_mean=1000.0  nu_mean=0.300  Force_mean=3.103
#                 det(F)@GP: mean=1.017, min=1.016, max=1.017
# ===== Test-set Evaluation =====
# Mean Rel L2(u): 1.726e+01
# Mean Rel L2(v): 5.240e+00
# Std  Rel L2(u): 7.705e+00
# Std  Rel L2(v): 2.548e+00
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 5.033
# Val error (mean of Rel L2 u,v): 1.125e+01  epoch_time=4.27s  cum_wall_clock=52.7s  gpu_peak_mem_allocated=425.0MB  gpu_peak_mem_reserved=679.5MB  gpu_peak_mem_device=1228.9MB/85094.8MB  opt_steps=300
#
# ================================================================================
# FINAL RESULTS:
# Mean Rel L2(u): 1.726e+01
# Mean Rel L2(v): 5.240e+00
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 5.033
# Best val_error: 6.272e+00 at epoch 2 (see model_best.pt)
# Total wall clock: 52.7s over 300 optimizer steps (batch_size=8)
# ================================================================================
# Inference latency (batch_size=1, forward pass only, no training): 4.7754 ms/sample (averaged over 200 calls, cuda)
#
# Training completed!
# Results saved to: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B1_arruda_boyce
# $ /usr/bin/python3 -u -m omar_pfem.measure_inference_latency --geometry B2 --material neo_hookean --checkpoint /content/drive/MyDrive/pfem_run/results/B2_neo_hookean/model_best.pt --dataset /content/drive/MyDrive/pfem_run/results/datasets/B2_neo_hookean/hyperelastic_training_data_q4.npz --ntrain 800 --ntest 200 --out_json /content/drive/MyDrive/pfem_run/results/B2_neo_hookean/inference_latency.json
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Loaded checkpoint: /content/drive/MyDrive/pfem_run/results/B2_neo_hookean/model_best.pt
#
# Material statistics in training set:
#   E: mean=1000.00, std=200.00, min=120.64, max=1791.61
#   nu: mean=0.3000, std=0.0484, min=0.2000, max=0.4000
#
# Force statistics in training set:
#   Force: mean=5.023, std=2.021, min=0.003, max=13.746
#   Nodes with force: 16800 / 352800
# Test samples: 200
# Inference latency: 4.6725 ms/sample (batch_size=1, 200 repeats, device=cuda)
# Written to /content/drive/MyDrive/pfem_run/results/B2_neo_hookean/inference_latency.json
# $ /usr/bin/python3 -u -m omar_pfem.train_B2 --path /content/drive/MyDrive/pfem_run/results/datasets/B2_neo_hookean/hyperelastic_training_data_q4.npz --material neo_hookean --ntrain 800 --ntest 200 --batch_size 8 --epochs 3 --validate_every 1 --save_every 1 --early_stop_patience 0 --print_every 999999 --out_dir /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_neo_hookean
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Using dataset: /content/drive/MyDrive/pfem_run/results/datasets/B2_neo_hookean/hyperelastic_training_data_q4.npz
# Output dir: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_neo_hookean
# Material: neo_hookean
# fun_dim=4  (3->[E,nu,fy], 4->[E,nu,fx,fy])
#
# Material statistics in training set:
#   E: mean=1000.00, std=200.00, min=120.64, max=1791.61
#   nu: mean=0.3000, std=0.0484, min=0.2000, max=0.4000
#
# Force statistics in training set:
#   Force: mean=5.023, std=2.021, min=0.003, max=13.746
#   Nodes with force: 16800 / 352800
# Loaded Q4 dataset: ntrain=800, ntest=200
# Sample 0: nodes=441, quads=400, E_mean=1000.0, nu_mean=0.300, Force_mean=0.974, Force_nodes=21
# Sample 1: nodes=441, quads=400, E_mean=1000.0, nu_mean=0.300, Force_mean=4.444, Force_nodes=21
# Sample 2: nodes=441, quads=400, E_mean=1000.0, nu_mean=0.299, Force_mean=3.157, Force_nodes=21
# [Saved] mesh_materials_forces_train_sample0_sid0.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_neo_hookean
# [Saved] mesh_materials_forces_test_sample0_sid0.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_neo_hookean
# [batch     0] (epoch=1) Pi_mean=9.040043e+01  E=1000.0  nu=0.300  Force=4.391  detF@GP=0.761  opt_steps=1
# [viz sid=571 tag=epoch1] Pi=2.657e-01  U=3.130e-01  W=4.735e-02
#                 L2(u)=7.514e-01  L2(v)=4.607e+00  Linf(|e|)=2.486e-02
#                 E_mean=1000.0  nu_mean=0.300  Force_mean=6.284
#                 det(F)@GP: mean=1.015, min=1.011, max=1.017
# ===== Test-set Evaluation =====
# Mean Rel L2(u): 7.794e-01
# Mean Rel L2(v): 2.571e+00
# Std  Rel L2(u): 5.471e-01
# Std  Rel L2(v): 2.501e+00
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 4.979
# Val error (mean of Rel L2 u,v): 1.675e+00  epoch_time=4.45s  cum_wall_clock=4.5s  gpu_peak_mem_allocated=425.0MB  gpu_peak_mem_reserved=562.0MB  gpu_peak_mem_device=1109.3MB/85094.8MB  opt_steps=100
# [best] New best val_error=1.675e+00 at epoch=1 -> model_best.pt
# [batch     0] (epoch=2) Pi_mean=2.853409e-01  E=1000.0  nu=0.300  Force=4.391  detF@GP=1.015  opt_steps=101
# [viz sid=84 tag=epoch2] Pi=4.367e-01  U=4.873e-01  W=5.056e-02
#                 L2(u)=1.891e+00  L2(v)=1.011e+00  Linf(|e|)=1.525e-02
#                 E_mean=1000.0  nu_mean=0.299  Force_mean=4.616
#                 det(F)@GP: mean=1.020, min=1.017, max=1.021
# ===== Test-set Evaluation =====
# Mean Rel L2(u): 1.615e+00
# Mean Rel L2(v): 2.490e+00
# Std  Rel L2(u): 1.690e+00
# Std  Rel L2(v): 2.438e+00
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 4.979
# Val error (mean of Rel L2 u,v): 2.052e+00  epoch_time=3.89s  cum_wall_clock=8.3s  gpu_peak_mem_allocated=425.0MB  gpu_peak_mem_reserved=679.5MB  gpu_peak_mem_device=1226.8MB/85094.8MB  opt_steps=200
# [batch     0] (epoch=3) Pi_mean=4.525390e-01  E=1000.0  nu=0.300  Force=4.391  detF@GP=1.020  opt_steps=201
# [viz sid=661 tag=epoch3] Pi=4.205e-01  U=4.974e-01  W=7.691e-02
#                 L2(u)=1.478e+00  L2(v)=4.396e-01  Linf(|e|)=1.520e-02
#                 E_mean=1000.0  nu_mean=0.300  Force_mean=6.897
#                 det(F)@GP: mean=1.021, min=1.015, max=1.022
# ===== Test-set Evaluation =====
# Mean Rel L2(u): 1.679e+00
# Mean Rel L2(v): 2.466e+00
# Std  Rel L2(u): 1.747e+00
# Std  Rel L2(v): 2.421e+00
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 4.979
# Val error (mean of Rel L2 u,v): 2.073e+00  epoch_time=4.07s  cum_wall_clock=12.4s  gpu_peak_mem_allocated=425.0MB  gpu_peak_mem_reserved=679.5MB  gpu_peak_mem_device=1226.8MB/85094.8MB  opt_steps=300
#
# ================================================================================
# FINAL RESULTS:
# Mean Rel L2(u): 1.679e+00
# Mean Rel L2(v): 2.466e+00
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 4.979
# Best val_error: 1.675e+00 at epoch 1 (see model_best.pt)
# Total wall clock: 12.4s over 300 optimizer steps (batch_size=8)
# ================================================================================
# Inference latency (batch_size=1, forward pass only, no training): 4.7505 ms/sample (averaged over 200 calls, cuda)
#
# Training completed!
# Results saved to: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_neo_hookean
# $ /usr/bin/python3 -u -m omar_pfem.measure_inference_latency --geometry B2 --material mooney_rivlin --checkpoint /content/drive/MyDrive/pfem_run/results/B2_mooney_rivlin/model_best.pt --dataset /content/drive/MyDrive/pfem_run/results/datasets/B2_mooney_rivlin/hyperelastic_training_data_q4.npz --ntrain 800 --ntest 200 --out_json /content/drive/MyDrive/pfem_run/results/B2_mooney_rivlin/inference_latency.json
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Loaded checkpoint: /content/drive/MyDrive/pfem_run/results/B2_mooney_rivlin/model_best.pt
#
# Material statistics in training set:
#   E: mean=1000.00, std=200.00, min=120.64, max=1791.61
#   nu: mean=0.3000, std=0.0484, min=0.2000, max=0.4000
#
# Force statistics in training set:
#   Force: mean=5.023, std=2.021, min=0.003, max=13.746
#   Nodes with force: 16800 / 352800
# Test samples: 200
# Inference latency: 4.8997 ms/sample (batch_size=1, 200 repeats, device=cuda)
# Written to /content/drive/MyDrive/pfem_run/results/B2_mooney_rivlin/inference_latency.json
# $ /usr/bin/python3 -u -m omar_pfem.train_B2 --path /content/drive/MyDrive/pfem_run/results/datasets/B2_mooney_rivlin/hyperelastic_training_data_q4.npz --material mooney_rivlin --ntrain 800 --ntest 200 --batch_size 8 --epochs 3 --validate_every 1 --save_every 1 --early_stop_patience 0 --print_every 999999 --out_dir /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_mooney_rivlin
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Using dataset: /content/drive/MyDrive/pfem_run/results/datasets/B2_mooney_rivlin/hyperelastic_training_data_q4.npz
# Output dir: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_mooney_rivlin
# Material: mooney_rivlin
# fun_dim=4  (3->[E,nu,fy], 4->[E,nu,fx,fy])
#
# Material statistics in training set:
#   E: mean=1000.00, std=200.00, min=120.64, max=1791.61
#   nu: mean=0.3000, std=0.0484, min=0.2000, max=0.4000
#
# Force statistics in training set:
#   Force: mean=5.023, std=2.021, min=0.003, max=13.746
#   Nodes with force: 16800 / 352800
# Loaded Q4 dataset: ntrain=800, ntest=200
# Sample 0: nodes=441, quads=400, E_mean=1000.0, nu_mean=0.300, Force_mean=0.974, Force_nodes=21
# Sample 1: nodes=441, quads=400, E_mean=1000.0, nu_mean=0.300, Force_mean=4.444, Force_nodes=21
# Sample 2: nodes=441, quads=400, E_mean=1000.0, nu_mean=0.299, Force_mean=3.157, Force_nodes=21
# [Saved] mesh_materials_forces_train_sample0_sid0.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_mooney_rivlin
# [Saved] mesh_materials_forces_test_sample0_sid0.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_mooney_rivlin
# [batch     0] (epoch=1) Pi_mean=1.224873e+02  E=1000.0  nu=0.300  Force=4.391  detF@GP=0.761  opt_steps=1
# [viz sid=571 tag=epoch1] Pi=4.305e+00  U=4.345e+00  W=3.977e-02
#                 L2(u)=4.296e+00  L2(v)=2.957e+01  Linf(|e|)=9.413e-02
#                 E_mean=1000.0  nu_mean=0.300  Force_mean=6.284
#                 det(F)@GP: mean=1.021, min=1.019, max=1.023
# ===== Test-set Evaluation =====
# Mean Rel L2(u): 1.078e+01
# Mean Rel L2(v): 1.795e+01
# Std  Rel L2(u): 6.789e+00
# Std  Rel L2(v): 1.339e+01
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 4.979
# Val error (mean of Rel L2 u,v): 1.437e+01  epoch_time=4.67s  cum_wall_clock=4.7s  gpu_peak_mem_allocated=425.0MB  gpu_peak_mem_reserved=559.9MB  gpu_peak_mem_device=1107.2MB/85094.8MB  opt_steps=100
# [best] New best val_error=1.437e+01 at epoch=1 -> model_best.pt
# [batch     0] (epoch=2) Pi_mean=4.268397e+00  E=1000.0  nu=0.300  Force=4.391  detF@GP=1.021  opt_steps=101
# [viz sid=84 tag=epoch2] Pi=1.665e+00  U=1.622e+00  W=-4.298e-02
#                 L2(u)=5.415e+00  L2(v)=7.663e+00  Linf(|e|)=6.221e-02
#                 E_mean=1000.0  nu_mean=0.299  Force_mean=4.616
#                 det(F)@GP: mean=0.984, min=0.983, max=0.985
# ===== Test-set Evaluation =====
# Mean Rel L2(u): 4.308e+00
# Mean Rel L2(v): 1.195e+01
# Std  Rel L2(u): 3.689e+00
# Std  Rel L2(v): 7.670e+00
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 4.979
# Val error (mean of Rel L2 u,v): 8.129e+00  epoch_time=4.15s  cum_wall_clock=8.8s  gpu_peak_mem_allocated=425.0MB  gpu_peak_mem_reserved=677.4MB  gpu_peak_mem_device=1224.7MB/85094.8MB  opt_steps=200
# [best] New best val_error=8.129e+00 at epoch=2 -> model_best.pt
# [batch     0] (epoch=3) Pi_mean=1.646999e+00  E=1000.0  nu=0.300  Force=4.391  detF@GP=0.984  opt_steps=201
# [viz sid=661 tag=epoch3] Pi=8.110e-01  U=8.911e-01  W=8.004e-02
#                 L2(u)=3.321e+00  L2(v)=8.458e-01  Linf(|e|)=1.963e-02
#                 E_mean=1000.0  nu_mean=0.300  Force_mean=6.897
#                 det(F)@GP: mean=1.022, min=1.020, max=1.022
# ===== Test-set Evaluation =====
# Mean Rel L2(u): 3.503e+00
# Mean Rel L2(v): 3.834e+00
# Std  Rel L2(u): 3.120e+00
# Std  Rel L2(v): 3.428e+00
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 4.979
# Val error (mean of Rel L2 u,v): 3.669e+00  epoch_time=4.19s  cum_wall_clock=13.0s  gpu_peak_mem_allocated=425.0MB  gpu_peak_mem_reserved=677.4MB  gpu_peak_mem_device=1224.7MB/85094.8MB  opt_steps=300
# [best] New best val_error=3.669e+00 at epoch=3 -> model_best.pt
#
# ================================================================================
# FINAL RESULTS:
# Mean Rel L2(u): 3.503e+00
# Mean Rel L2(v): 3.834e+00
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 4.979
# Best val_error: 3.669e+00 at epoch 3 (see model_best.pt)
# Total wall clock: 13.0s over 300 optimizer steps (batch_size=8)
# ================================================================================
# Inference latency (batch_size=1, forward pass only, no training): 4.9996 ms/sample (averaged over 200 calls, cuda)
#
# Training completed!
# Results saved to: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_mooney_rivlin
# $ /usr/bin/python3 -u -m omar_pfem.measure_inference_latency --geometry B2 --material arruda_boyce --checkpoint /content/drive/MyDrive/pfem_run/results/B2_arruda_boyce/model_best.pt --dataset /content/drive/MyDrive/pfem_run/results/datasets/B2_arruda_boyce/hyperelastic_training_data_q4.npz --ntrain 800 --ntest 200 --out_json /content/drive/MyDrive/pfem_run/results/B2_arruda_boyce/inference_latency.json
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Loaded checkpoint: /content/drive/MyDrive/pfem_run/results/B2_arruda_boyce/model_best.pt
#
# Material statistics in training set:
#   E: mean=1000.00, std=200.00, min=120.64, max=1791.61
#   nu: mean=0.3000, std=0.0484, min=0.2000, max=0.4000
#
# Force statistics in training set:
#   Force: mean=5.023, std=2.021, min=0.003, max=13.746
#   Nodes with force: 16800 / 352800
# Test samples: 200
# Inference latency: 4.8547 ms/sample (batch_size=1, 200 repeats, device=cuda)
# Written to /content/drive/MyDrive/pfem_run/results/B2_arruda_boyce/inference_latency.json
# $ /usr/bin/python3 -u -m omar_pfem.train_B2 --path /content/drive/MyDrive/pfem_run/results/datasets/B2_arruda_boyce/hyperelastic_training_data_q4.npz --material arruda_boyce --ntrain 800 --ntest 200 --batch_size 8 --epochs 3 --validate_every 1 --save_every 1 --early_stop_patience 0 --print_every 999999 --out_dir /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Using dataset: /content/drive/MyDrive/pfem_run/results/datasets/B2_arruda_boyce/hyperelastic_training_data_q4.npz
# Output dir: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce
# Material: arruda_boyce
# fun_dim=4  (3->[E,nu,fy], 4->[E,nu,fx,fy])
#
# Material statistics in training set:
#   E: mean=1000.00, std=200.00, min=120.64, max=1791.61
#   nu: mean=0.3000, std=0.0484, min=0.2000, max=0.4000
#
# Force statistics in training set:
#   Force: mean=5.023, std=2.021, min=0.003, max=13.746
#   Nodes with force: 16800 / 352800
# Loaded Q4 dataset: ntrain=800, ntest=200
# Sample 0: nodes=441, quads=400, E_mean=1000.0, nu_mean=0.300, Force_mean=0.974, Force_nodes=21
# Sample 1: nodes=441, quads=400, E_mean=1000.0, nu_mean=0.300, Force_mean=4.444, Force_nodes=21
# Sample 2: nodes=441, quads=400, E_mean=1000.0, nu_mean=0.299, Force_mean=3.157, Force_nodes=21
# [Saved] mesh_materials_forces_train_sample0_sid0.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce
# [Saved] mesh_materials_forces_test_sample0_sid0.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce
# [batch     0] (epoch=1) Pi_mean=6.455791e+01  E=1000.0  nu=0.300  Force=4.391  detF@GP=0.761  opt_steps=1
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it24_sid24.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=24, sid(in split)=24, gid(in original npz)=24
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce/bad_case_nonfinite_epoch1_it24_sid24_gid24.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it24_sid26.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=24, sid(in split)=26, gid(in original npz)=26
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce/bad_case_nonfinite_epoch1_it24_sid26_gid26.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it24_sid27.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=24, sid(in split)=27, gid(in original npz)=27
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce/bad_case_nonfinite_epoch1_it24_sid27_gid27.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it24_sid28.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=24, sid(in split)=28, gid(in original npz)=28
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce/bad_case_nonfinite_epoch1_it24_sid28_gid28.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it24_sid29.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=24, sid(in split)=29, gid(in original npz)=29
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce/bad_case_nonfinite_epoch1_it24_sid29_gid29.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it24_sid30.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=24, sid(in split)=30, gid(in original npz)=30
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce/bad_case_nonfinite_epoch1_it24_sid30_gid30.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it24_sid31.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=24, sid(in split)=31, gid(in original npz)=31
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce/bad_case_nonfinite_epoch1_it24_sid31_gid31.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it40_sid40.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=40, sid(in split)=40, gid(in original npz)=40
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce/bad_case_nonfinite_epoch1_it40_sid40_gid40.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it40_sid44.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=40, sid(in split)=44, gid(in original npz)=44
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce/bad_case_nonfinite_epoch1_it40_sid44_gid44.npz
# ================================================================================
#
# [Saved] mesh_materials_forces_bad_nonfinite_epoch1_it40_sid45.png in /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce
#
# ================================================================================
# [NaN/Inf DETECTED] reason=nonfinite
#   epoch=1, it=40, sid(in split)=45, gid(in original npz)=45
#   saved bad sample: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce/bad_case_nonfinite_epoch1_it40_sid45_gid45.npz
# ================================================================================
#
# [epoch 1] skipped=10 bad samples
# [viz sid=571 tag=epoch1] Pi=2.917e-01  U=2.443e-01  W=-4.739e-02
#                 L2(u)=2.110e+00  L2(v)=1.193e+00  Linf(|e|)=4.170e-02
#                 E_mean=1000.0  nu_mean=0.300  Force_mean=6.284
#                 det(F)@GP: mean=0.987, min=0.982, max=0.989
# ===== Test-set Evaluation =====
# Mean Rel L2(u): 4.255e+00
# Mean Rel L2(v): 1.096e+00
# Std  Rel L2(u): 2.276e+00
# Std  Rel L2(v): 1.006e-01
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 4.979
# Val error (mean of Rel L2 u,v): 2.676e+00  epoch_time=28.99s  cum_wall_clock=29.0s  gpu_peak_mem_allocated=425.0MB  gpu_peak_mem_reserved=562.0MB  gpu_peak_mem_device=1109.3MB/85094.8MB  opt_steps=100
# [best] New best val_error=2.676e+00 at epoch=1 -> model_best.pt
# [batch     0] (epoch=2) Pi_mean=2.765703e-01  E=1000.0  nu=0.300  Force=4.391  detF@GP=0.987  opt_steps=101
# [viz sid=84 tag=epoch2] Pi=7.002e-01  U=7.669e-01  W=6.666e-02
#                 L2(u)=4.068e+00  L2(v)=1.226e+00  Linf(|e|)=2.630e-02
#                 E_mean=1000.0  nu_mean=0.299  Force_mean=4.616
#                 det(F)@GP: mean=1.027, min=1.024, max=1.028
# ===== Test-set Evaluation =====
# Mean Rel L2(u): 3.303e+00
# Mean Rel L2(v): 2.833e+00
# Std  Rel L2(u): 2.999e+00
# Std  Rel L2(v): 2.706e+00
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 4.979
# Val error (mean of Rel L2 u,v): 3.068e+00  epoch_time=4.33s  cum_wall_clock=33.3s  gpu_peak_mem_allocated=425.0MB  gpu_peak_mem_reserved=679.5MB  gpu_peak_mem_device=1228.9MB/85094.8MB  opt_steps=200
# [batch     0] (epoch=3) Pi_mean=7.310799e-01  E=1000.0  nu=0.300  Force=4.391  detF@GP=1.027  opt_steps=201
# [viz sid=661 tag=epoch3] Pi=8.967e-01  U=1.010e+00  W=1.137e-01
#                 L2(u)=3.620e+00  L2(v)=7.010e-01  Linf(|e|)=2.976e-02
#                 E_mean=1000.0  nu_mean=0.300  Force_mean=6.897
#                 det(F)@GP: mean=1.031, min=1.028, max=1.032
# ===== Test-set Evaluation =====
# Mean Rel L2(u): 3.689e+00
# Mean Rel L2(v): 3.465e+00
# Std  Rel L2(u): 3.276e+00
# Std  Rel L2(v): 3.173e+00
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 4.979
# Val error (mean of Rel L2 u,v): 3.577e+00  epoch_time=4.44s  cum_wall_clock=37.8s  gpu_peak_mem_allocated=425.0MB  gpu_peak_mem_reserved=679.5MB  gpu_peak_mem_device=1228.9MB/85094.8MB  opt_steps=300
#
# ================================================================================
# FINAL RESULTS:
# Mean Rel L2(u): 3.689e+00
# Mean Rel L2(v): 3.465e+00
# Avg E: 1000.0
# Avg nu: 0.300
# Avg Force: 4.979
# Best val_error: 2.676e+00 at epoch 1 (see model_best.pt)
# Total wall clock: 37.8s over 300 optimizer steps (batch_size=8)
# ================================================================================
# Inference latency (batch_size=1, forward pass only, no training): 4.8860 ms/sample (averaged over 200 calls, cuda)
#
# Training completed!
# Results saved to: /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/B2_arruda_boyce
#
# Backfill pass complete.
# Inference latency: written directly into each case's own directory (RESULTS_DIR/{case}/inference_latency.json).
# GPU memory profiles (3-epoch throwaway runs at the real batch size): see /content/drive/MyDrive/pfem_run/results/memory_profile_reruns/{case}/metrics_history.json for gpu_peak_mem_device_mb / gpu_device_total_mb.

# %% [markdown]
# ## Cell 8 - Summary: metrics + loss curves across all 6 cases
#
# Reads each case's `metrics_history.json` -- works even for cases that are
# still mid-run or were only partially completed before a disconnect.

# %%
import numpy as np
from matplotlib import pyplot as plt

fig, axes = plt.subplots(2, 3, figsize=(16, 9))
summary_rows = []

for ax, (geometry, material) in zip(axes.flat, CASES):
    name = case_name(geometry, material)
    metrics_path = os.path.join(RESULTS_DIR, name, "metrics_history.json")
    if not os.path.exists(metrics_path):
        ax.set_title(f"{name}\n(no data yet)")
        continue

    with open(metrics_path) as f:
        history = _json.load(f)
    if not history:
        ax.set_title(f"{name}\n(empty history)")
        continue

    epochs = [h["epoch"] for h in history]
    val_err = [h["val_error"] for h in history]

    ax.semilogy(epochs, val_err, label="val_error")
    ax.set_title(f"{name} (epoch {epochs[-1]})")
    ax.set_xlabel("epoch")
    ax.legend()
    ax.grid(True, alpha=0.3)

    summary_rows.append((name, epochs[-1], history[-1]["mean_rel_L2_u"], history[-1]["mean_rel_L2_v"]))

plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "all_cases_loss_curves.png"), dpi=150)
plt.show()

print(f"{'case':<20s} {'last epoch':>10s} {'RelL2(u)':>12s} {'RelL2(v)':>12s}")
for name, ep, u, v in summary_rows:
    print(f"{name:<20s} {ep:>10d} {u:>12.3e} {v:>12.3e}")
# Out:
# case                 last epoch     RelL2(u)     RelL2(v)
# B1_neo_hookean              750    1.779e-01    1.112e-01
# B1_mooney_rivlin            700    1.898e-01    1.004e-01
# B1_arruda_boyce             675    2.172e-01    7.588e-02
# B2_neo_hookean              825    3.485e-01    3.542e-01
# B2_mooney_rivlin            575    3.373e-01    3.634e-01
# B2_arruda_boyce             650    3.455e-01    3.233e-01

# %% [markdown]
# ## Cell 9 - Mesh (h-refinement) convergence study for the reference FE solver
#
# Per the advisor's request to investigate the influence of mesh refinement
# and discuss the spatial convergence of the *reference FE solution* --
# this is a property of the CPU Newton-Raphson solver itself
# (`omar_pfem/mesh_convergence.py`), independent of the neural operator or
# `MESH_N`/`PROTOCOL` above.
#
# Uses fixed, closed-form analytic (E, nu, load) fields instead of the
# random GRF ensemble used everywhere else in this study, so the *exact
# same* physical field can be solved at every resolution (the GRF sampler's
# random phase array is sized by the mesh resolution itself, so re-sampling
# it at a different N does not give a finer view of the same field -- see
# `mesh_convergence.py`'s module docstring). This checks solver convergence
# only, so it is run once per geometry (Neo-Hookean) by default; add the
# other two materials to `CONVERGENCE_MATERIALS` below for full coverage.

# %%
CONVERGENCE_RESOLUTIONS = "6,11,16,21,26,31,41,51"   # node-count-per-side; 21 = this study's own mesh
CONVERGENCE_MATERIALS = ["neo_hookean"]              # add "mooney_rivlin"/"arruda_boyce" for full coverage

convergence_dir = os.path.join(RESULTS_DIR, "mesh_convergence")
os.makedirs(convergence_dir, exist_ok=True)

for geometry in GEOMETRIES:
    for material in CONVERGENCE_MATERIALS:
        out_json = os.path.join(convergence_dir, f"{geometry}_{material}_convergence.json")
        if os.path.exists(out_json):
            print(f"[{geometry}/{material}] convergence study already done -> {out_json}, skipping.")
            continue
        run_streaming([
            sys.executable, "-u", "-m", "omar_pfem.mesh_convergence",
            "--geometry", geometry, "--material", material,
            "--resolutions", CONVERGENCE_RESOLUTIONS,
            "--out_json", out_json,
        ], cwd=WORK_DIR, log_path=os.path.join(convergence_dir, f"{geometry}_{material}.log"))

print("\nMesh convergence study complete -- see", convergence_dir)
# Out:
# [B1/neo_hookean] convergence study already done -> /content/drive/MyDrive/pfem_run/results/mesh_convergence/B1_neo_hookean_convergence.json, skipping.
# [B2/neo_hookean] convergence study already done -> /content/drive/MyDrive/pfem_run/results/mesh_convergence/B2_neo_hookean_convergence.json, skipping.
#
# Mesh convergence study complete -- see /content/drive/MyDrive/pfem_run/results/mesh_convergence

# %% [markdown]
# ## Cell 10 - GPU-native FEM solver: correctness check + timing benchmark
#
# Per the advisor's request for a GPU-native FEM solver and its cost
# compared to the reference CPU solve (`NATIVE_FEM_SECONDS_PER_SAMPLE`
# above). Two scripts, in order:
#
# 1. `validate_gpu_fem_solver.py` -- solves the SAME problem instance with
#    both the existing CPU Newton-Raphson solver and the new
#    `torch.func`-based batched GPU solver (`gpu_fem_solver.py`) and reports
#    their agreement. Already verified locally to ~1e-13 relative error
#    (machine precision) for both geometries and all 3 materials -- this
#    just re-confirms that on the actual Colab GPU before trusting any
#    timing number.
# 2. `gpu_fem_benchmark.py` -- only meaningful once every validation above
#    reports PASS. Times BATCHED solves (multiple independent samples
#    solved simultaneously via `torch.func.vmap`, the natural way to use a
#    GPU) at several batch sizes, and reports ms/sample and the speedup vs.
#    the 8.0 s/sample CPU reference.

# %%
GPU_SOLVER_N = MESH_N          # same mesh resolution as the main study, for a like-for-like comparison
GPU_SOLVER_BATCH_SIZES = "1,8,32,128"

gpu_solver_dir = os.path.join(RESULTS_DIR, "gpu_fem_solver")
os.makedirs(gpu_solver_dir, exist_ok=True)

print("Step 1/2: correctness validation (GPU-style solver vs. CPU reference)")
validation_ok = True
for geometry in GEOMETRIES:
    for material in MATERIALS:
        log_path = os.path.join(gpu_solver_dir, f"validate_{geometry}_{material}.log")
        try:
            run_streaming([
                sys.executable, "-u", "-m", "omar_pfem.validate_gpu_fem_solver",
                "--geometry", geometry, "--material", material, "--N", "11",
            ], cwd=WORK_DIR, log_path=log_path)
        except RuntimeError as e:
            validation_ok = False
            print(f"[{geometry}/{material}] validation command failed: {e}")
            continue
        with open(log_path) as f:
            if "PASS" not in f.read():
                validation_ok = False
                print(f"[{geometry}/{material}] did NOT report PASS -- see {log_path}")

if not validation_ok:
    print("\nWARNING: at least one (geometry, material) did not PASS validation -- "
          "do NOT trust the timing numbers below until this is resolved.")
else:
    print("\nAll (geometry, material) pairs PASSED -- proceeding to timing benchmark.")

    print("\nStep 2/2: timing benchmark")
    for geometry in GEOMETRIES:
        for material in ["neo_hookean"]:   # cost is dominated by mesh/batch size, not material; extend if needed
            out_json = os.path.join(gpu_solver_dir, f"{geometry}_{material}_timing.json")
            if os.path.exists(out_json):
                print(f"[{geometry}/{material}] GPU FEM timing already done -> {out_json}, skipping.")
                continue
            run_streaming([
                sys.executable, "-u", "-m", "omar_pfem.gpu_fem_benchmark",
                "--geometry", geometry, "--material", material, "--N", str(GPU_SOLVER_N),
                "--batch_sizes", GPU_SOLVER_BATCH_SIZES, "--n_repeats", "3",
                "--out_json", out_json,
            ], cwd=WORK_DIR, log_path=os.path.join(gpu_solver_dir, f"timing_{geometry}_{material}.log"))

print("\nGPU FEM solver correctness + timing complete -- see", gpu_solver_dir)
# Out:
# Step 1/2: correctness validation (GPU-style solver vs. CPU reference)
# $ /usr/bin/python3 -u -m omar_pfem.validate_gpu_fem_solver --geometry B1 --material neo_hookean --N 11
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Device: cuda
#
# --- (a) CPU reference solver (solve_hyperelastic_TL_spatial), N=11 ---
# [step 1/10] converged in 2 iters, ||R||=6.646e-12
# [step 2/10] converged in 2 iters, ||R||=6.608e-12
# [step 3/10] converged in 2 iters, ||R||=6.697e-12
# [step 4/10] converged in 2 iters, ||R||=6.701e-12
# [step 5/10] converged in 2 iters, ||R||=6.859e-12
# [step 6/10] converged in 2 iters, ||R||=6.812e-12
# [step 7/10] converged in 2 iters, ||R||=7.075e-12
# [step 8/10] converged in 2 iters, ||R||=7.033e-12
# [step 9/10] converged in 2 iters, ||R||=6.609e-12
# [step 10/10] converged in 2 iters, ||R||=7.327e-12
#
# --- (b) GPU-style autodiff Newton solver, N=11 ---
#
# ================================================================================
# CORRECTNESS CHECK: GPU-style solver vs. validated CPU reference solver
# ================================================================================
# max |u_cpu|:                 2.150172e-03
# max |u_gpu - u_cpu| (abs):   2.636889e-16
# mean node-wise relative err: 1.373715e-13
# max  node-wise relative err: 9.920302e-13
# ================================================================================
# PASS: the two solvers agree to within machine precision -- same equilibrium.
# $ /usr/bin/python3 -u -m omar_pfem.validate_gpu_fem_solver --geometry B1 --material mooney_rivlin --N 11
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Device: cuda
#
# --- (a) CPU reference solver (solve_hyperelastic_TL_spatial), N=11 ---
# [step 1/10] converged in 2 iters, ||R||=3.345e-12
# [step 2/10] converged in 2 iters, ||R||=2.967e-12
# [step 3/10] converged in 2 iters, ||R||=3.077e-12
# [step 4/10] converged in 2 iters, ||R||=3.331e-12
# [step 5/10] converged in 2 iters, ||R||=3.074e-12
# [step 6/10] converged in 2 iters, ||R||=2.999e-12
# [step 7/10] converged in 2 iters, ||R||=3.586e-12
# [step 8/10] converged in 2 iters, ||R||=3.284e-12
# [step 9/10] converged in 2 iters, ||R||=2.900e-12
# [step 10/10] converged in 2 iters, ||R||=3.576e-12
#
# --- (b) GPU-style autodiff Newton solver, N=11 ---
#
# ================================================================================
# CORRECTNESS CHECK: GPU-style solver vs. validated CPU reference solver
# ================================================================================
# max |u_cpu|:                 1.403966e-03
# max |u_gpu - u_cpu| (abs):   2.256038e-16
# mean node-wise relative err: 2.077641e-13
# max  node-wise relative err: 1.366813e-12
# ================================================================================
# PASS: the two solvers agree to within machine precision -- same equilibrium.
# $ /usr/bin/python3 -u -m omar_pfem.validate_gpu_fem_solver --geometry B1 --material arruda_boyce --N 11
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Device: cuda
#
# --- (a) CPU reference solver (solve_hyperelastic_TL_spatial), N=11 ---
# [step 1/10] converged in 2 iters, ||R||=5.799e-12
# [step 2/10] converged in 2 iters, ||R||=5.814e-12
# [step 3/10] converged in 2 iters, ||R||=5.775e-12
# [step 4/10] converged in 2 iters, ||R||=5.963e-12
# [step 5/10] converged in 2 iters, ||R||=5.606e-12
# [step 6/10] converged in 2 iters, ||R||=5.858e-12
# [step 7/10] converged in 2 iters, ||R||=5.875e-12
# [step 8/10] converged in 2 iters, ||R||=5.749e-12
# [step 9/10] converged in 2 iters, ||R||=5.824e-12
# [step 10/10] converged in 2 iters, ||R||=5.885e-12
#
# --- (b) GPU-style autodiff Newton solver, N=11 ---
#
# ================================================================================
# CORRECTNESS CHECK: GPU-style solver vs. validated CPU reference solver
# ================================================================================
# max |u_cpu|:                 2.133656e-03
# max |u_gpu - u_cpu| (abs):   2.425514e-16
# mean node-wise relative err: 1.330968e-13
# max  node-wise relative err: 7.494064e-13
# ================================================================================
# PASS: the two solvers agree to within machine precision -- same equilibrium.
# $ /usr/bin/python3 -u -m omar_pfem.validate_gpu_fem_solver --geometry B2 --material neo_hookean --N 11
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Device: cuda
#
# --- (a) CPU reference solver (solve_hyperelastic_TL_ring), N=11 ---
# [step 1/10] converged in 2 iters, ||R||=1.442e-09
# [step 2/10] converged in 2 iters, ||R||=1.443e-09
# [step 3/10] converged in 2 iters, ||R||=1.446e-09
# [step 4/10] converged in 2 iters, ||R||=1.446e-09
# [step 5/10] converged in 2 iters, ||R||=1.449e-09
# [step 6/10] converged in 2 iters, ||R||=1.451e-09
# [step 7/10] converged in 2 iters, ||R||=1.453e-09
# [step 8/10] converged in 2 iters, ||R||=1.456e-09
# [step 9/10] converged in 2 iters, ||R||=1.458e-09
# [step 10/10] converged in 2 iters, ||R||=1.461e-09
#
# --- (b) GPU-style autodiff Newton solver, N=11 ---
#
# ================================================================================
# CORRECTNESS CHECK: GPU-style solver vs. validated CPU reference solver
# ================================================================================
# max |u_cpu|:                 1.914168e-02
# max |u_gpu - u_cpu| (abs):   5.250557e-16
# mean node-wise relative err: 1.342501e-14
# max  node-wise relative err: 5.321853e-14
# ================================================================================
# PASS: the two solvers agree to within machine precision -- same equilibrium.
# $ /usr/bin/python3 -u -m omar_pfem.validate_gpu_fem_solver --geometry B2 --material mooney_rivlin --N 11
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Device: cuda
#
# --- (a) CPU reference solver (solve_hyperelastic_TL_ring), N=11 ---
# [step 1/10] converged in 2 iters, ||R||=4.701e-10
# [step 2/10] converged in 2 iters, ||R||=4.688e-10
# [step 3/10] converged in 2 iters, ||R||=4.667e-10
# [step 4/10] converged in 2 iters, ||R||=4.655e-10
# [step 5/10] converged in 2 iters, ||R||=4.649e-10
# [step 6/10] converged in 2 iters, ||R||=4.620e-10
# [step 7/10] converged in 2 iters, ||R||=4.615e-10
# [step 8/10] converged in 2 iters, ||R||=4.591e-10
# [step 9/10] converged in 2 iters, ||R||=4.583e-10
# [step 10/10] converged in 2 iters, ||R||=4.561e-10
#
# --- (b) GPU-style autodiff Newton solver, N=11 ---
#
# ================================================================================
# CORRECTNESS CHECK: GPU-style solver vs. validated CPU reference solver
# ================================================================================
# max |u_cpu|:                 1.253886e-02
# max |u_gpu - u_cpu| (abs):   4.614364e-16
# mean node-wise relative err: 1.584490e-14
# max  node-wise relative err: 6.285247e-14
# ================================================================================
# PASS: the two solvers agree to within machine precision -- same equilibrium.
# $ /usr/bin/python3 -u -m omar_pfem.validate_gpu_fem_solver --geometry B2 --material arruda_boyce --N 11
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Device: cuda
#
# --- (a) CPU reference solver (solve_hyperelastic_TL_ring), N=11 ---
# [step 1/10] converged in 2 iters, ||R||=4.067e-09
# [step 2/10] converged in 2 iters, ||R||=4.071e-09
# [step 3/10] converged in 2 iters, ||R||=4.075e-09
# [step 4/10] converged in 2 iters, ||R||=4.079e-09
# [step 5/10] converged in 2 iters, ||R||=4.082e-09
# [step 6/10] converged in 2 iters, ||R||=4.086e-09
# [step 7/10] converged in 2 iters, ||R||=4.091e-09
# [step 8/10] converged in 2 iters, ||R||=4.094e-09
# [step 9/10] converged in 2 iters, ||R||=4.098e-09
# [step 10/10] converged in 2 iters, ||R||=4.103e-09
#
# --- (b) GPU-style autodiff Newton solver, N=11 ---
#
# ================================================================================
# CORRECTNESS CHECK: GPU-style solver vs. validated CPU reference solver
# ================================================================================
# max |u_cpu|:                 1.832286e-02
# max |u_gpu - u_cpu| (abs):   5.689234e-16
# mean node-wise relative err: 1.813986e-14
# max  node-wise relative err: 5.923585e-14
# ================================================================================
# PASS: the two solvers agree to within machine precision -- same equilibrium.
#
# All (geometry, material) pairs PASSED -- proceeding to timing benchmark.
#
# Step 2/2: timing benchmark
# [B1/neo_hookean] GPU FEM timing already done -> /content/drive/MyDrive/pfem_run/results/gpu_fem_solver/B1_neo_hookean_timing.json, skipping.
# [B2/neo_hookean] GPU FEM timing already done -> /content/drive/MyDrive/pfem_run/results/gpu_fem_solver/B2_neo_hookean_timing.json, skipping.
#
# GPU FEM solver correctness + timing complete -- see /content/drive/MyDrive/pfem_run/results/gpu_fem_solver

# %% [markdown]
# ## Cell 11 - Out-of-distribution (OOD) evaluation
#
# Per the advisor's request: "the test data are sampled from the same
# distribution as the training data ... include OOD predictions, for
# example different material ranges and loading magnitudes." For each of
# the 6 already-trained cases (Cell 6/7): generates a small OOD-only test
# set with material stiffness and load magnitude shifted ~2 std away from
# the in-distribution mean used everywhere else in this study, then
# evaluates that case's existing checkpoint on it -- **no retraining or
# fine-tuning**. Requires Cell 6/7 to have produced a checkpoint first;
# cases without one yet are skipped with a message.
#
# Uses `--id_ntrain NTRAIN` when evaluating the in-distribution side --
# `evaluate_ood.py` needs this to correctly read the SAME held-out test
# slice (`samples[NTRAIN:NTRAIN+NTEST]`) the case was actually validated
# on during training, rather than accidentally reading samples that were
# part of the training set (see that script's module docstring for why
# this matters).

# %%
OOD_NTEST = 200
# In-distribution defaults (see data_generate_B{1,2}.py): E~N(1000,200), nu~N(0.3,0.05) clipped to
# [0.2,0.4], B1 load ty~N(-5,2), B2 pressure p~N(5,2). OOD shifts both material stiffness and load
# magnitude ~2 std away from those means -- "different material ranges and loading magnitudes" per
# the advisor's own wording, not an arbitrarily extreme shift.
OOD_E_MEAN, OOD_E_STD = 1500.0, 200.0
OOD_TY_MEAN, OOD_TY_STD = -9.0, 2.0    # B1
OOD_P_MEAN, OOD_P_STD = 9.0, 2.0       # B2

ood_data_dir = os.path.join(DATA_DIR, "ood")                          # local scratch: fast, disposable
ood_archive_dir = os.path.join(DATASETS_ARCHIVE_DIR, "ood")           # Drive: durable copy of each OOD NPZ
ood_results_dir = os.path.join(RESULTS_DIR, "ood_eval")               # Drive: reports/logs
os.makedirs(ood_results_dir, exist_ok=True)

for geometry, material in CASES:
    name = case_name(geometry, material)
    case_out_dir = os.path.join(RESULTS_DIR, name)
    checkpoint = os.path.join(case_out_dir, "model_best.pt")
    if not os.path.exists(checkpoint):
        checkpoint = os.path.join(case_out_dir, "model_final.pt")
    if not os.path.exists(checkpoint):
        print(f"[{name}] no checkpoint found yet -- run Cell 6/7 first, skipping OOD eval.")
        continue

    id_path = os.path.join(DATASETS_ARCHIVE_DIR, name, "hyperelastic_training_data_q4.npz")
    if not os.path.exists(id_path):
        print(f"[{name}] in-distribution dataset not found at {id_path}, skipping OOD eval.")
        continue

    out_json = os.path.join(ood_results_dir, f"{name}_ood_report.json")
    if os.path.exists(out_json):
        print(f"[{name}] OOD evaluation already done -> {out_json}, skipping.")
        continue

    ood_h5_dir = os.path.join(ood_data_dir, f"fem_{name}_ood")
    ood_npz_dir = os.path.join(ood_data_dir, f"npz_{name}_ood")
    ood_path = os.path.join(ood_npz_dir, "hyperelastic_training_data_q4.npz")
    ood_archive_path = os.path.join(ood_archive_dir, name, "hyperelastic_training_data_q4.npz")

    # Same durability pattern as ensure_dataset(): restore from Drive if a
    # disconnect wiped local scratch after this OOD set was already
    # generated, instead of regenerating it from scratch.
    if os.path.exists(ood_path):
        print(f"[{name}] OOD dataset already exists locally, skipping generation.")
    elif os.path.exists(ood_archive_path):
        print(f"[{name}] Restoring archived OOD dataset from Drive ({ood_archive_path}).")
        os.makedirs(ood_npz_dir, exist_ok=True)
        shutil.copy2(ood_archive_path, ood_path)
    else:
        if geometry == "B1":
            gen_module = "omar_pfem.data.data_generate_B1"
            mesh_args = ["--Nx", str(MESH_N), "--Ny", str(MESH_N)]
            shift_args = ["--ty_mean", str(OOD_TY_MEAN), "--ty_std", str(OOD_TY_STD)]
            conv_module = "omar_pfem.data.convert_B1_quad"
        else:
            gen_module = "omar_pfem.data.data_generate_B2"
            mesh_args = ["--Ntheta", str(MESH_N), "--Nr", str(MESH_N)]
            shift_args = ["--p_mean", str(OOD_P_MEAN), "--p_std", str(OOD_P_STD)]
            conv_module = "omar_pfem.data.convert_B2_quad"

        run_streaming([
            sys.executable, "-u", "-m", gen_module,
            "--num_index", "1", "--num_samples", str(OOD_NTEST),
            *mesh_args, "--material", material, "--n_workers", str(N_WORKERS),
            "--E_mean", str(OOD_E_MEAN), "--E_std", str(OOD_E_STD),
            *shift_args,
            "--out_dir", ood_h5_dir,
        ], cwd=WORK_DIR, log_path=os.path.join(ood_results_dir, f"{name}_ood_data_generation.log"))
        run_streaming([
            sys.executable, "-u", "-m", conv_module,
            "--h5_dir", ood_h5_dir, "--out_dir", ood_npz_dir,
        ], cwd=WORK_DIR, log_path=os.path.join(ood_results_dir, f"{name}_ood_npz_conversion.log"))

        os.makedirs(os.path.dirname(ood_archive_path), exist_ok=True)
        shutil.copy2(ood_path, ood_archive_path)
        print(f"[{name}] OOD dataset archived to {ood_archive_path}")

    run_streaming([
        sys.executable, "-u", "-m", "omar_pfem.evaluate_ood",
        "--geometry", geometry, "--material", material,
        "--checkpoint", checkpoint,
        "--id_path", id_path, "--id_ntrain", str(NTRAIN),
        "--ood_path", ood_path,
        "--ntest", str(OOD_NTEST), "--out_json", out_json,
    ], cwd=WORK_DIR, log_path=os.path.join(ood_results_dir, f"{name}_ood_eval.log"))

print("\nOOD evaluation complete -- see", ood_results_dir)
# Out:
# Streaming output truncated to the last 5000 lines.
# [step 10/10] converged in 2 iters, ||R||=6.186e-10
#   Sample 167: max displacement=1.715e-02
# [step 10/10] converged in 2 iters, ||R||=6.131e-10
#   Sample 168: max displacement=1.758e-02
# [step 1/10] converged in 2 iters, ||R||=2.841e-10
# [step 1/10] converged in 2 iters, ||R||=6.831e-10
# [step 1/10] converged in 2 iters, ||R||=8.298e-10
# [step 1/10] converged in 2 iters, ||R||=5.300e-10
# [step 1/10] converged in 2 iters, ||R||=2.830e-09
# [step 1/10] converged in 2 iters, ||R||=1.174e-09
# [step 1/10] converged in 2 iters, ||R||=7.802e-10
# [step 1/10] converged in 2 iters, ||R||=2.032e-09
# [step 1/10] converged in 2 iters, ||R||=1.238e-09
# [step 1/10] converged in 2 iters, ||R||=4.027e-10
# [step 1/10] converged in 2 iters, ||R||=3.396e-10
# [step 1/10] converged in 2 iters, ||R||=1.602e-09
# [step 2/10] converged in 2 iters, ||R||=2.847e-10
# [step 2/10] converged in 2 iters, ||R||=6.827e-10
# [step 2/10] converged in 2 iters, ||R||=8.300e-10
# [step 2/10] converged in 2 iters, ||R||=2.836e-09
# [step 2/10] converged in 2 iters, ||R||=5.272e-10
# [step 2/10] converged in 2 iters, ||R||=1.162e-09
# [step 2/10] converged in 2 iters, ||R||=2.009e-09
# [step 2/10] converged in 2 iters, ||R||=1.227e-09
# [step 2/10] converged in 2 iters, ||R||=7.701e-10
# [step 2/10] converged in 2 iters, ||R||=4.035e-10
# [step 2/10] converged in 2 iters, ||R||=3.362e-10
# [step 2/10] converged in 2 iters, ||R||=1.582e-09
# [step 3/10] converged in 2 iters, ||R||=2.842e-10
# [step 3/10] converged in 2 iters, ||R||=6.822e-10
# [step 3/10] converged in 2 iters, ||R||=8.320e-10
# [step 3/10] converged in 2 iters, ||R||=2.843e-09
# [step 3/10] converged in 2 iters, ||R||=5.258e-10
# [step 3/10] converged in 2 iters, ||R||=1.154e-09
# [step 3/10] converged in 2 iters, ||R||=1.985e-09
# [step 3/10] converged in 2 iters, ||R||=1.217e-09
# [step 3/10] converged in 2 iters, ||R||=7.609e-10
# [step 3/10] converged in 2 iters, ||R||=4.038e-10
# [step 3/10] converged in 2 iters, ||R||=3.351e-10
# [step 3/10] converged in 2 iters, ||R||=1.564e-09
# [step 4/10] converged in 2 iters, ||R||=2.862e-10
# [step 4/10] converged in 2 iters, ||R||=6.815e-10
# [step 4/10] converged in 2 iters, ||R||=8.330e-10
# [step 4/10] converged in 2 iters, ||R||=2.849e-09
# [step 4/10] converged in 2 iters, ||R||=5.229e-10
# [step 4/10] converged in 2 iters, ||R||=1.143e-09
# [step 4/10] converged in 2 iters, ||R||=1.961e-09
# [step 4/10] converged in 2 iters, ||R||=1.207e-09
# [step 4/10] converged in 2 iters, ||R||=7.519e-10
# [step 4/10] converged in 2 iters, ||R||=4.037e-10
# [step 4/10] converged in 2 iters, ||R||=3.318e-10
# [step 4/10] converged in 2 iters, ||R||=1.548e-09
# [step 5/10] converged in 2 iters, ||R||=2.850e-10
# [step 5/10] converged in 2 iters, ||R||=6.819e-10
# [step 5/10] converged in 2 iters, ||R||=2.855e-09
# [step 5/10] converged in 2 iters, ||R||=8.337e-10
# [step 5/10] converged in 2 iters, ||R||=1.197e-09
# [step 5/10] converged in 2 iters, ||R||=1.132e-09
# [step 5/10] converged in 2 iters, ||R||=5.215e-10
# [step 5/10] converged in 2 iters, ||R||=1.939e-09
# [step 5/10] converged in 2 iters, ||R||=4.042e-10
# [step 5/10] converged in 2 iters, ||R||=7.440e-10
# [step 5/10] converged in 2 iters, ||R||=3.285e-10
# [step 5/10] converged in 2 iters, ||R||=1.530e-09
# [step 6/10] converged in 2 iters, ||R||=2.863e-10
# [step 6/10] converged in 2 iters, ||R||=8.348e-10
# [step 6/10] converged in 2 iters, ||R||=6.811e-10
# [step 6/10] converged in 2 iters, ||R||=2.861e-09
# [step 6/10] converged in 2 iters, ||R||=1.185e-09
# [step 6/10] converged in 2 iters, ||R||=5.185e-10
# [step 6/10] converged in 2 iters, ||R||=1.122e-09
# [step 6/10] converged in 2 iters, ||R||=1.916e-09
# [step 6/10] converged in 2 iters, ||R||=4.047e-10
# [step 6/10] converged in 2 iters, ||R||=7.340e-10
# [step 6/10] converged in 2 iters, ||R||=3.268e-10
# [step 6/10] converged in 2 iters, ||R||=1.513e-09
# [step 7/10] converged in 2 iters, ||R||=2.856e-10
# [step 7/10] converged in 2 iters, ||R||=6.820e-10
# [step 7/10] converged in 2 iters, ||R||=8.378e-10
# [step 7/10] converged in 2 iters, ||R||=2.868e-09
# [step 7/10] converged in 2 iters, ||R||=1.176e-09
# [step 7/10] converged in 2 iters, ||R||=5.161e-10
# [step 7/10] converged in 2 iters, ||R||=1.113e-09
# [step 7/10] converged in 2 iters, ||R||=1.892e-09
# [step 7/10] converged in 2 iters, ||R||=4.051e-10
# [step 7/10] converged in 2 iters, ||R||=7.258e-10
# [step 7/10] converged in 2 iters, ||R||=3.229e-10
# [step 7/10] converged in 2 iters, ||R||=1.498e-09
# [step 8/10] converged in 2 iters, ||R||=2.862e-10
# [step 8/10] converged in 2 iters, ||R||=6.814e-10
# [step 8/10] converged in 2 iters, ||R||=8.393e-10
# [step 8/10] converged in 2 iters, ||R||=2.874e-09
# [step 8/10] converged in 2 iters, ||R||=5.139e-10
# [step 8/10] converged in 2 iters, ||R||=1.167e-09
# [step 8/10] converged in 2 iters, ||R||=1.104e-09
# [step 8/10] converged in 2 iters, ||R||=4.060e-10
# [step 8/10] converged in 2 iters, ||R||=1.869e-09
# [step 8/10] converged in 2 iters, ||R||=7.172e-10
# [step 8/10] converged in 2 iters, ||R||=3.201e-10
# [step 8/10] converged in 2 iters, ||R||=1.482e-09
# [step 9/10] converged in 2 iters, ||R||=2.868e-10
# [step 9/10] converged in 2 iters, ||R||=6.818e-10
# [step 9/10] converged in 2 iters, ||R||=5.129e-10
# [step 9/10] converged in 2 iters, ||R||=2.880e-09
# [step 9/10] converged in 2 iters, ||R||=8.412e-10
# [step 9/10] converged in 2 iters, ||R||=1.155e-09
# [step 9/10] converged in 2 iters, ||R||=1.094e-09
# [step 9/10] converged in 2 iters, ||R||=1.848e-09
# [step 9/10] converged in 2 iters, ||R||=4.065e-10
# [step 9/10] converged in 2 iters, ||R||=7.103e-10
# [step 9/10] converged in 2 iters, ||R||=3.188e-10
# [step 9/10] converged in 2 iters, ||R||=1.465e-09
# [step 10/10] converged in 2 iters, ||R||=2.861e-10
#   Sample 169: max displacement=1.141e-02
# [step 10/10] converged in 2 iters, ||R||=6.816e-10
# Completed 170/200 samples
#   Sample 170: max displacement=1.571e-02
# [step 10/10] converged in 2 iters, ||R||=5.100e-10
#   Sample 172: max displacement=1.612e-02
# [step 10/10] converged in 2 iters, ||R||=2.886e-09
#   Sample 173: max displacement=2.239e-02
# [step 10/10] converged in 2 iters, ||R||=8.417e-10
#   Sample 171: max displacement=1.599e-02
# [step 10/10] converged in 2 iters, ||R||=1.147e-09
#   Sample 177: max displacement=1.831e-02
# [step 10/10] converged in 2 iters, ||R||=1.083e-09
#   Sample 174: max displacement=1.744e-02
# [step 10/10] converged in 2 iters, ||R||=1.825e-09
#   Sample 176: max displacement=1.917e-02
# [step 10/10] converged in 2 iters, ||R||=4.069e-10
#   Sample 178: max displacement=1.605e-02
# [step 10/10] converged in 2 iters, ||R||=7.011e-10
#   Sample 175: max displacement=1.600e-02
# [step 10/10] converged in 2 iters, ||R||=3.162e-10
#   Sample 179: max displacement=1.397e-02
# [step 10/10] converged in 2 iters, ||R||=1.450e-09
# Completed 180/200 samples
#   Sample 180: max displacement=2.007e-02
# [step 1/10] converged in 2 iters, ||R||=1.282e-09
# [step 1/10] converged in 2 iters, ||R||=5.378e-10
# [step 1/10] converged in 2 iters, ||R||=1.757e-09
# [step 1/10] converged in 2 iters, ||R||=2.121e-09
# [step 1/10] converged in 2 iters, ||R||=6.749e-10
# [step 1/10] converged in 2 iters, ||R||=2.746e-10
# [step 1/10] converged in 2 iters, ||R||=1.033e-09
# [step 1/10] converged in 2 iters, ||R||=1.153e-09
# [step 1/10] converged in 2 iters, ||R||=1.030e-09
# [step 1/10] converged in 2 iters, ||R||=3.876e-10
# [step 1/10] converged in 2 iters, ||R||=7.343e-10
# [step 1/10] converged in 2 iters, ||R||=9.873e-10
# [step 2/10] converged in 2 iters, ||R||=1.280e-09
# [step 2/10] converged in 2 iters, ||R||=5.318e-10
# [step 2/10] converged in 2 iters, ||R||=1.732e-09
# [step 2/10] converged in 2 iters, ||R||=2.103e-09
# [step 2/10] converged in 2 iters, ||R||=6.675e-10
# [step 2/10] converged in 2 iters, ||R||=2.710e-10
# [step 2/10] converged in 2 iters, ||R||=1.022e-09
# [step 2/10] converged in 2 iters, ||R||=1.142e-09
# [step 2/10] converged in 2 iters, ||R||=1.016e-09
# [step 2/10] converged in 2 iters, ||R||=3.865e-10
# [step 2/10] converged in 2 iters, ||R||=7.255e-10
# [step 2/10] converged in 2 iters, ||R||=9.758e-10
# [step 3/10] converged in 2 iters, ||R||=1.280e-09
# [step 3/10] converged in 2 iters, ||R||=5.250e-10
# [step 3/10] converged in 2 iters, ||R||=1.708e-09
# [step 3/10] converged in 2 iters, ||R||=2.083e-09
# [step 3/10] converged in 2 iters, ||R||=6.616e-10
# [step 3/10] converged in 2 iters, ||R||=2.718e-10
# [step 3/10] converged in 2 iters, ||R||=1.012e-09
# [step 3/10] converged in 2 iters, ||R||=1.131e-09
# [step 3/10] converged in 2 iters, ||R||=1.004e-09
# [step 3/10] converged in 2 iters, ||R||=3.874e-10
# [step 3/10] converged in 2 iters, ||R||=7.172e-10
# [step 3/10] converged in 2 iters, ||R||=9.648e-10
# [step 4/10] converged in 2 iters, ||R||=1.279e-09
# [step 4/10] converged in 2 iters, ||R||=5.202e-10
# [step 4/10] converged in 2 iters, ||R||=1.684e-09
# [step 4/10] converged in 2 iters, ||R||=2.063e-09
# [step 4/10] converged in 2 iters, ||R||=6.550e-10
# [step 4/10] converged in 2 iters, ||R||=2.692e-10
# [step 4/10] converged in 2 iters, ||R||=1.002e-09
# [step 4/10] converged in 2 iters, ||R||=1.120e-09
# [step 4/10] converged in 2 iters, ||R||=9.894e-10
# [step 4/10] converged in 2 iters, ||R||=3.862e-10
# [step 4/10] converged in 2 iters, ||R||=7.107e-10
# [step 4/10] converged in 2 iters, ||R||=9.536e-10
# [step 5/10] converged in 2 iters, ||R||=1.277e-09
# [step 5/10] converged in 2 iters, ||R||=5.144e-10
# [step 5/10] converged in 2 iters, ||R||=1.660e-09
# [step 5/10] converged in 2 iters, ||R||=2.045e-09
# [step 5/10] converged in 2 iters, ||R||=6.485e-10
# [step 5/10] converged in 2 iters, ||R||=2.688e-10
# [step 5/10] converged in 2 iters, ||R||=9.935e-10
# [step 5/10] converged in 2 iters, ||R||=1.110e-09
# [step 5/10] converged in 2 iters, ||R||=9.779e-10
# [step 5/10] converged in 2 iters, ||R||=3.866e-10
# [step 5/10] converged in 2 iters, ||R||=7.038e-10
# [step 5/10] converged in 2 iters, ||R||=9.433e-10
# [step 6/10] converged in 2 iters, ||R||=1.277e-09
# [step 6/10] converged in 2 iters, ||R||=5.091e-10
# [step 6/10] converged in 2 iters, ||R||=1.638e-09
# [step 6/10] converged in 2 iters, ||R||=2.025e-09
# [step 6/10] converged in 2 iters, ||R||=6.420e-10
# [step 6/10] converged in 2 iters, ||R||=2.653e-10
# [step 6/10] converged in 2 iters, ||R||=9.843e-10
# [step 6/10] converged in 2 iters, ||R||=1.100e-09
# [step 6/10] converged in 2 iters, ||R||=9.644e-10
# [step 6/10] converged in 2 iters, ||R||=3.873e-10
# [step 6/10] converged in 2 iters, ||R||=6.963e-10
# [step 6/10] converged in 2 iters, ||R||=9.339e-10
# [step 7/10] converged in 2 iters, ||R||=1.275e-09
# [step 7/10] converged in 2 iters, ||R||=5.045e-10
# [step 7/10] converged in 2 iters, ||R||=2.006e-09
# [step 7/10] converged in 2 iters, ||R||=1.615e-09
# [step 7/10] converged in 2 iters, ||R||=1.091e-09
# [step 7/10] converged in 2 iters, ||R||=6.363e-10
# [step 7/10] converged in 2 iters, ||R||=9.747e-10
# [step 7/10] converged in 2 iters, ||R||=2.651e-10
# [step 7/10] converged in 2 iters, ||R||=9.521e-10
# [step 7/10] converged in 2 iters, ||R||=3.881e-10
# [step 7/10] converged in 2 iters, ||R||=6.900e-10
# [step 7/10] converged in 2 iters, ||R||=9.233e-10
# [step 8/10] converged in 2 iters, ||R||=1.275e-09
# [step 8/10] converged in 2 iters, ||R||=4.989e-10
# [step 8/10] converged in 2 iters, ||R||=1.592e-09
# [step 8/10] converged in 2 iters, ||R||=1.989e-09
# [step 8/10] converged in 2 iters, ||R||=6.305e-10
# [step 8/10] converged in 2 iters, ||R||=1.082e-09
# [step 8/10] converged in 2 iters, ||R||=9.650e-10
# [step 8/10] converged in 2 iters, ||R||=2.639e-10
# [step 8/10] converged in 2 iters, ||R||=9.428e-10
# [step 8/10] converged in 2 iters, ||R||=3.873e-10
# [step 8/10] converged in 2 iters, ||R||=6.828e-10
# [step 8/10] converged in 2 iters, ||R||=9.130e-10
# [step 9/10] converged in 2 iters, ||R||=1.275e-09
# [step 9/10] converged in 2 iters, ||R||=4.939e-10
# [step 9/10] converged in 2 iters, ||R||=1.572e-09
# [step 9/10] converged in 2 iters, ||R||=1.971e-09
# [step 9/10] converged in 2 iters, ||R||=6.245e-10
# [step 9/10] converged in 2 iters, ||R||=1.074e-09
# [step 9/10] converged in 2 iters, ||R||=9.565e-10
# [step 9/10] converged in 2 iters, ||R||=2.633e-10
# [step 9/10] converged in 2 iters, ||R||=9.282e-10
# [step 9/10] converged in 2 iters, ||R||=3.877e-10
# [step 9/10] converged in 2 iters, ||R||=6.776e-10
# [step 9/10] converged in 2 iters, ||R||=9.040e-10
# [step 10/10] converged in 2 iters, ||R||=1.275e-09
#   Sample 181: max displacement=1.975e-02
# [step 10/10] converged in 2 iters, ||R||=4.889e-10
#   Sample 183: max displacement=1.587e-02
# [step 10/10] converged in 2 iters, ||R||=1.548e-09
#   Sample 182: max displacement=1.986e-02
# [step 10/10] converged in 2 iters, ||R||=6.180e-10
#   Sample 185: max displacement=1.666e-02
# [step 10/10] converged in 2 iters, ||R||=1.065e-09
# [step 10/10] converged in 2 iters, ||R||=9.480e-10
#   Sample 188: max displacement=1.906e-02
#   Sample 187: max displacement=1.799e-02
# [step 10/10] converged in 2 iters, ||R||=1.952e-09
#   Sample 186: max displacement=1.946e-02
# [step 10/10] converged in 2 iters, ||R||=2.621e-10
#   Sample 184: max displacement=1.338e-02
# [step 10/10] converged in 2 iters, ||R||=9.164e-10
#   Sample 189: max displacement=1.720e-02
# [step 10/10] converged in 2 iters, ||R||=3.870e-10
# Completed 190/200 samples
#   Sample 190: max displacement=1.378e-02
# [step 10/10] converged in 2 iters, ||R||=6.717e-10
#   Sample 191: max displacement=1.799e-02
# [step 10/10] converged in 2 iters, ||R||=8.940e-10
#   Sample 192: max displacement=1.757e-02
# [step 1/10] converged in 2 iters, ||R||=1.280e-10
# [step 1/10] converged in 2 iters, ||R||=1.301e-10
# [step 1/10] converged in 2 iters, ||R||=9.649e-10
# [step 1/10] converged in 2 iters, ||R||=8.184e-11
# [step 1/10] converged in 2 iters, ||R||=8.529e-10
# [step 1/10] converged in 2 iters, ||R||=2.816e-10
# [step 1/10] converged in 2 iters, ||R||=4.129e-10
# [step 2/10] converged in 2 iters, ||R||=1.279e-10
# [step 1/10] converged in 2 iters, ||R||=1.644e-09
# [step 2/10] converged in 2 iters, ||R||=1.302e-10
# [step 2/10] converged in 2 iters, ||R||=9.569e-10
# [step 2/10] converged in 2 iters, ||R||=8.164e-11
# [step 3/10] converged in 2 iters, ||R||=1.278e-10
# [step 3/10] converged in 2 iters, ||R||=1.307e-10
# [step 3/10] converged in 2 iters, ||R||=9.479e-10
# [step 3/10] converged in 2 iters, ||R||=8.106e-11
# [step 2/10] converged in 2 iters, ||R||=8.496e-10
# [step 2/10] converged in 2 iters, ||R||=2.818e-10
# [step 2/10] converged in 2 iters, ||R||=4.084e-10
# [step 2/10] converged in 2 iters, ||R||=1.622e-09
# [step 4/10] converged in 2 iters, ||R||=1.279e-10
# [step 4/10] converged in 2 iters, ||R||=1.312e-10
# [step 4/10] converged in 2 iters, ||R||=9.413e-10
# [step 4/10] converged in 2 iters, ||R||=8.101e-11
# [step 5/10] converged in 2 iters, ||R||=1.291e-10
# [step 5/10] converged in 2 iters, ||R||=1.302e-10
# [step 5/10] converged in 2 iters, ||R||=9.349e-10
# [step 5/10] converged in 2 iters, ||R||=8.092e-11
# [step 3/10] converged in 2 iters, ||R||=8.466e-10
# [step 3/10] converged in 2 iters, ||R||=2.826e-10
# [step 3/10] converged in 2 iters, ||R||=4.034e-10
# [step 3/10] converged in 2 iters, ||R||=1.601e-09
# [step 6/10] converged in 2 iters, ||R||=1.270e-10
# [step 6/10] converged in 2 iters, ||R||=1.315e-10
# [step 6/10] converged in 2 iters, ||R||=9.267e-10
# [step 6/10] converged in 2 iters, ||R||=8.123e-11
# [step 7/10] converged in 2 iters, ||R||=1.287e-10
# [step 7/10] converged in 2 iters, ||R||=1.314e-10
# [step 7/10] converged in 2 iters, ||R||=9.196e-10
# [step 4/10] converged in 2 iters, ||R||=8.445e-10
# [step 4/10] converged in 2 iters, ||R||=2.823e-10
# [step 4/10] converged in 2 iters, ||R||=4.020e-10
# [step 7/10] converged in 2 iters, ||R||=8.051e-11
# [step 4/10] converged in 2 iters, ||R||=1.580e-09
# [step 8/10] converged in 2 iters, ||R||=1.285e-10
# [step 8/10] converged in 2 iters, ||R||=1.303e-10
# [step 8/10] converged in 2 iters, ||R||=9.128e-10
# [step 8/10] converged in 2 iters, ||R||=8.051e-11
# [step 9/10] converged in 2 iters, ||R||=1.277e-10
# [step 9/10] converged in 2 iters, ||R||=1.315e-10
# [step 9/10] converged in 2 iters, ||R||=9.055e-10
# [step 5/10] converged in 2 iters, ||R||=8.415e-10
# [step 5/10] converged in 2 iters, ||R||=2.830e-10
# [step 5/10] converged in 2 iters, ||R||=3.981e-10
# [step 5/10] converged in 2 iters, ||R||=1.560e-09
# [step 9/10] converged in 2 iters, ||R||=8.091e-11
# [step 10/10] converged in 2 iters, ||R||=1.277e-10
#   Sample 193: max displacement=1.159e-02
# [step 10/10] converged in 2 iters, ||R||=1.322e-10
#   Sample 194: max displacement=1.096e-02
# [step 10/10] converged in 2 iters, ||R||=8.991e-10
#   Sample 195: max displacement=1.638e-02
# [step 10/10] converged in 2 iters, ||R||=8.103e-11
#   Sample 198: max displacement=1.049e-02
# [step 6/10] converged in 2 iters, ||R||=2.824e-10
# [step 6/10] converged in 2 iters, ||R||=8.384e-10
# [step 6/10] converged in 2 iters, ||R||=1.539e-09
# [step 6/10] converged in 2 iters, ||R||=3.942e-10
# [step 7/10] converged in 2 iters, ||R||=2.841e-10
# [step 7/10] converged in 2 iters, ||R||=8.366e-10
# [step 7/10] converged in 2 iters, ||R||=1.519e-09
# [step 7/10] converged in 2 iters, ||R||=3.902e-10
# [step 8/10] converged in 2 iters, ||R||=2.837e-10
# [step 8/10] converged in 2 iters, ||R||=8.347e-10
# [step 8/10] converged in 2 iters, ||R||=1.500e-09
# [step 8/10] converged in 2 iters, ||R||=3.861e-10
# [step 9/10] converged in 2 iters, ||R||=2.838e-10
# [step 9/10] converged in 2 iters, ||R||=8.322e-10
# [step 9/10] converged in 2 iters, ||R||=3.850e-10
# [step 9/10] converged in 2 iters, ||R||=1.481e-09
# [step 10/10] converged in 2 iters, ||R||=2.841e-10
#   Sample 199: max displacement=1.349e-02
# [step 10/10] converged in 2 iters, ||R||=8.301e-10
#   Sample 196: max displacement=1.693e-02
# [step 10/10] converged in 2 iters, ||R||=3.812e-10
#   Sample 197: max displacement=1.368e-02
# [step 10/10] converged in 2 iters, ||R||=1.462e-09
# Completed 200/200 samples
#   Sample 200: max displacement=2.024e-02
#
# Dataset generated with 200 successful samples out of 200
# Dataset split: Train=140, Val=30, Test=30
#
# Dataset saved to: /content/pfem_data/ood/fem_B2_neo_hookean_ood
# $ /usr/bin/python3 -u -m omar_pfem.data.convert_B2_quad --h5_dir /content/pfem_data/ood/fem_B2_neo_hookean_ood --out_dir /content/pfem_data/ood/npz_B2_neo_hookean_ood
# Converting /content/pfem_data/ood/fem_B2_neo_hookean_ood/hyperelastic_dataset_physics.h5 to training format (Q4 mesh, B2 ring)...
# Total samples: 200
# Valid samples: 200
# Using samples: 200
# Nodes: 441
# Domain: quarter ring R_in=1.0, R_out=2.0
# Elements: 400 Q4 elements
# theta=0 symmetry nodes (u_y=0): 21
# theta=pi/2 symmetry nodes (u_x=0): 21
# Inner boundary nodes: 21
# Inner boundary edges: 20
# Processing sample 1/200 (original index 0)
# Processing sample 11/200 (original index 10)
# Processing sample 21/200 (original index 20)
# Processing sample 31/200 (original index 30)
# Processing sample 41/200 (original index 40)
# Processing sample 51/200 (original index 50)
# Processing sample 61/200 (original index 60)
# Processing sample 71/200 (original index 70)
# Processing sample 81/200 (original index 80)
# Processing sample 91/200 (original index 90)
# Processing sample 101/200 (original index 100)
# Processing sample 111/200 (original index 110)
# Processing sample 121/200 (original index 120)
# Processing sample 131/200 (original index 130)
# Processing sample 141/200 (original index 140)
# Processing sample 151/200 (original index 150)
# Processing sample 161/200 (original index 160)
# Processing sample 171/200 (original index 170)
# Processing sample 181/200 (original index 180)
# Processing sample 191/200 (original index 190)
#
# Saving to /content/pfem_data/ood/npz_B2_neo_hookean_ood/hyperelastic_training_data_q4.npz...
# Successfully saved 200 samples to /content/pfem_data/ood/npz_B2_neo_hookean_ood/hyperelastic_training_data_q4.npz
# [B2_neo_hookean] OOD dataset archived to /content/drive/MyDrive/pfem_run/results/datasets/ood/B2_neo_hookean/hyperelastic_training_data_q4.npz
# $ /usr/bin/python3 -u -m omar_pfem.evaluate_ood --geometry B2 --material neo_hookean --checkpoint /content/drive/MyDrive/pfem_run/results/B2_neo_hookean/model_best.pt --id_path /content/drive/MyDrive/pfem_run/results/datasets/B2_neo_hookean/hyperelastic_training_data_q4.npz --id_ntrain 800 --ood_path /content/pfem_data/ood/npz_B2_neo_hookean_ood/hyperelastic_training_data_q4.npz --ntest 200 --out_json /content/drive/MyDrive/pfem_run/results/ood_eval/B2_neo_hookean_ood_report.json
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Loaded checkpoint: /content/drive/MyDrive/pfem_run/results/B2_neo_hookean/model_best.pt
#
# Material statistics in training set:
#   E: mean=1000.00, std=200.00, min=120.64, max=1791.61
#   nu: mean=0.3000, std=0.0484, min=0.2000, max=0.4000
#
# Force statistics in training set:
#   Force: mean=5.023, std=2.021, min=0.003, max=13.746
#   Nodes with force: 16800 / 352800
# In-distribution test set: 200 samples (samples [800:1000] of /content/drive/MyDrive/pfem_run/results/datasets/B2_neo_hookean/hyperelastic_training_data_q4.npz)
# Out-of-distribution test set: 200 samples (/content/pfem_data/ood/npz_B2_neo_hookean_ood/hyperelastic_training_data_q4.npz)
#
# ================================================================================
# OOD EVALUATION SUMMARY
# ================================================================================
# In-distribution val_error:     3.2374e-01
# Out-of-distribution val_error: 5.1255e-01
# Degradation factor (OOD/ID):   1.58x
# ================================================================================
# Full report written to /content/drive/MyDrive/pfem_run/results/ood_eval/B2_neo_hookean_ood_report.json
# $ /usr/bin/python3 -u -m omar_pfem.data.data_generate_B2 --num_index 1 --num_samples 200 --Ntheta 21 --Nr 21 --material mooney_rivlin --n_workers 12 --E_mean 1500.0 --E_std 200.0 --p_mean 9.0 --p_std 2.0 --out_dir /content/pfem_data/ood/fem_B2_mooney_rivlin_ood
# Generating B2 dataset (mooney_rivlin) for physics-informed training [OUT-OF-DISTRIBUTION: {'E_mean': 1500.0, 'E_std': 200.0, 'nu_mean': 0.3, 'nu_std': 0.05, 'nu_clip': (0.2, 0.4), 'p_mean': 9.0, 'p_std': 2.0}]...
# Generating 200 samples using 12 worker processes...
# [step 1/10] converged in 2 iters, ||R||=3.972e-11
# [step 1/10] converged in 2 iters, ||R||=4.007e-11
# [step 1/10] converged in 2 iters, ||R||=1.081e-10
# [step 1/10] converged in 2 iters, ||R||=1.855e-10
# [step 1/10] converged in 2 iters, ||R||=2.082e-10
# [step 1/10] converged in 2 iters, ||R||=4.283e-10
# [step 1/10] converged in 2 iters, ||R||=4.150e-11
# [step 1/10] converged in 2 iters, ||R||=8.125e-11
# [step 1/10] converged in 2 iters, ||R||=8.649e-11
# [step 1/10] converged in 2 iters, ||R||=5.130e-11
# [step 1/10] converged in 2 iters, ||R||=3.113e-11
# [step 1/10] converged in 2 iters, ||R||=2.663e-10
# [step 2/10] converged in 2 iters, ||R||=4.112e-11
# [step 2/10] converged in 2 iters, ||R||=2.062e-10
# [step 2/10] converged in 2 iters, ||R||=4.073e-11
# [step 2/10] converged in 2 iters, ||R||=3.790e-11
# [step 2/10] converged in 2 iters, ||R||=1.059e-10
# [step 2/10] converged in 2 iters, ||R||=1.857e-10
# [step 2/10] converged in 2 iters, ||R||=5.186e-11
# [step 2/10] converged in 2 iters, ||R||=2.616e-10
# [step 2/10] converged in 2 iters, ||R||=7.875e-11
# [step 2/10] converged in 2 iters, ||R||=4.265e-10
# [step 2/10] converged in 2 iters, ||R||=8.438e-11
# [step 2/10] converged in 2 iters, ||R||=3.083e-11
# [step 3/10] converged in 2 iters, ||R||=3.840e-11
# [step 3/10] converged in 2 iters, ||R||=2.059e-10
# [step 3/10] converged in 2 iters, ||R||=2.618e-10
# [step 3/10] converged in 2 iters, ||R||=7.975e-11
# [step 3/10] converged in 2 iters, ||R||=3.966e-11
# [step 3/10] converged in 2 iters, ||R||=1.072e-10
# [step 3/10] converged in 2 iters, ||R||=1.859e-10
# [step 3/10] converged in 2 iters, ||R||=4.231e-10
# [step 3/10] converged in 2 iters, ||R||=3.805e-11
# [step 3/10] converged in 2 iters, ||R||=5.174e-11
# [step 3/10] converged in 2 iters, ||R||=8.357e-11
# [step 3/10] converged in 2 iters, ||R||=3.166e-11
# [step 4/10] converged in 2 iters, ||R||=7.854e-11
# [step 4/10] converged in 2 iters, ||R||=3.878e-11
# [step 4/10] converged in 2 iters, ||R||=1.838e-10
# [step 4/10] converged in 2 iters, ||R||=2.609e-10
# [step 4/10] converged in 2 iters, ||R||=2.055e-10
# [step 4/10] converged in 2 iters, ||R||=3.861e-11
# [step 4/10] converged in 2 iters, ||R||=5.223e-11
# [step 4/10] converged in 2 iters, ||R||=3.067e-11
# [step 4/10] converged in 2 iters, ||R||=3.924e-11
# [step 4/10] converged in 2 iters, ||R||=4.197e-10
# [step 4/10] converged in 2 iters, ||R||=8.267e-11
# [step 4/10] converged in 2 iters, ||R||=1.049e-10
# [step 5/10] converged in 2 iters, ||R||=8.032e-11
# [step 5/10] converged in 2 iters, ||R||=1.827e-10
# [step 5/10] converged in 2 iters, ||R||=4.010e-11
# [step 5/10] converged in 2 iters, ||R||=3.884e-11
# [step 5/10] converged in 2 iters, ||R||=2.590e-10
# [step 5/10] converged in 2 iters, ||R||=5.165e-11
# [step 5/10] converged in 2 iters, ||R||=4.161e-10
# [step 5/10] converged in 2 iters, ||R||=2.045e-10
# [step 5/10] converged in 2 iters, ||R||=3.991e-11
# [step 5/10] converged in 2 iters, ||R||=3.427e-11
# [step 5/10] converged in 2 iters, ||R||=8.450e-11
# [step 5/10] converged in 2 iters, ||R||=1.062e-10
# [step 6/10] converged in 2 iters, ||R||=7.924e-11
# [step 6/10] converged in 2 iters, ||R||=5.004e-11
# [step 6/10] converged in 2 iters, ||R||=3.932e-11
# [step 6/10] converged in 2 iters, ||R||=2.572e-10
# [step 6/10] converged in 2 iters, ||R||=4.140e-10
# [step 6/10] converged in 2 iters, ||R||=1.820e-10
# [step 6/10] converged in 2 iters, ||R||=3.914e-11
# [step 6/10] converged in 2 iters, ||R||=8.699e-11
# [step 6/10] converged in 2 iters, ||R||=3.407e-11
# [step 6/10] converged in 2 iters, ||R||=2.032e-10
# [step 6/10] converged in 2 iters, ||R||=1.052e-10
# [step 6/10] converged in 2 iters, ||R||=3.912e-11
# [step 7/10] converged in 2 iters, ||R||=7.841e-11
# [step 7/10] converged in 2 iters, ||R||=5.242e-11
# [step 7/10] converged in 2 iters, ||R||=3.910e-11
# [step 7/10] converged in 2 iters, ||R||=4.109e-10
# [step 7/10] converged in 2 iters, ||R||=2.551e-10
# [step 7/10] converged in 2 iters, ||R||=1.808e-10
# [step 7/10] converged in 2 iters, ||R||=1.051e-10
# [step 7/10] converged in 2 iters, ||R||=3.249e-11
# [step 7/10] converged in 2 iters, ||R||=3.956e-11
# [step 7/10] converged in 2 iters, ||R||=2.031e-10
# [step 7/10] converged in 2 iters, ||R||=8.450e-11
# [step 7/10] converged in 2 iters, ||R||=4.082e-11
# [step 8/10] converged in 2 iters, ||R||=7.888e-11
# [step 8/10] converged in 2 iters, ||R||=5.141e-11
# [step 8/10] converged in 2 iters, ||R||=3.039e-11
# [step 8/10] converged in 2 iters, ||R||=3.920e-11
# [step 8/10] converged in 2 iters, ||R||=1.808e-10
# [step 8/10] converged in 2 iters, ||R||=2.015e-10
# [step 8/10] converged in 2 iters, ||R||=4.102e-10
# [step 8/10] converged in 2 iters, ||R||=1.053e-10
# [step 8/10] converged in 2 iters, ||R||=2.510e-10
# [step 8/10] converged in 2 iters, ||R||=3.884e-11
# [step 8/10] converged in 2 iters, ||R||=3.875e-11
# [step 8/10] converged in 2 iters, ||R||=8.228e-11
# [step 9/10] converged in 2 iters, ||R||=7.928e-11
# [step 9/10] converged in 2 iters, ||R||=5.109e-11
# [step 9/10] converged in 2 iters, ||R||=3.911e-11
# [step 9/10] converged in 2 iters, ||R||=4.045e-10
# [step 9/10] converged in 2 iters, ||R||=3.179e-11
# [step 9/10] converged in 2 iters, ||R||=1.795e-10
# [step 9/10] converged in 2 iters, ||R||=2.013e-10
# [step 9/10] converged in 2 iters, ||R||=1.039e-10
# [step 9/10] converged in 2 iters, ||R||=2.528e-10
# [step 9/10] converged in 2 iters, ||R||=3.856e-11
# [step 9/10] converged in 2 iters, ||R||=8.159e-11
# [step 9/10] converged in 2 iters, ||R||=3.748e-11
# [step 10/10] converged in 2 iters, ||R||=7.757e-11
#   Sample 6: max displacement=9.462e-03
# [step 10/10] converged in 2 iters, ||R||=3.857e-11
#   Sample 9: max displacement=7.068e-03
# [step 10/10] converged in 2 iters, ||R||=4.991e-11
#   Sample 12: max displacement=8.748e-03
# [step 10/10] converged in 2 iters, ||R||=4.007e-10
#   Sample 8: max displacement=1.104e-02
# [step 10/10] converged in 2 iters, ||R||=2.009e-10
# [step 10/10] converged in 2 iters, ||R||=1.747e-10
#   Sample 4: max displacement=1.081e-02
#   Sample 2: max displacement=9.917e-03
# [step 10/10] converged in 2 iters, ||R||=3.252e-11
#   Sample 10: max displacement=7.023e-03
# [step 10/10] converged in 2 iters, ||R||=2.495e-10
#   Sample 5: max displacement=1.072e-02
# [step 10/10] converged in 2 iters, ||R||=3.867e-11
#   Sample 7: max displacement=7.284e-03
# [step 10/10] converged in 2 iters, ||R||=3.958e-11
# Completed 10/200 samples
#   Sample 1: max displacement=6.210e-03
# [step 10/10] converged in 2 iters, ||R||=8.313e-11
#   Sample 3: max displacement=8.111e-03
# [step 10/10] converged in 2 iters, ||R||=1.018e-10
#   Sample 11: max displacement=8.811e-03
# [step 1/10] converged in 2 iters, ||R||=2.587e-10
# [step 1/10] converged in 2 iters, ||R||=1.275e-10
# [step 1/10] converged in 2 iters, ||R||=3.211e-10
# [step 1/10] converged in 2 iters, ||R||=7.225e-11
# [step 1/10] converged in 2 iters, ||R||=7.347e-11
# [step 1/10] converged in 2 iters, ||R||=1.126e-10
# [step 1/10] converged in 2 iters, ||R||=5.025e-10
# [step 1/10] converged in 2 iters, ||R||=1.579e-10
# [step 1/10] converged in 2 iters, ||R||=2.097e-10
# [step 1/10] converged in 2 iters, ||R||=3.068e-10
# [step 1/10] converged in 2 iters, ||R||=6.083e-10
# [step 1/10] converged in 2 iters, ||R||=5.794e-11
# [step 2/10] converged in 2 iters, ||R||=2.552e-10
# [step 2/10] converged in 2 iters, ||R||=3.175e-10
# [step 2/10] converged in 2 iters, ||R||=1.272e-10
# [step 2/10] converged in 2 iters, ||R||=7.261e-11
# [step 2/10] converged in 2 iters, ||R||=7.235e-11
# [step 2/10] converged in 2 iters, ||R||=1.133e-10
# [step 2/10] converged in 2 iters, ||R||=1.573e-10
# [step 2/10] converged in 2 iters, ||R||=4.995e-10
# [step 2/10] converged in 2 iters, ||R||=2.093e-10
# [step 2/10] converged in 2 iters, ||R||=3.047e-10
# [step 2/10] converged in 2 iters, ||R||=6.042e-10
# [step 2/10] converged in 2 iters, ||R||=5.746e-11
# [step 3/10] converged in 2 iters, ||R||=1.275e-10
# [step 3/10] converged in 2 iters, ||R||=2.540e-10
# [step 3/10] converged in 2 iters, ||R||=3.158e-10
# [step 3/10] converged in 2 iters, ||R||=7.088e-11
# [step 3/10] converged in 2 iters, ||R||=2.085e-10
# [step 3/10] converged in 2 iters, ||R||=4.951e-10
# [step 3/10] converged in 2 iters, ||R||=1.132e-10
# [step 3/10] converged in 2 iters, ||R||=1.567e-10
# [step 3/10] converged in 2 iters, ||R||=7.252e-11
# [step 3/10] converged in 2 iters, ||R||=5.990e-10
# [step 3/10] converged in 2 iters, ||R||=3.042e-10
# [step 3/10] converged in 2 iters, ||R||=5.839e-11
# [step 4/10] converged in 2 iters, ||R||=1.260e-10
# [step 4/10] converged in 2 iters, ||R||=2.527e-10
# [step 4/10] converged in 2 iters, ||R||=3.127e-10
# [step 4/10] converged in 2 iters, ||R||=2.084e-10
# [step 4/10] converged in 2 iters, ||R||=7.225e-11
# [step 4/10] converged in 2 iters, ||R||=1.132e-10
# [step 4/10] converged in 2 iters, ||R||=4.908e-10
# [step 4/10] converged in 2 iters, ||R||=1.555e-10
# [step 4/10] converged in 2 iters, ||R||=7.281e-11
# [step 4/10] converged in 2 iters, ||R||=3.019e-10
# [step 4/10] converged in 2 iters, ||R||=5.960e-10
# [step 4/10] converged in 2 iters, ||R||=5.806e-11
# [step 5/10] converged in 2 iters, ||R||=2.505e-10
# [step 5/10] converged in 2 iters, ||R||=1.275e-10
# [step 5/10] converged in 2 iters, ||R||=3.113e-10
# [step 5/10] converged in 2 iters, ||R||=2.072e-10
# [step 5/10] converged in 2 iters, ||R||=1.129e-10
# [step 5/10] converged in 2 iters, ||R||=7.197e-11
# [step 5/10] converged in 2 iters, ||R||=7.185e-11
# [step 5/10] converged in 2 iters, ||R||=1.536e-10
# [step 5/10] converged in 2 iters, ||R||=4.854e-10
# [step 5/10] converged in 2 iters, ||R||=3.003e-10
# [step 5/10] converged in 2 iters, ||R||=5.911e-10
# [step 5/10] converged in 2 iters, ||R||=5.732e-11
# [step 6/10] converged in 2 iters, ||R||=2.480e-10
# [step 6/10] converged in 2 iters, ||R||=1.264e-10
# [step 6/10] converged in 2 iters, ||R||=3.078e-10
# [step 6/10] converged in 2 iters, ||R||=1.542e-10
# [step 6/10] converged in 2 iters, ||R||=2.073e-10
# [step 6/10] converged in 2 iters, ||R||=7.254e-11
# [step 6/10] converged in 2 iters, ||R||=1.135e-10
# [step 6/10] converged in 2 iters, ||R||=7.270e-11
# [step 6/10] converged in 2 iters, ||R||=4.830e-10
# [step 6/10] converged in 2 iters, ||R||=2.979e-10
# [step 6/10] converged in 2 iters, ||R||=5.871e-10
# [step 6/10] converged in 2 iters, ||R||=5.678e-11
# [step 7/10] converged in 2 iters, ||R||=2.473e-10
# [step 7/10] converged in 2 iters, ||R||=1.257e-10
# [step 7/10] converged in 2 iters, ||R||=3.056e-10
# [step 7/10] converged in 2 iters, ||R||=1.526e-10
# [step 7/10] converged in 2 iters, ||R||=2.064e-10
# [step 7/10] converged in 2 iters, ||R||=7.170e-11
# [step 7/10] converged in 2 iters, ||R||=1.125e-10
# [step 7/10] converged in 2 iters, ||R||=7.278e-11
# [step 7/10] converged in 2 iters, ||R||=4.796e-10
# [step 7/10] converged in 2 iters, ||R||=2.953e-10
# [step 7/10] converged in 2 iters, ||R||=5.813e-10
# [step 7/10] converged in 2 iters, ||R||=5.748e-11
# [step 8/10] converged in 2 iters, ||R||=2.459e-10
# [step 8/10] converged in 2 iters, ||R||=1.263e-10
# [step 8/10] converged in 2 iters, ||R||=3.048e-10
# [step 8/10] converged in 2 iters, ||R||=1.129e-10
# [step 8/10] converged in 2 iters, ||R||=2.070e-10
# [step 8/10] converged in 2 iters, ||R||=7.012e-11
# [step 8/10] converged in 2 iters, ||R||=1.530e-10
# [step 8/10] converged in 2 iters, ||R||=2.947e-10
# [step 8/10] converged in 2 iters, ||R||=7.336e-11
# [step 8/10] converged in 2 iters, ||R||=4.758e-10
# [step 8/10] converged in 2 iters, ||R||=5.772e-10
# [step 8/10] converged in 2 iters, ||R||=5.524e-11
# [step 9/10] converged in 2 iters, ||R||=2.434e-10
# [step 9/10] converged in 2 iters, ||R||=1.254e-10
# [step 9/10] converged in 2 iters, ||R||=3.030e-10
# [step 9/10] converged in 2 iters, ||R||=1.114e-10
# [step 9/10] converged in 2 iters, ||R||=2.060e-10
# [step 9/10] converged in 2 iters, ||R||=7.172e-11
# [step 9/10] converged in 2 iters, ||R||=1.518e-10
# [step 9/10] converged in 2 iters, ||R||=2.918e-10
# [step 9/10] converged in 2 iters, ||R||=7.256e-11
# [step 9/10] converged in 2 iters, ||R||=4.719e-10
# [step 9/10] converged in 2 iters, ||R||=5.728e-10
# [step 9/10] converged in 2 iters, ||R||=5.866e-11
# [step 10/10] converged in 2 iters, ||R||=2.423e-10
#   Sample 14: max displacement=1.120e-02
# [step 10/10] converged in 2 iters, ||R||=3.001e-10
#   Sample 15: max displacement=1.293e-02
# [step 10/10] converged in 2 iters, ||R||=1.254e-10
#   Sample 13: max displacement=1.023e-02
# [step 10/10] converged in 2 iters, ||R||=1.136e-10
#   Sample 17: max displacement=9.909e-03
# [step 10/10] converged in 2 iters, ||R||=2.064e-10
#   Sample 22: max displacement=1.143e-02
# [step 10/10] converged in 2 iters, ||R||=7.156e-11
# [step 10/10] converged in 2 iters, ||R||=2.913e-10
#   Sample 19: max displacement=7.998e-03
#   Sample 24: max displacement=1.100e-02
# [step 10/10] converged in 2 iters, ||R||=7.172e-11
# Completed 20/200 samples
#   Sample 18: max displacement=8.785e-03
# [step 10/10] converged in 2 iters, ||R||=1.512e-10
#   Sample 16: max displacement=9.784e-03
# [step 10/10] converged in 2 iters, ||R||=4.672e-10
#   Sample 20: max displacement=1.201e-02
# [step 10/10] converged in 2 iters, ||R||=5.664e-10
#   Sample 21: max displacement=1.219e-02
# [step 10/10] converged in 2 iters, ||R||=5.856e-11
#   Sample 23: max displacement=8.294e-03
# [step 1/10] converged in 2 iters, ||R||=1.581e-10
# [step 1/10] converged in 2 iters, ||R||=2.878e-11
# [step 1/10] converged in 2 iters, ||R||=5.438e-11
# [step 1/10] converged in 2 iters, ||R||=1.640e-10
# [step 1/10] converged in 2 iters, ||R||=2.121e-10
# [step 1/10] converged in 2 iters, ||R||=1.367e-10
# [step 1/10] converged in 2 iters, ||R||=1.907e-10
# [step 1/10] converged in 2 iters, ||R||=7.750e-11
# [step 1/10] converged in 2 iters, ||R||=3.541e-11
# [step 1/10] converged in 2 iters, ||R||=3.503e-10
# [step 1/10] converged in 2 iters, ||R||=2.158e-10
# [step 1/10] converged in 2 iters, ||R||=7.165e-10
# [step 2/10] converged in 2 iters, ||R||=1.564e-10
# [step 2/10] converged in 2 iters, ||R||=5.605e-11
# [step 2/10] converged in 2 iters, ||R||=3.071e-11
# [step 2/10] converged in 2 iters, ||R||=1.636e-10
# [step 2/10] converged in 2 iters, ||R||=2.113e-10
# [step 2/10] converged in 2 iters, ||R||=1.352e-10
# [step 2/10] converged in 2 iters, ||R||=1.907e-10
# [step 2/10] converged in 2 iters, ||R||=3.449e-11
# [step 2/10] converged in 2 iters, ||R||=7.676e-11
# [step 2/10] converged in 2 iters, ||R||=3.475e-10
# [step 2/10] converged in 2 iters, ||R||=7.085e-10
# [step 2/10] converged in 2 iters, ||R||=2.159e-10
# [step 3/10] converged in 2 iters, ||R||=1.562e-10
# [step 3/10] converged in 2 iters, ||R||=5.608e-11
# [step 3/10] converged in 2 iters, ||R||=2.952e-11
# [step 3/10] converged in 2 iters, ||R||=1.635e-10
# [step 3/10] converged in 2 iters, ||R||=2.105e-10
# [step 3/10] converged in 2 iters, ||R||=1.861e-10
# [step 3/10] converged in 2 iters, ||R||=3.491e-11
# [step 3/10] converged in 2 iters, ||R||=1.355e-10
# [step 3/10] converged in 2 iters, ||R||=7.644e-11
# [step 3/10] converged in 2 iters, ||R||=3.454e-10
# [step 3/10] converged in 2 iters, ||R||=7.049e-10
# [step 3/10] converged in 2 iters, ||R||=2.154e-10
# [step 4/10] converged in 2 iters, ||R||=1.543e-10
# [step 4/10] converged in 2 iters, ||R||=5.523e-11
# [step 4/10] converged in 2 iters, ||R||=2.816e-11
# [step 4/10] converged in 2 iters, ||R||=1.634e-10
# [step 4/10] converged in 2 iters, ||R||=2.089e-10
# [step 4/10] converged in 2 iters, ||R||=1.875e-10
# [step 4/10] converged in 2 iters, ||R||=3.418e-11
# [step 4/10] converged in 2 iters, ||R||=1.351e-10
# [step 4/10] converged in 2 iters, ||R||=7.793e-11
# [step 4/10] converged in 2 iters, ||R||=3.427e-10
# [step 4/10] converged in 2 iters, ||R||=6.980e-10
# [step 4/10] converged in 2 iters, ||R||=2.138e-10
# [step 5/10] converged in 2 iters, ||R||=1.540e-10
# [step 5/10] converged in 2 iters, ||R||=5.558e-11
# [step 5/10] converged in 2 iters, ||R||=2.793e-11
# [step 5/10] converged in 2 iters, ||R||=1.638e-10
# [step 5/10] converged in 2 iters, ||R||=2.062e-10
# [step 5/10] converged in 2 iters, ||R||=1.843e-10
# [step 5/10] converged in 2 iters, ||R||=3.543e-11
# [step 5/10] converged in 2 iters, ||R||=1.346e-10
# [step 5/10] converged in 2 iters, ||R||=3.403e-10
# [step 5/10] converged in 2 iters, ||R||=7.593e-11
# [step 5/10] converged in 2 iters, ||R||=2.126e-10
# [step 5/10] converged in 2 iters, ||R||=6.920e-10
# [step 6/10] converged in 2 iters, ||R||=1.539e-10
# [step 6/10] converged in 2 iters, ||R||=5.354e-11
# [step 6/10] converged in 2 iters, ||R||=2.923e-11
# [step 6/10] converged in 2 iters, ||R||=1.638e-10
# [step 6/10] converged in 2 iters, ||R||=2.054e-10
# [step 6/10] converged in 2 iters, ||R||=1.864e-10
# [step 6/10] converged in 2 iters, ||R||=3.494e-11
# [step 6/10] converged in 2 iters, ||R||=3.382e-10
# [step 6/10] converged in 2 iters, ||R||=7.822e-11
# [step 6/10] converged in 2 iters, ||R||=1.337e-10
# [step 6/10] converged in 2 iters, ||R||=6.848e-10
# [step 6/10] converged in 2 iters, ||R||=2.125e-10
# [step 7/10] converged in 2 iters, ||R||=1.521e-10
# [step 7/10] converged in 2 iters, ||R||=5.548e-11
# [step 7/10] converged in 2 iters, ||R||=2.996e-11
# [step 7/10] converged in 2 iters, ||R||=1.623e-10
# [step 7/10] converged in 2 iters, ||R||=2.059e-10
# [step 7/10] converged in 2 iters, ||R||=7.616e-11
# [step 7/10] converged in 2 iters, ||R||=1.845e-10
# [step 7/10] converged in 2 iters, ||R||=3.555e-11
# [step 7/10] converged in 2 iters, ||R||=1.331e-10
# [step 7/10] converged in 2 iters, ||R||=3.354e-10
# [step 7/10] converged in 2 iters, ||R||=2.117e-10
# [step 7/10] converged in 2 iters, ||R||=6.802e-10
# [step 8/10] converged in 2 iters, ||R||=1.538e-10
# [step 8/10] converged in 2 iters, ||R||=5.584e-11
# [step 8/10] converged in 2 iters, ||R||=2.780e-11
# [step 8/10] converged in 2 iters, ||R||=1.621e-10
# [step 8/10] converged in 2 iters, ||R||=2.031e-10
# [step 8/10] converged in 2 iters, ||R||=7.826e-11
# [step 8/10] converged in 2 iters, ||R||=1.832e-10
# [step 8/10] converged in 2 iters, ||R||=3.709e-11
# [step 8/10] converged in 2 iters, ||R||=1.328e-10
# [step 8/10] converged in 2 iters, ||R||=3.325e-10
# [step 8/10] converged in 2 iters, ||R||=2.100e-10
# [step 8/10] converged in 2 iters, ||R||=6.770e-10
# [step 9/10] converged in 2 iters, ||R||=1.502e-10
# [step 9/10] converged in 2 iters, ||R||=5.654e-11
# [step 9/10] converged in 2 iters, ||R||=2.812e-11
# [step 9/10] converged in 2 iters, ||R||=1.630e-10
# [step 9/10] converged in 2 iters, ||R||=2.030e-10
# [step 9/10] converged in 2 iters, ||R||=7.616e-11
# [step 9/10] converged in 2 iters, ||R||=1.829e-10
# [step 9/10] converged in 2 iters, ||R||=3.473e-11
# [step 9/10] converged in 2 iters, ||R||=1.314e-10
# [step 9/10] converged in 2 iters, ||R||=3.303e-10
# [step 9/10] converged in 2 iters, ||R||=2.108e-10
# [step 9/10] converged in 2 iters, ||R||=6.691e-10
# [step 10/10] converged in 2 iters, ||R||=1.494e-10
#   Sample 25: max displacement=1.064e-02
# [step 10/10] converged in 2 iters, ||R||=5.507e-11
#   Sample 27: max displacement=9.046e-03
# [step 10/10] converged in 2 iters, ||R||=3.005e-11
#   Sample 26: max displacement=6.264e-03
# [step 10/10] converged in 2 iters, ||R||=2.011e-10
#   Sample 30: max displacement=1.131e-02
# [step 10/10] converged in 2 iters, ||R||=1.620e-10
#   Sample 29: max displacement=1.081e-02
# [step 10/10] converged in 2 iters, ||R||=7.416e-11
# Completed 30/200 samples
#   Sample 32: max displacement=8.561e-03
# [step 10/10] converged in 2 iters, ||R||=3.519e-11
#   Sample 33: max displacement=6.863e-03
# [step 10/10] converged in 2 iters, ||R||=1.832e-10
#   Sample 31: max displacement=9.315e-03
# [step 10/10] converged in 2 iters, ||R||=1.316e-10
#   Sample 28: max displacement=9.780e-03
# [step 10/10] converged in 2 iters, ||R||=3.267e-10
#   Sample 34: max displacement=1.222e-02
# [step 10/10] converged in 2 iters, ||R||=2.096e-10
#   Sample 35: max displacement=1.195e-02
# [step 10/10] converged in 2 iters, ||R||=6.617e-10
#   Sample 36: max displacement=1.238e-02
# [step 1/10] converged in 2 iters, ||R||=3.279e-11
# [step 1/10] converged in 2 iters, ||R||=2.333e-10
# [step 1/10] converged in 2 iters, ||R||=1.908e-10
# [step 1/10] converged in 2 iters, ||R||=8.480e-10
# [step 1/10] converged in 2 iters, ||R||=8.738e-11
# [step 1/10] converged in 2 iters, ||R||=3.296e-10
# [step 1/10] converged in 2 iters, ||R||=3.413e-10
# [step 1/10] converged in 2 iters, ||R||=5.393e-10
# [step 1/10] converged in 2 iters, ||R||=1.675e-10
# [step 1/10] converged in 2 iters, ||R||=2.111e-10
# [step 1/10] converged in 2 iters, ||R||=2.430e-10
# [step 1/10] converged in 2 iters, ||R||=6.295e-11
# [step 2/10] converged in 2 iters, ||R||=2.314e-10
# [step 2/10] converged in 2 iters, ||R||=3.388e-11
# [step 2/10] converged in 2 iters, ||R||=1.888e-10
# [step 2/10] converged in 2 iters, ||R||=3.391e-10
# [step 2/10] converged in 2 iters, ||R||=3.279e-10
# [step 2/10] converged in 2 iters, ||R||=5.341e-10
# [step 2/10] converged in 2 iters, ||R||=8.678e-11
# [step 2/10] converged in 2 iters, ||R||=8.405e-10
# [step 2/10] converged in 2 iters, ||R||=1.670e-10
# [step 2/10] converged in 2 iters, ||R||=2.092e-10
# [step 2/10] converged in 2 iters, ||R||=2.431e-10
# [step 2/10] converged in 2 iters, ||R||=6.245e-11
# [step 3/10] converged in 2 iters, ||R||=2.317e-10
# [step 3/10] converged in 2 iters, ||R||=3.532e-11
# [step 3/10] converged in 2 iters, ||R||=1.873e-10
# [step 3/10] converged in 2 iters, ||R||=3.255e-10
# [step 3/10] converged in 2 iters, ||R||=5.308e-10
# [step 3/10] converged in 2 iters, ||R||=3.365e-10
# [step 3/10] converged in 2 iters, ||R||=8.327e-10
# [step 3/10] converged in 2 iters, ||R||=8.769e-11
# [step 3/10] converged in 2 iters, ||R||=1.655e-10
# [step 3/10] converged in 2 iters, ||R||=2.091e-10
# [step 3/10] converged in 2 iters, ||R||=2.395e-10
# [step 3/10] converged in 2 iters, ||R||=6.241e-11
# [step 4/10] converged in 2 iters, ||R||=2.291e-10
# [step 4/10] converged in 2 iters, ||R||=3.710e-11
# [step 4/10] converged in 2 iters, ||R||=1.882e-10
# [step 4/10] converged in 2 iters, ||R||=8.277e-10
# [step 4/10] converged in 2 iters, ||R||=3.334e-10
# [step 4/10] converged in 2 iters, ||R||=8.670e-11
# [step 4/10] converged in 2 iters, ||R||=5.257e-10
# [step 4/10] converged in 2 iters, ||R||=3.238e-10
# [step 4/10] converged in 2 iters, ||R||=1.665e-10
# [step 4/10] converged in 2 iters, ||R||=2.075e-10
# [step 4/10] converged in 2 iters, ||R||=2.363e-10
# [step 4/10] converged in 2 iters, ||R||=6.159e-11
# [step 5/10] converged in 2 iters, ||R||=2.277e-10
# [step 5/10] converged in 2 iters, ||R||=3.681e-11
# [step 5/10] converged in 2 iters, ||R||=1.858e-10
# [step 5/10] converged in 2 iters, ||R||=3.327e-10
# [step 5/10] converged in 2 iters, ||R||=8.701e-11
# [step 5/10] converged in 2 iters, ||R||=8.193e-10
# [step 5/10] converged in 2 iters, ||R||=3.210e-10
# [step 5/10] converged in 2 iters, ||R||=5.213e-10
# [step 5/10] converged in 2 iters, ||R||=1.643e-10
# [step 5/10] converged in 2 iters, ||R||=2.056e-10
# [step 5/10] converged in 2 iters, ||R||=2.382e-10
# [step 5/10] converged in 2 iters, ||R||=6.205e-11
# [step 6/10] converged in 2 iters, ||R||=2.256e-10
# [step 6/10] converged in 2 iters, ||R||=3.394e-11
# [step 6/10] converged in 2 iters, ||R||=1.837e-10
# [step 6/10] converged in 2 iters, ||R||=3.298e-10
# [step 6/10] converged in 2 iters, ||R||=8.593e-11
# [step 6/10] converged in 2 iters, ||R||=8.108e-10
# [step 6/10] converged in 2 iters, ||R||=3.195e-10
# [step 6/10] converged in 2 iters, ||R||=5.172e-10
# [step 6/10] converged in 2 iters, ||R||=1.614e-10
# [step 6/10] converged in 2 iters, ||R||=2.053e-10
# [step 6/10] converged in 2 iters, ||R||=2.364e-10
# [step 6/10] converged in 2 iters, ||R||=6.250e-11
# [step 7/10] converged in 2 iters, ||R||=2.232e-10
# [step 7/10] converged in 2 iters, ||R||=3.391e-11
# [step 7/10] converged in 2 iters, ||R||=1.831e-10
# [step 7/10] converged in 2 iters, ||R||=8.562e-11
# [step 7/10] converged in 2 iters, ||R||=3.276e-10
# [step 7/10] converged in 2 iters, ||R||=5.139e-10
# [step 7/10] converged in 2 iters, ||R||=8.036e-10
# [step 7/10] converged in 2 iters, ||R||=3.164e-10
# [step 7/10] converged in 2 iters, ||R||=2.041e-10
# [step 7/10] converged in 2 iters, ||R||=1.623e-10
# [step 7/10] converged in 2 iters, ||R||=2.344e-10
# [step 7/10] converged in 2 iters, ||R||=6.250e-11
# [step 8/10] converged in 2 iters, ||R||=2.227e-10
# [step 8/10] converged in 2 iters, ||R||=3.229e-11
# [step 8/10] converged in 2 iters, ||R||=1.821e-10
# [step 8/10] converged in 2 iters, ||R||=8.639e-11
# [step 8/10] converged in 2 iters, ||R||=3.250e-10
# [step 8/10] converged in 2 iters, ||R||=5.080e-10
# [step 8/10] converged in 2 iters, ||R||=7.970e-10
# [step 8/10] converged in 2 iters, ||R||=3.159e-10
# [step 8/10] converged in 2 iters, ||R||=2.029e-10
# [step 8/10] converged in 2 iters, ||R||=1.603e-10
# [step 8/10] converged in 2 iters, ||R||=2.346e-10
# [step 8/10] converged in 2 iters, ||R||=6.350e-11
# [step 9/10] converged in 2 iters, ||R||=2.215e-10
# [step 9/10] converged in 2 iters, ||R||=3.458e-11
# [step 9/10] converged in 2 iters, ||R||=1.820e-10
# [step 9/10] converged in 2 iters, ||R||=8.638e-11
# [step 9/10] converged in 2 iters, ||R||=5.050e-10
# [step 9/10] converged in 2 iters, ||R||=3.234e-10
# [step 9/10] converged in 2 iters, ||R||=3.129e-10
# [step 9/10] converged in 2 iters, ||R||=7.895e-10
# [step 9/10] converged in 2 iters, ||R||=1.608e-10
# [step 9/10] converged in 2 iters, ||R||=2.010e-10
# [step 9/10] converged in 2 iters, ||R||=2.323e-10
# [step 9/10] converged in 2 iters, ||R||=6.225e-11
# [step 10/10] converged in 2 iters, ||R||=2.202e-10
#   Sample 38: max displacement=1.118e-02
# [step 10/10] converged in 2 iters, ||R||=3.537e-11
#   Sample 37: max displacement=6.051e-03
# [step 10/10] converged in 2 iters, ||R||=1.775e-10
#   Sample 39: max displacement=9.873e-03
# [step 10/10] converged in 2 iters, ||R||=8.498e-11
# Completed 40/200 samples
#   Sample 41: max displacement=9.324e-03
# [step 10/10] converged in 2 iters, ||R||=3.213e-10
#   Sample 43: max displacement=1.153e-02
# [step 10/10] converged in 2 iters, ||R||=3.109e-10
#   Sample 42: max displacement=1.222e-02
# [step 10/10] converged in 2 iters, ||R||=5.013e-10
#   Sample 44: max displacement=1.255e-02
# [step 10/10] converged in 2 iters, ||R||=7.842e-10
#   Sample 40: max displacement=1.454e-02
# [step 10/10] converged in 2 iters, ||R||=1.575e-10
#   Sample 45: max displacement=9.662e-03
# [step 10/10] converged in 2 iters, ||R||=1.992e-10
#   Sample 46: max displacement=1.067e-02
# ...
#   Sample 171: max displacement=1.504e-02
# [step 10/10] converged in 2 iters, ||R||=5.633e-10
# Completed 170/200 samples
#   Sample 169: max displacement=1.082e-02
# [step 10/10] converged in 2 iters, ||R||=1.862e-09
#   Sample 170: max displacement=1.494e-02
# [step 10/10] converged in 2 iters, ||R||=9.612e-10
#   Sample 172: max displacement=1.539e-02
# [step 10/10] converged in 2 iters, ||R||=7.446e-10
#   Sample 174: max displacement=1.674e-02
# [step 10/10] converged in 2 iters, ||R||=1.246e-09
#   Sample 175: max displacement=1.519e-02
# [step 10/10] converged in 2 iters, ||R||=7.363e-10
#   Sample 177: max displacement=1.767e-02
# [step 10/10] converged in 2 iters, ||R||=4.786e-09
#   Sample 173: max displacement=2.098e-02
# [step 10/10] converged in 2 iters, ||R||=1.344e-09
#   Sample 176: max displacement=1.831e-02
# [step 10/10] converged in 2 iters, ||R||=1.127e-09
#   Sample 178: max displacement=1.531e-02
# [step 10/10] converged in 2 iters, ||R||=1.823e-09
# [step 10/10] converged in 2 iters, ||R||=3.196e-10
#   Sample 180: max displacement=1.919e-02
# Completed 180/200 samples
#   Sample 179: max displacement=1.346e-02
# [step 1/10] converged in 2 iters, ||R||=3.139e-09
# [step 1/10] converged in 2 iters, ||R||=2.052e-09
# [step 1/10] converged in 2 iters, ||R||=5.528e-10
# [step 1/10] converged in 2 iters, ||R||=3.858e-10
# [step 1/10] converged in 2 iters, ||R||=9.366e-10
# [step 1/10] converged in 2 iters, ||R||=1.042e-09
# [step 1/10] converged in 2 iters, ||R||=1.512e-09
# [step 1/10] converged in 2 iters, ||R||=2.895e-09
# [step 1/10] converged in 2 iters, ||R||=1.356e-09
# [step 1/10] converged in 2 iters, ||R||=5.648e-10
# [step 1/10] converged in 2 iters, ||R||=2.231e-09
# [step 1/10] converged in 2 iters, ||R||=8.071e-10
# [step 2/10] converged in 2 iters, ||R||=3.141e-09
# [step 2/10] converged in 2 iters, ||R||=2.046e-09
# [step 2/10] converged in 2 iters, ||R||=5.509e-10
# [step 2/10] converged in 2 iters, ||R||=9.346e-10
# [step 2/10] converged in 2 iters, ||R||=3.858e-10
# [step 2/10] converged in 2 iters, ||R||=1.038e-09
# [step 2/10] converged in 2 iters, ||R||=2.894e-09
# [step 2/10] converged in 2 iters, ||R||=1.502e-09
# [step 2/10] converged in 2 iters, ||R||=1.352e-09
# [step 2/10] converged in 2 iters, ||R||=5.662e-10
# [step 2/10] converged in 2 iters, ||R||=2.229e-09
# [step 2/10] converged in 2 iters, ||R||=8.024e-10
# [step 3/10] converged in 2 iters, ||R||=3.143e-09
# [step 3/10] converged in 2 iters, ||R||=2.040e-09
# [step 3/10] converged in 2 iters, ||R||=5.495e-10
# [step 3/10] converged in 2 iters, ||R||=9.333e-10
# [step 3/10] converged in 2 iters, ||R||=3.854e-10
# [step 3/10] converged in 2 iters, ||R||=1.035e-09
# [step 3/10] converged in 2 iters, ||R||=2.892e-09
# [step 3/10] converged in 2 iters, ||R||=1.492e-09
# [step 3/10] converged in 2 iters, ||R||=1.348e-09
# [step 3/10] converged in 2 iters, ||R||=5.663e-10
# [step 3/10] converged in 2 iters, ||R||=2.226e-09
# [step 3/10] converged in 2 iters, ||R||=7.972e-10
# [step 4/10] converged in 2 iters, ||R||=3.145e-09
# [step 4/10] converged in 2 iters, ||R||=2.034e-09
# [step 4/10] converged in 2 iters, ||R||=5.473e-10
# [step 4/10] converged in 2 iters, ||R||=9.316e-10
# [step 4/10] converged in 2 iters, ||R||=3.852e-10
# [step 4/10] converged in 2 iters, ||R||=2.891e-09
# [step 4/10] converged in 2 iters, ||R||=1.032e-09
# [step 4/10] converged in 2 iters, ||R||=1.482e-09
# [step 4/10] converged in 2 iters, ||R||=1.344e-09
# [step 4/10] converged in 2 iters, ||R||=5.666e-10
# [step 4/10] converged in 2 iters, ||R||=2.224e-09
# [step 4/10] converged in 2 iters, ||R||=7.939e-10
# [step 5/10] converged in 2 iters, ||R||=3.148e-09
# [step 5/10] converged in 2 iters, ||R||=2.028e-09
# [step 5/10] converged in 2 iters, ||R||=5.466e-10
# [step 5/10] converged in 2 iters, ||R||=3.852e-10
# [step 5/10] converged in 2 iters, ||R||=9.305e-10
# [step 5/10] converged in 2 iters, ||R||=2.889e-09
# [step 5/10] converged in 2 iters, ||R||=1.029e-09
# [step 5/10] converged in 2 iters, ||R||=1.341e-09
# [step 5/10] converged in 2 iters, ||R||=1.472e-09
# [step 5/10] converged in 2 iters, ||R||=5.676e-10
# [step 5/10] converged in 2 iters, ||R||=2.221e-09
# [step 5/10] converged in 2 iters, ||R||=7.914e-10
# [step 6/10] converged in 2 iters, ||R||=3.150e-09
# [step 6/10] converged in 2 iters, ||R||=2.023e-09
# [step 6/10] converged in 2 iters, ||R||=5.445e-10
# [step 6/10] converged in 2 iters, ||R||=3.851e-10
# [step 6/10] converged in 2 iters, ||R||=9.303e-10
# [step 6/10] converged in 2 iters, ||R||=2.887e-09
# [step 6/10] converged in 2 iters, ||R||=1.026e-09
# [step 6/10] converged in 2 iters, ||R||=1.336e-09
# [step 6/10] converged in 2 iters, ||R||=1.460e-09
# [step 6/10] converged in 2 iters, ||R||=5.682e-10
# [step 6/10] converged in 2 iters, ||R||=2.219e-09
# [step 6/10] converged in 2 iters, ||R||=7.881e-10
# [step 7/10] converged in 2 iters, ||R||=3.153e-09
# [step 7/10] converged in 2 iters, ||R||=2.017e-09
# [step 7/10] converged in 2 iters, ||R||=5.433e-10
# [step 7/10] converged in 2 iters, ||R||=3.851e-10
# [step 7/10] converged in 2 iters, ||R||=9.286e-10
# [step 7/10] converged in 2 iters, ||R||=2.886e-09
# [step 7/10] converged in 2 iters, ||R||=1.449e-09
# [step 7/10] converged in 2 iters, ||R||=1.023e-09
# [step 7/10] converged in 2 iters, ||R||=1.333e-09
# [step 7/10] converged in 2 iters, ||R||=5.686e-10
# [step 7/10] converged in 2 iters, ||R||=2.217e-09
# [step 7/10] converged in 2 iters, ||R||=7.843e-10
# [step 8/10] converged in 2 iters, ||R||=3.155e-09
# [step 8/10] converged in 2 iters, ||R||=2.012e-09
# [step 8/10] converged in 2 iters, ||R||=5.421e-10
# [step 8/10] converged in 2 iters, ||R||=3.851e-10
# [step 8/10] converged in 2 iters, ||R||=9.274e-10
# [step 8/10] converged in 2 iters, ||R||=2.886e-09
# [step 8/10] converged in 2 iters, ||R||=1.441e-09
# [step 8/10] converged in 2 iters, ||R||=1.020e-09
# [step 8/10] converged in 2 iters, ||R||=1.329e-09
# [step 8/10] converged in 2 iters, ||R||=5.687e-10
# [step 8/10] converged in 2 iters, ||R||=2.215e-09
# [step 8/10] converged in 2 iters, ||R||=7.806e-10
# [step 9/10] converged in 2 iters, ||R||=3.158e-09
# [step 9/10] converged in 2 iters, ||R||=2.007e-09
# [step 9/10] converged in 2 iters, ||R||=5.405e-10
# [step 9/10] converged in 2 iters, ||R||=3.842e-10
# [step 9/10] converged in 2 iters, ||R||=9.261e-10
# [step 9/10] converged in 2 iters, ||R||=2.885e-09
# [step 9/10] converged in 2 iters, ||R||=1.017e-09
# [step 9/10] converged in 2 iters, ||R||=1.432e-09
# [step 9/10] converged in 2 iters, ||R||=1.325e-09
# [step 9/10] converged in 2 iters, ||R||=5.698e-10
# [step 9/10] converged in 2 iters, ||R||=2.213e-09
# [step 9/10] converged in 2 iters, ||R||=7.774e-10
# [step 10/10] converged in 2 iters, ||R||=3.161e-09
#   Sample 181: max displacement=1.870e-02
# [step 10/10] converged in 2 iters, ||R||=2.002e-09
#   Sample 182: max displacement=1.899e-02
# [step 10/10] converged in 2 iters, ||R||=5.394e-10
#   Sample 183: max displacement=1.532e-02
# [step 10/10] converged in 2 iters, ||R||=3.845e-10
#   Sample 184: max displacement=1.274e-02
# [step 10/10] converged in 2 iters, ||R||=2.884e-09
#   Sample 188: max displacement=1.813e-02
# [step 10/10] converged in 2 iters, ||R||=9.248e-10
#   Sample 185: max displacement=1.590e-02
# [step 10/10] converged in 2 iters, ||R||=1.014e-09
#   Sample 187: max displacement=1.741e-02
# [step 10/10] converged in 2 iters, ||R||=1.421e-09
#   Sample 186: max displacement=1.896e-02
# [step 10/10] converged in 2 iters, ||R||=1.321e-09
#   Sample 189: max displacement=1.659e-02
# [step 10/10] converged in 2 iters, ||R||=5.690e-10
# Completed 190/200 samples
#   Sample 190: max displacement=1.311e-02
# [step 10/10] converged in 2 iters, ||R||=2.211e-09
#   Sample 191: max displacement=1.703e-02
# [step 10/10] converged in 2 iters, ||R||=7.734e-10
#   Sample 192: max displacement=1.678e-02
# [step 1/10] converged in 2 iters, ||R||=2.710e-10
# [step 1/10] converged in 2 iters, ||R||=4.301e-10
# [step 1/10] converged in 2 iters, ||R||=2.090e-09
# [step 1/10] converged in 2 iters, ||R||=1.094e-09
# [step 1/10] converged in 2 iters, ||R||=7.774e-10
# [step 1/10] converged in 2 iters, ||R||=1.494e-10
# [step 1/10] converged in 2 iters, ||R||=9.925e-10
# [step 1/10] converged in 2 iters, ||R||=1.454e-09
# [step 2/10] converged in 2 iters, ||R||=2.706e-10
# [step 2/10] converged in 2 iters, ||R||=4.308e-10
# [step 2/10] converged in 2 iters, ||R||=2.087e-09
# [step 2/10] converged in 2 iters, ||R||=1.092e-09
# [step 2/10] converged in 2 iters, ||R||=7.752e-10
# [step 2/10] converged in 2 iters, ||R||=1.497e-10
# [step 2/10] converged in 2 iters, ||R||=9.940e-10
# [step 2/10] converged in 2 iters, ||R||=1.448e-09
# [step 3/10] converged in 2 iters, ||R||=2.712e-10
# [step 3/10] converged in 2 iters, ||R||=4.307e-10
# [step 3/10] converged in 2 iters, ||R||=2.085e-09
# [step 3/10] converged in 2 iters, ||R||=1.090e-09
# [step 3/10] converged in 2 iters, ||R||=7.745e-10
# [step 3/10] converged in 2 iters, ||R||=1.441e-09
# [step 3/10] converged in 2 iters, ||R||=1.496e-10
# [step 3/10] converged in 2 iters, ||R||=9.954e-10
# [step 4/10] converged in 2 iters, ||R||=2.708e-10
# [step 4/10] converged in 2 iters, ||R||=4.314e-10
# [step 4/10] converged in 2 iters, ||R||=2.081e-09
# [step 4/10] converged in 2 iters, ||R||=1.088e-09
# [step 4/10] converged in 2 iters, ||R||=7.720e-10
# [step 4/10] converged in 2 iters, ||R||=1.435e-09
# [step 4/10] converged in 2 iters, ||R||=1.496e-10
# [step 4/10] converged in 2 iters, ||R||=9.965e-10
# [step 5/10] converged in 2 iters, ||R||=2.706e-10
# [step 5/10] converged in 2 iters, ||R||=4.317e-10
# [step 5/10] converged in 2 iters, ||R||=2.078e-09
# [step 5/10] converged in 2 iters, ||R||=1.085e-09
# [step 5/10] converged in 2 iters, ||R||=7.708e-10
# [step 5/10] converged in 2 iters, ||R||=9.986e-10
# [step 5/10] converged in 2 iters, ||R||=1.500e-10
# [step 5/10] converged in 2 iters, ||R||=1.428e-09
# [step 6/10] converged in 2 iters, ||R||=2.715e-10
# [step 6/10] converged in 2 iters, ||R||=4.324e-10
# [step 6/10] converged in 2 iters, ||R||=1.082e-09
# [step 6/10] converged in 2 iters, ||R||=2.075e-09
# [step 6/10] converged in 2 iters, ||R||=7.694e-10
# [step 6/10] converged in 2 iters, ||R||=9.987e-10
# [step 6/10] converged in 2 iters, ||R||=1.498e-10
# [step 6/10] converged in 2 iters, ||R||=1.423e-09
# [step 7/10] converged in 2 iters, ||R||=2.716e-10
# [step 7/10] converged in 2 iters, ||R||=4.326e-10
# [step 7/10] converged in 2 iters, ||R||=1.081e-09
# [step 7/10] converged in 2 iters, ||R||=2.073e-09
# [step 7/10] converged in 2 iters, ||R||=7.682e-10
# [step 7/10] converged in 2 iters, ||R||=1.000e-09
# [step 7/10] converged in 2 iters, ||R||=1.417e-09
# [step 7/10] converged in 2 iters, ||R||=1.497e-10
# [step 8/10] converged in 2 iters, ||R||=2.715e-10
# [step 8/10] converged in 2 iters, ||R||=4.327e-10
# [step 8/10] converged in 2 iters, ||R||=1.079e-09
# [step 8/10] converged in 2 iters, ||R||=2.070e-09
# [step 8/10] converged in 2 iters, ||R||=7.670e-10
# [step 8/10] converged in 2 iters, ||R||=1.002e-09
# [step 8/10] converged in 2 iters, ||R||=1.497e-10
# [step 8/10] converged in 2 iters, ||R||=1.410e-09
# [step 9/10] converged in 2 iters, ||R||=2.726e-10
# [step 9/10] converged in 2 iters, ||R||=1.077e-09
# [step 9/10] converged in 2 iters, ||R||=4.334e-10
# [step 9/10] converged in 2 iters, ||R||=2.068e-09
# [step 9/10] converged in 2 iters, ||R||=7.652e-10
# [step 9/10] converged in 2 iters, ||R||=1.004e-09
# [step 9/10] converged in 2 iters, ||R||=1.500e-10
# [step 9/10] converged in 2 iters, ||R||=1.405e-09
# [step 10/10] converged in 2 iters, ||R||=2.713e-10
#   Sample 193: max displacement=1.102e-02
# [step 10/10] converged in 2 iters, ||R||=1.075e-09
#   Sample 195: max displacement=1.561e-02
# [step 10/10] converged in 2 iters, ||R||=4.342e-10
#   Sample 194: max displacement=1.020e-02
# [step 10/10] converged in 2 iters, ||R||=2.065e-09
#   Sample 196: max displacement=1.606e-02
# [step 10/10] converged in 2 iters, ||R||=7.638e-10
#   Sample 197: max displacement=1.300e-02
# [step 10/10] converged in 2 iters, ||R||=1.004e-09
#   Sample 199: max displacement=1.270e-02
# [step 10/10] converged in 2 iters, ||R||=1.496e-10
#   Sample 198: max displacement=9.965e-03
# [step 10/10] converged in 2 iters, ||R||=1.399e-09
# Completed 200/200 samples
#   Sample 200: max displacement=1.942e-02
#
# Dataset generated with 200 successful samples out of 200
# Dataset split: Train=140, Val=30, Test=30
#
# Dataset saved to: /content/pfem_data/ood/fem_B2_arruda_boyce_ood
# $ /usr/bin/python3 -u -m omar_pfem.data.convert_B2_quad --h5_dir /content/pfem_data/ood/fem_B2_arruda_boyce_ood --out_dir /content/pfem_data/ood/npz_B2_arruda_boyce_ood
# Converting /content/pfem_data/ood/fem_B2_arruda_boyce_ood/hyperelastic_dataset_physics.h5 to training format (Q4 mesh, B2 ring)...
# Total samples: 200
# Valid samples: 200
# Using samples: 200
# Nodes: 441
# Domain: quarter ring R_in=1.0, R_out=2.0
# Elements: 400 Q4 elements
# theta=0 symmetry nodes (u_y=0): 21
# theta=pi/2 symmetry nodes (u_x=0): 21
# Inner boundary nodes: 21
# Inner boundary edges: 20
# Processing sample 1/200 (original index 0)
# Processing sample 11/200 (original index 10)
# Processing sample 21/200 (original index 20)
# Processing sample 31/200 (original index 30)
# Processing sample 41/200 (original index 40)
# Processing sample 51/200 (original index 50)
# Processing sample 61/200 (original index 60)
# Processing sample 71/200 (original index 70)
# Processing sample 81/200 (original index 80)
# Processing sample 91/200 (original index 90)
# Processing sample 101/200 (original index 100)
# Processing sample 111/200 (original index 110)
# Processing sample 121/200 (original index 120)
# Processing sample 131/200 (original index 130)
# Processing sample 141/200 (original index 140)
# Processing sample 151/200 (original index 150)
# Processing sample 161/200 (original index 160)
# Processing sample 171/200 (original index 170)
# Processing sample 181/200 (original index 180)
# Processing sample 191/200 (original index 190)
#
# Saving to /content/pfem_data/ood/npz_B2_arruda_boyce_ood/hyperelastic_training_data_q4.npz...
# Successfully saved 200 samples to /content/pfem_data/ood/npz_B2_arruda_boyce_ood/hyperelastic_training_data_q4.npz
# [B2_arruda_boyce] OOD dataset archived to /content/drive/MyDrive/pfem_run/results/datasets/ood/B2_arruda_boyce/hyperelastic_training_data_q4.npz
# $ /usr/bin/python3 -u -m omar_pfem.evaluate_ood --geometry B2 --material arruda_boyce --checkpoint /content/drive/MyDrive/pfem_run/results/B2_arruda_boyce/model_best.pt --id_path /content/drive/MyDrive/pfem_run/results/datasets/B2_arruda_boyce/hyperelastic_training_data_q4.npz --id_ntrain 800 --ood_path /content/pfem_data/ood/npz_B2_arruda_boyce_ood/hyperelastic_training_data_q4.npz --ntest 200 --out_json /content/drive/MyDrive/pfem_run/results/ood_eval/B2_arruda_boyce_ood_report.json
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Loaded checkpoint: /content/drive/MyDrive/pfem_run/results/B2_arruda_boyce/model_best.pt
#
# Material statistics in training set:
#   E: mean=1000.00, std=200.00, min=120.64, max=1791.61
#   nu: mean=0.3000, std=0.0484, min=0.2000, max=0.4000
#
# Force statistics in training set:
#   Force: mean=5.023, std=2.021, min=0.003, max=13.746
#   Nodes with force: 16800 / 352800
# In-distribution test set: 200 samples (samples [800:1000] of /content/drive/MyDrive/pfem_run/results/datasets/B2_arruda_boyce/hyperelastic_training_data_q4.npz)
# Out-of-distribution test set: 200 samples (/content/pfem_data/ood/npz_B2_arruda_boyce_ood/hyperelastic_training_data_q4.npz)
#
# ================================================================================
# OOD EVALUATION SUMMARY
# ================================================================================
# In-distribution val_error:     3.1116e-01
# Out-of-distribution val_error: 2.3771e-01
# Degradation factor (OOD/ID):   0.76x
# ================================================================================
# Full report written to /content/drive/MyDrive/pfem_run/results/ood_eval/B2_arruda_boyce_ood_report.json
#
# OOD evaluation complete -- see /content/drive/MyDrive/pfem_run/results/ood_eval

# %% [markdown]
# ## Cell 12 - Resolution-invariance study (10 independent trainings across mesh sizes)
#
# Per the advisor's request: "train on two different meshes and then
# training on further ... meshes (altogether 10) and showing the results
# are always the same." This trains the SAME protocol independently at
# each of `RES_STUDY_RESOLUTIONS` and compares the resulting validation
# errors side by side -- it does not need a new capability (Transolver is
# mesh-size-agnostic and the data-generation scripts already take mesh
# resolution as a CLI argument), just the orchestration driver
# `resolution_invariance_study.py`.
#
# **This is the single most expensive item in this notebook**: each
# resolution repeats the full generate-dataset + train pipeline (up to
# `CONTINUE_EPOCHS`, same early-stopping settings as the main 6 cases), so
# the whole cell is roughly 10x the cost of training one case. By default
# this runs for B1 x Neo-Hookean only (one geometry/material, matching the
# scope of the mesh-convergence cell above); add entries to
# `RES_STUDY_CASES` for more coverage if the compute budget allows it.
#
# Resumes cleanly if interrupted, the same way the main 6 cases do: a
# resolution that already finished (`model_final.pt`/`EARLY_STOPPED` under
# its Drive-backed `--out_dir`) is skipped entirely -- its dataset is never
# touched again, so a disconnect never forces regenerating an
# already-finished resolution's data. A resolution that was only partway
# done (dataset generated, training interrupted) restores its dataset from
# `--archive_dir` (Drive) instead of regenerating it, exactly mirroring
# `ensure_dataset`'s pattern for the 6 main cases. The summary table flags
# any resolution that hit the epoch cap without early-stopping -- treat
# those as lower bounds, not converged results.

# %%
RES_STUDY_RESOLUTIONS = "13,17,21,25,29,33,37,41,45,49"   # 10 values; 21 = this study's own mesh
RES_STUDY_CASES = [("B1", "neo_hookean")]                 # add more (geometry, material) pairs if budget allows

res_study_data_dir = os.path.join(DATA_DIR, "resolution_study")            # local scratch: fast, disposable
res_study_archive_dir = os.path.join(DATASETS_ARCHIVE_DIR, "resolution_study")  # Drive: durable, per-resolution NPZs
res_study_results_dir = os.path.join(RESULTS_DIR, "resolution_study")      # Drive: checkpoints/metrics/summary
os.makedirs(res_study_results_dir, exist_ok=True)

for geometry, material in RES_STUDY_CASES:
    name = case_name(geometry, material)
    case_out_dir = os.path.join(res_study_results_dir, name)
    os.makedirs(case_out_dir, exist_ok=True)
    summary_path = os.path.join(case_out_dir, "resolution_study_summary.json")
    if os.path.exists(summary_path):
        print(f"[{name}] resolution-invariance study already done -> {summary_path}, skipping.")
        continue

    run_streaming([
        sys.executable, "-u", "-m", "omar_pfem.resolution_invariance_study",
        "--geometry", geometry, "--material", material,
        "--resolutions", RES_STUDY_RESOLUTIONS,
        "--ntrain", str(NTRAIN), "--ntest", str(NTEST), "--n_workers", str(N_WORKERS),
        "--batch_size", str(PROTOCOL["batch_size"]),
        "--epochs", str(PROTOCOL["epochs"]),
        "--validate_every", str(PROTOCOL["validate_every"]),
        "--early_stop_patience", str(PROTOCOL["early_stop_patience"]),
        "--early_stop_min_delta", str(PROTOCOL["early_stop_min_delta"]),
        "--data_dir", os.path.join(res_study_data_dir, name),
        "--archive_dir", os.path.join(res_study_archive_dir, name),
        "--out_dir", case_out_dir,
    ], cwd=WORK_DIR, log_path=os.path.join(res_study_results_dir, f"{name}.log"))

print("\nResolution-invariance study complete -- see", res_study_results_dir)
# Out:
# Streaming output truncated to the last 5000 lines.
# [step 6/10] converged in 2 iters, ||R||=6.225e-10
# [step 6/10] converged in 2 iters, ||R||=9.750e-11
# [step 6/10] converged in 2 iters, ||R||=1.187e-10
# [step 6/10] converged in 2 iters, ||R||=1.010e-10
# [step 6/10] converged in 2 iters, ||R||=2.270e-11
# [step 6/10] converged in 2 iters, ||R||=3.239e-11
# [step 6/10] converged in 2 iters, ||R||=6.757e-12
# [step 6/10] converged in 2 iters, ||R||=7.893e-12
# [step 6/10] converged in 2 iters, ||R||=2.781e-11
# [step 6/10] converged in 2 iters, ||R||=7.444e-10
# [step 7/10] converged in 2 iters, ||R||=1.599e-10
# [step 7/10] converged in 2 iters, ||R||=5.549e-11
# [step 7/10] converged in 2 iters, ||R||=9.901e-11
# [step 7/10] converged in 2 iters, ||R||=6.386e-10
# [step 7/10] converged in 2 iters, ||R||=1.198e-10
# [step 7/10] converged in 2 iters, ||R||=1.020e-10
# [step 7/10] converged in 2 iters, ||R||=2.331e-11
# [step 7/10] converged in 2 iters, ||R||=3.257e-11
# [step 7/10] converged in 2 iters, ||R||=7.055e-12
# [step 7/10] converged in 2 iters, ||R||=8.102e-12
# [step 7/10] converged in 2 iters, ||R||=2.788e-11
# [step 7/10] converged in 2 iters, ||R||=7.631e-10
# [step 8/10] converged in 2 iters, ||R||=1.628e-10
# [step 8/10] converged in 2 iters, ||R||=5.645e-11
# [step 8/10] converged in 2 iters, ||R||=1.006e-10
# [step 8/10] converged in 2 iters, ||R||=6.552e-10
# [step 8/10] converged in 2 iters, ||R||=1.033e-10
# [step 8/10] converged in 2 iters, ||R||=1.212e-10
# [step 8/10] converged in 2 iters, ||R||=3.279e-11
# [step 8/10] converged in 2 iters, ||R||=2.360e-11
# [step 8/10] converged in 2 iters, ||R||=6.946e-12
# [step 8/10] converged in 2 iters, ||R||=2.838e-11
# [step 8/10] converged in 2 iters, ||R||=8.250e-12
# [step 8/10] converged in 2 iters, ||R||=7.823e-10
# [step 9/10] converged in 2 iters, ||R||=1.654e-10
# [step 9/10] converged in 2 iters, ||R||=5.724e-11
# [step 9/10] converged in 2 iters, ||R||=1.022e-10
# [step 9/10] converged in 2 iters, ||R||=6.720e-10
# [step 9/10] converged in 2 iters, ||R||=1.045e-10
# [step 9/10] converged in 2 iters, ||R||=1.227e-10
# [step 9/10] converged in 2 iters, ||R||=3.309e-11
# [step 9/10] converged in 2 iters, ||R||=2.352e-11
# [step 9/10] converged in 2 iters, ||R||=7.171e-12
# [step 9/10] converged in 2 iters, ||R||=2.877e-11
# [step 9/10] converged in 2 iters, ||R||=8.018e-12
# [step 9/10] converged in 2 iters, ||R||=8.024e-10
# [step 10/10] converged in 2 iters, ||R||=1.685e-10
#   Sample 265: max displacement=7.507e-03
# [step 10/10] converged in 2 iters, ||R||=5.813e-11
#   Sample 266: max displacement=6.241e-03
# [step 10/10] converged in 2 iters, ||R||=1.039e-10
#   Sample 267: max displacement=7.189e-03
# [step 10/10] converged in 2 iters, ||R||=6.895e-10
#   Sample 268: max displacement=9.057e-03
# [step 10/10] converged in 2 iters, ||R||=1.058e-10
#   Sample 269: max displacement=6.749e-03
# [step 10/10] converged in 2 iters, ||R||=1.244e-10
# Completed 270/1000 samples
#   Sample 272: max displacement=6.374e-03
# [step 10/10] converged in 2 iters, ||R||=3.326e-11
#   Sample 270: max displacement=5.857e-03
# [step 10/10] converged in 2 iters, ||R||=2.373e-11
#   Sample 271: max displacement=4.393e-03
# [step 10/10] converged in 2 iters, ||R||=7.151e-12
#   Sample 273: max displacement=3.265e-03
# [step 10/10] converged in 2 iters, ||R||=2.899e-11
#   Sample 275: max displacement=5.386e-03
# [step 10/10] converged in 2 iters, ||R||=7.659e-12
#   Sample 274: max displacement=3.403e-03
# [step 10/10] converged in 2 iters, ||R||=8.232e-10
#   Sample 276: max displacement=1.016e-02
# [step 1/10] converged in 2 iters, ||R||=1.031e-10
# [step 1/10] converged in 2 iters, ||R||=1.519e-11
# [step 1/10] converged in 2 iters, ||R||=1.742e-10
# [step 1/10] converged in 2 iters, ||R||=9.922e-10
# [step 1/10] converged in 2 iters, ||R||=1.100e-11
# [step 1/10] converged in 2 iters, ||R||=1.666e-11
# [step 1/10] converged in 2 iters, ||R||=3.760e-10
# [step 1/10] converged in 2 iters, ||R||=6.907e-12
# [step 1/10] converged in 2 iters, ||R||=1.161e-11
# [step 1/10] converged in 2 iters, ||R||=8.913e-12
# [step 1/10] converged in 2 iters, ||R||=3.073e-11
# [step 1/10] converged in 2 iters, ||R||=1.282e-10
# [step 2/10] converged in 2 iters, ||R||=1.050e-10
# [step 2/10] converged in 2 iters, ||R||=1.525e-11
# [step 2/10] converged in 2 iters, ||R||=1.773e-10
# [step 2/10] converged in 2 iters, ||R||=1.017e-09
# [step 2/10] converged in 2 iters, ||R||=1.082e-11
# [step 2/10] converged in 2 iters, ||R||=1.676e-11
# [step 2/10] converged in 2 iters, ||R||=3.839e-10
# [step 2/10] converged in 2 iters, ||R||=7.156e-12
# [step 2/10] converged in 2 iters, ||R||=1.177e-11
# [step 2/10] converged in 2 iters, ||R||=9.042e-12
# [step 2/10] converged in 2 iters, ||R||=3.103e-11
# [step 2/10] converged in 2 iters, ||R||=1.297e-10
# [step 3/10] converged in 2 iters, ||R||=1.066e-10
# [step 3/10] converged in 2 iters, ||R||=1.510e-11
# [step 3/10] converged in 2 iters, ||R||=1.809e-10
# [step 3/10] converged in 2 iters, ||R||=1.112e-11
# [step 3/10] converged in 2 iters, ||R||=1.043e-09
# [step 3/10] converged in 2 iters, ||R||=1.697e-11
# [step 3/10] converged in 2 iters, ||R||=3.922e-10
# [step 3/10] converged in 2 iters, ||R||=7.019e-12
# [step 3/10] converged in 2 iters, ||R||=1.164e-11
# [step 3/10] converged in 2 iters, ||R||=8.928e-12
# [step 3/10] converged in 2 iters, ||R||=3.135e-11
# [step 3/10] converged in 2 iters, ||R||=1.316e-10
# [step 4/10] converged in 2 iters, ||R||=1.086e-10
# [step 4/10] converged in 2 iters, ||R||=1.520e-11
# [step 4/10] converged in 2 iters, ||R||=1.844e-10
# [step 4/10] converged in 2 iters, ||R||=1.112e-11
# [step 4/10] converged in 2 iters, ||R||=1.069e-09
# [step 4/10] converged in 2 iters, ||R||=1.678e-11
# [step 4/10] converged in 2 iters, ||R||=4.006e-10
# [step 4/10] converged in 2 iters, ||R||=7.199e-12
# [step 4/10] converged in 2 iters, ||R||=1.191e-11
# [step 4/10] converged in 2 iters, ||R||=9.188e-12
# [step 4/10] converged in 2 iters, ||R||=3.159e-11
# [step 4/10] converged in 2 iters, ||R||=1.333e-10
# [step 5/10] converged in 2 iters, ||R||=1.108e-10
# [step 5/10] converged in 2 iters, ||R||=1.507e-11
# [step 5/10] converged in 2 iters, ||R||=1.879e-10
# [step 5/10] converged in 2 iters, ||R||=1.091e-11
# [step 5/10] converged in 2 iters, ||R||=1.096e-09
# [step 5/10] converged in 2 iters, ||R||=1.729e-11
# [step 5/10] converged in 2 iters, ||R||=4.095e-10
# [step 5/10] converged in 2 iters, ||R||=7.092e-12
# [step 5/10] converged in 2 iters, ||R||=1.213e-11
# [step 5/10] converged in 2 iters, ||R||=9.172e-12
# [step 5/10] converged in 2 iters, ||R||=3.231e-11
# [step 5/10] converged in 2 iters, ||R||=1.348e-10
# [step 6/10] converged in 2 iters, ||R||=1.129e-10
# [step 6/10] converged in 2 iters, ||R||=1.500e-11
# [step 6/10] converged in 2 iters, ||R||=1.916e-10
# [step 6/10] converged in 2 iters, ||R||=1.085e-11
# [step 6/10] converged in 2 iters, ||R||=1.720e-11
# [step 6/10] converged in 2 iters, ||R||=1.124e-09
# [step 6/10] converged in 2 iters, ||R||=4.181e-10
# [step 6/10] converged in 2 iters, ||R||=7.597e-12
# [step 6/10] converged in 2 iters, ||R||=1.190e-11
# [step 6/10] converged in 2 iters, ||R||=9.024e-12
# [step 6/10] converged in 2 iters, ||R||=3.261e-11
# [step 6/10] converged in 2 iters, ||R||=1.368e-10
# [step 7/10] converged in 2 iters, ||R||=1.151e-10
# [step 7/10] converged in 2 iters, ||R||=1.518e-11
# [step 7/10] converged in 2 iters, ||R||=1.952e-10
# [step 7/10] converged in 2 iters, ||R||=1.085e-11
# [step 7/10] converged in 2 iters, ||R||=1.731e-11
# [step 7/10] converged in 2 iters, ||R||=1.153e-09
# [step 7/10] converged in 2 iters, ||R||=4.273e-10
# [step 7/10] converged in 2 iters, ||R||=7.323e-12
# [step 7/10] converged in 2 iters, ||R||=1.218e-11
# [step 7/10] converged in 2 iters, ||R||=9.027e-12
# [step 7/10] converged in 2 iters, ||R||=3.330e-11
# [step 7/10] converged in 2 iters, ||R||=1.385e-10
# [step 8/10] converged in 2 iters, ||R||=1.173e-10
# [step 8/10] converged in 2 iters, ||R||=1.499e-11
# [step 8/10] converged in 2 iters, ||R||=1.994e-10
# [step 8/10] converged in 2 iters, ||R||=1.097e-11
# [step 8/10] converged in 2 iters, ||R||=1.183e-09
# [step 8/10] converged in 2 iters, ||R||=1.758e-11
# [step 8/10] converged in 2 iters, ||R||=4.363e-10
# [step 8/10] converged in 2 iters, ||R||=7.391e-12
# [step 8/10] converged in 2 iters, ||R||=1.205e-11
# [step 8/10] converged in 2 iters, ||R||=9.439e-12
# [step 8/10] converged in 2 iters, ||R||=3.399e-11
# [step 8/10] converged in 2 iters, ||R||=1.407e-10
# [step 9/10] converged in 2 iters, ||R||=1.195e-10
# [step 9/10] converged in 2 iters, ||R||=1.518e-11
# [step 9/10] converged in 2 iters, ||R||=2.030e-10
# [step 9/10] converged in 2 iters, ||R||=1.108e-11
# [step 9/10] converged in 2 iters, ||R||=1.213e-09
# [step 9/10] converged in 2 iters, ||R||=1.799e-11
# [step 9/10] converged in 2 iters, ||R||=4.463e-10
# [step 9/10] converged in 2 iters, ||R||=7.023e-12
# [step 9/10] converged in 2 iters, ||R||=1.227e-11
# [step 9/10] converged in 2 iters, ||R||=9.141e-12
# [step 9/10] converged in 2 iters, ||R||=3.436e-11
# [step 9/10] converged in 2 iters, ||R||=1.424e-10
# [step 10/10] converged in 2 iters, ||R||=1.217e-10
#   Sample 277: max displacement=7.060e-03
# [step 10/10] converged in 2 iters, ||R||=1.517e-11
#   Sample 278: max displacement=5.002e-03
# [step 10/10] converged in 2 iters, ||R||=2.072e-10
#   Sample 279: max displacement=7.502e-03
# [step 10/10] converged in 2 iters, ||R||=1.102e-11
# Completed 280/1000 samples
#   Sample 281: max displacement=4.409e-03
# [step 10/10] converged in 2 iters, ||R||=1.756e-11
#   Sample 282: max displacement=3.858e-03
# [step 10/10] converged in 2 iters, ||R||=1.245e-09
#   Sample 280: max displacement=1.027e-02
# [step 10/10] converged in 2 iters, ||R||=7.083e-12
#   Sample 284: max displacement=2.627e-03
# [step 10/10] converged in 2 iters, ||R||=4.558e-10
#   Sample 283: max displacement=8.728e-03
# [step 10/10] converged in 2 iters, ||R||=1.229e-11
#   Sample 285: max displacement=4.164e-03
# [step 10/10] converged in 2 iters, ||R||=9.323e-12
#   Sample 287: max displacement=3.574e-03
# [step 10/10] converged in 2 iters, ||R||=3.516e-11
#   Sample 286: max displacement=5.395e-03
# [step 10/10] converged in 2 iters, ||R||=1.442e-10
#   Sample 288: max displacement=6.618e-03
# [step 1/10] converged in 2 iters, ||R||=4.035e-11
# [step 1/10] converged in 2 iters, ||R||=1.155e-10
# [step 1/10] converged in 2 iters, ||R||=1.377e-10
# [step 1/10] converged in 2 iters, ||R||=2.764e-11
# [step 1/10] converged in 2 iters, ||R||=8.658e-11
# [step 1/10] converged in 2 iters, ||R||=2.682e-11
# [step 1/10] converged in 2 iters, ||R||=7.876e-12
# [step 1/10] converged in 2 iters, ||R||=1.175e-10
# [step 1/10] converged in 2 iters, ||R||=8.504e-12
# [step 1/10] converged in 2 iters, ||R||=8.804e-11
# [step 1/10] converged in 2 iters, ||R||=5.612e-11
# [step 1/10] converged in 2 iters, ||R||=8.025e-12
# [step 2/10] converged in 2 iters, ||R||=4.120e-11
# [step 2/10] converged in 2 iters, ||R||=1.179e-10
# [step 2/10] converged in 2 iters, ||R||=1.395e-10
# [step 2/10] converged in 2 iters, ||R||=2.793e-11
# [step 2/10] converged in 2 iters, ||R||=8.764e-11
# [step 2/10] converged in 2 iters, ||R||=2.712e-11
# [step 2/10] converged in 2 iters, ||R||=7.991e-12
# [step 2/10] converged in 2 iters, ||R||=1.199e-10
# [step 2/10] converged in 2 iters, ||R||=8.635e-12
# [step 2/10] converged in 2 iters, ||R||=8.972e-11
# [step 2/10] converged in 2 iters, ||R||=5.602e-11
# [step 2/10] converged in 2 iters, ||R||=7.836e-12
# [step 3/10] converged in 2 iters, ||R||=4.172e-11
# [step 3/10] converged in 2 iters, ||R||=1.202e-10
# [step 3/10] converged in 2 iters, ||R||=1.414e-10
# [step 3/10] converged in 2 iters, ||R||=2.841e-11
# [step 3/10] converged in 2 iters, ||R||=8.876e-11
# [step 3/10] converged in 2 iters, ||R||=2.766e-11
# [step 3/10] converged in 2 iters, ||R||=7.681e-12
# [step 3/10] converged in 2 iters, ||R||=1.221e-10
# [step 3/10] converged in 2 iters, ||R||=8.444e-12
# [step 3/10] converged in 2 iters, ||R||=9.132e-11
# [step 3/10] converged in 2 iters, ||R||=5.571e-11
# [step 3/10] converged in 2 iters, ||R||=8.112e-12
# [step 4/10] converged in 2 iters, ||R||=4.230e-11
# [step 4/10] converged in 2 iters, ||R||=1.226e-10
# [step 4/10] converged in 2 iters, ||R||=1.430e-10
# [step 4/10] converged in 2 iters, ||R||=2.886e-11
# [step 4/10] converged in 2 iters, ||R||=9.008e-11
# [step 4/10] converged in 2 iters, ||R||=2.777e-11
# [step 4/10] converged in 2 iters, ||R||=7.712e-12
# [step 4/10] converged in 2 iters, ||R||=1.246e-10
# [step 4/10] converged in 2 iters, ||R||=8.382e-12
# [step 4/10] converged in 2 iters, ||R||=9.270e-11
# [step 4/10] converged in 2 iters, ||R||=5.615e-11
# [step 4/10] converged in 2 iters, ||R||=7.872e-12
# [step 5/10] converged in 2 iters, ||R||=4.307e-11
# [step 5/10] converged in 2 iters, ||R||=1.253e-10
# [step 5/10] converged in 2 iters, ||R||=1.449e-10
# [step 5/10] converged in 2 iters, ||R||=2.942e-11
# [step 5/10] converged in 2 iters, ||R||=9.149e-11
# [step 5/10] converged in 2 iters, ||R||=2.816e-11
# [step 5/10] converged in 2 iters, ||R||=1.269e-10
# [step 5/10] converged in 2 iters, ||R||=7.852e-12
# [step 5/10] converged in 2 iters, ||R||=8.517e-12
# [step 5/10] converged in 2 iters, ||R||=9.458e-11
# [step 5/10] converged in 2 iters, ||R||=5.569e-11
# [step 5/10] converged in 2 iters, ||R||=7.905e-12
# [step 6/10] converged in 2 iters, ||R||=4.363e-11
# [step 6/10] converged in 2 iters, ||R||=1.465e-10
# [step 6/10] converged in 2 iters, ||R||=1.278e-10
# [step 6/10] converged in 2 iters, ||R||=2.961e-11
# [step 6/10] converged in 2 iters, ||R||=9.287e-11
# [step 6/10] converged in 2 iters, ||R||=2.843e-11
# [step 6/10] converged in 2 iters, ||R||=7.667e-12
# [step 6/10] converged in 2 iters, ||R||=1.296e-10
# [step 6/10] converged in 2 iters, ||R||=8.883e-12
# [step 6/10] converged in 2 iters, ||R||=9.643e-11
# [step 6/10] converged in 2 iters, ||R||=5.621e-11
# [step 6/10] converged in 2 iters, ||R||=7.895e-12
# [step 7/10] converged in 2 iters, ||R||=4.429e-11
# [step 7/10] converged in 2 iters, ||R||=1.482e-10
# [step 7/10] converged in 2 iters, ||R||=1.305e-10
# [step 7/10] converged in 2 iters, ||R||=3.000e-11
# [step 7/10] converged in 2 iters, ||R||=9.389e-11
# [step 7/10] converged in 2 iters, ||R||=2.876e-11
# [step 7/10] converged in 2 iters, ||R||=7.628e-12
# [step 7/10] converged in 2 iters, ||R||=1.322e-10
# [step 7/10] converged in 2 iters, ||R||=8.622e-12
# [step 7/10] converged in 2 iters, ||R||=9.781e-11
# [step 7/10] converged in 2 iters, ||R||=5.560e-11
# [step 7/10] converged in 2 iters, ||R||=8.155e-12
# [step 8/10] converged in 2 iters, ||R||=4.540e-11
# [step 8/10] converged in 2 iters, ||R||=1.332e-10
# [step 8/10] converged in 2 iters, ||R||=1.503e-10
# [step 8/10] converged in 2 iters, ||R||=3.067e-11
# [step 8/10] converged in 2 iters, ||R||=9.560e-11
# [step 8/10] converged in 2 iters, ||R||=2.888e-11
# [step 8/10] converged in 2 iters, ||R||=1.348e-10
# [step 8/10] converged in 2 iters, ||R||=7.825e-12
# [step 8/10] converged in 2 iters, ||R||=8.724e-12
# [step 8/10] converged in 2 iters, ||R||=9.997e-11
# [step 8/10] converged in 2 iters, ||R||=5.544e-11
# [step 8/10] converged in 2 iters, ||R||=8.164e-12
# [step 9/10] converged in 2 iters, ||R||=4.633e-11
# [step 9/10] converged in 2 iters, ||R||=1.520e-10
# [step 9/10] converged in 2 iters, ||R||=1.358e-10
# [step 9/10] converged in 2 iters, ||R||=3.078e-11
# [step 9/10] converged in 2 iters, ||R||=9.712e-11
# [step 9/10] converged in 2 iters, ||R||=2.955e-11
# [step 9/10] converged in 2 iters, ||R||=1.375e-10
# [step 9/10] converged in 2 iters, ||R||=7.946e-12
# [step 9/10] converged in 2 iters, ||R||=8.723e-12
# [step 9/10] converged in 2 iters, ||R||=1.017e-10
# [step 9/10] converged in 2 iters, ||R||=5.563e-11
# [step 9/10] converged in 2 iters, ||R||=8.122e-12
# [step 10/10] converged in 2 iters, ||R||=4.695e-11
#   Sample 289: max displacement=6.100e-03
# [step 10/10] converged in 2 iters, ||R||=1.538e-10
# Completed 290/1000 samples
#   Sample 291: max displacement=6.980e-03
# [step 10/10] converged in 2 iters, ||R||=1.389e-10
#   Sample 290: max displacement=7.689e-03
# [step 10/10] converged in 2 iters, ||R||=3.145e-11
#   Sample 292: max displacement=5.696e-03
# [step 10/10] converged in 2 iters, ||R||=9.853e-11
#   Sample 293: max displacement=6.724e-03
# [step 10/10] converged in 2 iters, ||R||=2.995e-11
#   Sample 294: max displacement=5.970e-03
# [step 10/10] converged in 2 iters, ||R||=1.405e-10
#   Sample 296: max displacement=7.699e-03
# [step 10/10] converged in 2 iters, ||R||=7.971e-12
#   Sample 295: max displacement=3.908e-03
# [step 10/10] converged in 2 iters, ||R||=9.103e-12
#   Sample 297: max displacement=3.630e-03
# [step 10/10] converged in 2 iters, ||R||=1.034e-10
#   Sample 298: max displacement=6.640e-03
# [step 10/10] converged in 2 iters, ||R||=5.556e-11
#   Sample 299: max displacement=6.497e-03
# [step 10/10] converged in 2 iters, ||R||=8.095e-12
# Completed 300/1000 samples
#   Sample 300: max displacement=3.773e-03
# [step 1/10] converged in 2 iters, ||R||=2.503e-11
# [step 1/10] converged in 2 iters, ||R||=2.695e-10
# [step 1/10] converged in 2 iters, ||R||=1.605e-11
# [step 1/10] converged in 2 iters, ||R||=8.209e-10
# [step 1/10] converged in 2 iters, ||R||=5.757e-11
# [step 1/10] converged in 2 iters, ||R||=2.982e-11
# [step 1/10] converged in 2 iters, ||R||=5.761e-12
# [step 1/10] converged in 2 iters, ||R||=7.882e-12
# [step 1/10] converged in 2 iters, ||R||=5.570e-11
# [step 1/10] converged in 2 iters, ||R||=7.714e-11
# [step 1/10] converged in 2 iters, ||R||=2.825e-11
# [step 1/10] converged in 2 iters, ||R||=9.857e-11
# [step 2/10] converged in 2 iters, ||R||=2.543e-11
# [step 2/10] converged in 2 iters, ||R||=2.753e-10
# [step 2/10] converged in 2 iters, ||R||=1.615e-11
# [step 2/10] converged in 2 iters, ||R||=8.414e-10
# [step 2/10] converged in 2 iters, ||R||=5.872e-11
# [step 2/10] converged in 2 iters, ||R||=3.014e-11
# [step 2/10] converged in 2 iters, ||R||=6.085e-12
# [step 2/10] converged in 2 iters, ||R||=5.601e-11
# [step 2/10] converged in 2 iters, ||R||=8.180e-12
# [step 2/10] converged in 2 iters, ||R||=7.845e-11
# [step 2/10] converged in 2 iters, ||R||=2.913e-11
# [step 2/10] converged in 2 iters, ||R||=1.002e-10
# [step 3/10] converged in 2 iters, ||R||=2.530e-11
# [step 3/10] converged in 2 iters, ||R||=2.811e-10
# [step 3/10] converged in 2 iters, ||R||=1.618e-11
# [step 3/10] converged in 2 iters, ||R||=8.629e-10
# [step 3/10] converged in 2 iters, ||R||=5.970e-11
# [step 3/10] converged in 2 iters, ||R||=3.047e-11
# [step 3/10] converged in 2 iters, ||R||=6.048e-12
# [step 3/10] converged in 2 iters, ||R||=5.609e-11
# [step 3/10] converged in 2 iters, ||R||=8.167e-12
# [step 3/10] converged in 2 iters, ||R||=7.966e-11
# [step 3/10] converged in 2 iters, ||R||=2.907e-11
# [step 3/10] converged in 2 iters, ||R||=1.015e-10
# [step 4/10] converged in 2 iters, ||R||=2.575e-11
# [step 4/10] converged in 2 iters, ||R||=2.875e-10
# [step 4/10] converged in 2 iters, ||R||=1.641e-11
# [step 4/10] converged in 2 iters, ||R||=8.848e-10
# [step 4/10] converged in 2 iters, ||R||=3.087e-11
# [step 4/10] converged in 2 iters, ||R||=6.069e-11
# [step 4/10] converged in 2 iters, ||R||=5.832e-12
# [step 4/10] converged in 2 iters, ||R||=5.622e-11
# [step 4/10] converged in 2 iters, ||R||=8.189e-12
# [step 4/10] converged in 2 iters, ||R||=8.099e-11
# [step 4/10] converged in 2 iters, ||R||=2.920e-11
# [step 4/10] converged in 2 iters, ||R||=1.033e-10
# [step 5/10] converged in 2 iters, ||R||=2.588e-11
# [step 5/10] converged in 2 iters, ||R||=2.939e-10
# [step 5/10] converged in 2 iters, ||R||=1.651e-11
# [step 5/10] converged in 2 iters, ||R||=9.069e-10
# [step 5/10] converged in 2 iters, ||R||=3.148e-11
# [step 5/10] converged in 2 iters, ||R||=6.176e-11
# [step 5/10] converged in 2 iters, ||R||=5.974e-12
# [step 5/10] converged in 2 iters, ||R||=5.634e-11
# [step 5/10] converged in 2 iters, ||R||=8.200e-12
# [step 5/10] converged in 2 iters, ||R||=8.221e-11
# [step 5/10] converged in 2 iters, ||R||=2.984e-11
# [step 5/10] converged in 2 iters, ||R||=1.046e-10
# [step 6/10] converged in 2 iters, ||R||=2.594e-11
# [step 6/10] converged in 2 iters, ||R||=3.005e-10
# [step 6/10] converged in 2 iters, ||R||=9.301e-10
# [step 6/10] converged in 2 iters, ||R||=1.647e-11
# [step 6/10] converged in 2 iters, ||R||=6.304e-11
# [step 6/10] converged in 2 iters, ||R||=3.179e-11
# [step 6/10] converged in 2 iters, ||R||=5.811e-12
# [step 6/10] converged in 2 iters, ||R||=5.650e-11
# [step 6/10] converged in 2 iters, ||R||=7.994e-12
# [step 6/10] converged in 2 iters, ||R||=2.973e-11
# [step 6/10] converged in 2 iters, ||R||=8.373e-11
# [step 6/10] converged in 2 iters, ||R||=1.061e-10
# [step 7/10] converged in 2 iters, ||R||=2.622e-11
# [step 7/10] converged in 2 iters, ||R||=3.073e-10
# [step 7/10] converged in 2 iters, ||R||=1.658e-11
# [step 7/10] converged in 2 iters, ||R||=9.536e-10
# [step 7/10] converged in 2 iters, ||R||=6.402e-11
# [step 7/10] converged in 2 iters, ||R||=3.236e-11
# [step 7/10] converged in 2 iters, ||R||=5.963e-12
# [step 7/10] converged in 2 iters, ||R||=5.657e-11
# [step 7/10] converged in 2 iters, ||R||=8.073e-12
# [step 7/10] converged in 2 iters, ||R||=3.030e-11
# [step 7/10] converged in 2 iters, ||R||=8.526e-11
# [step 7/10] converged in 2 iters, ||R||=1.078e-10
# [step 8/10] converged in 2 iters, ||R||=2.649e-11
# [step 8/10] converged in 2 iters, ||R||=3.143e-10
# [step 8/10] converged in 2 iters, ||R||=1.636e-11
# [step 8/10] converged in 2 iters, ||R||=9.785e-10
# [step 8/10] converged in 2 iters, ||R||=5.827e-12
# [step 8/10] converged in 2 iters, ||R||=6.523e-11
# [step 8/10] converged in 2 iters, ||R||=3.304e-11
# [step 8/10] converged in 2 iters, ||R||=5.690e-11
# [step 8/10] converged in 2 iters, ||R||=8.253e-12
# [step 8/10] converged in 2 iters, ||R||=3.094e-11
# [step 8/10] converged in 2 iters, ||R||=8.657e-11
# [step 8/10] converged in 2 iters, ||R||=1.097e-10
# [step 9/10] converged in 2 iters, ||R||=2.668e-11
# [step 9/10] converged in 2 iters, ||R||=3.219e-10
# [step 9/10] converged in 2 iters, ||R||=1.665e-11
# [step 9/10] converged in 2 iters, ||R||=1.003e-09
# [step 9/10] converged in 2 iters, ||R||=6.638e-11
# [step 9/10] converged in 2 iters, ||R||=5.953e-12
# [step 9/10] converged in 2 iters, ||R||=3.321e-11
# [step 9/10] converged in 2 iters, ||R||=5.721e-11
# [step 9/10] converged in 2 iters, ||R||=7.998e-12
# [step 9/10] converged in 2 iters, ||R||=3.101e-11
# [step 9/10] converged in 2 iters, ||R||=8.800e-11
# [step 9/10] converged in 2 iters, ||R||=1.108e-10
# [step 10/10] converged in 2 iters, ||R||=2.700e-11
#   Sample 301: max displacement=5.237e-03
# [step 10/10] converged in 2 iters, ||R||=3.291e-10
#   Sample 303: max displacement=8.625e-03
# [step 10/10] converged in 2 iters, ||R||=1.029e-09
#   Sample 304: max displacement=8.904e-03
# [step 10/10] converged in 2 iters, ||R||=1.679e-11
#   Sample 302: max displacement=4.400e-03
# [step 10/10] converged in 2 iters, ||R||=6.762e-11
#   Sample 305: max displacement=7.270e-03
# [step 10/10] converged in 2 iters, ||R||=5.993e-12
#   Sample 308: max displacement=1.716e-03
# [step 10/10] converged in 2 iters, ||R||=3.402e-11
#   Sample 306: max displacement=4.648e-03
# [step 10/10] converged in 2 iters, ||R||=5.723e-11
#   Sample 309: max displacement=6.756e-03
# [step 10/10] converged in 2 iters, ||R||=8.316e-12
#   Sample 307: max displacement=3.317e-03
# [step 10/10] converged in 2 iters, ||R||=3.163e-11
# Completed 310/1000 samples
#   Sample 311: max displacement=5.247e-03
# [step 10/10] converged in 2 iters, ||R||=8.941e-11
#   Sample 310: max displacement=6.979e-03
# [step 10/10] converged in 2 iters, ||R||=1.128e-10
#   Sample 312: max displacement=6.365e-03
# [step 1/10] converged in 2 iters, ||R||=3.067e-10
# [step 1/10] converged in 2 iters, ||R||=2.186e-11
# [step 1/10] converged in 2 iters, ||R||=3.652e-10
# [step 1/10] converged in 2 iters, ||R||=4.398e-11
# [step 1/10] converged in 2 iters, ||R||=5.647e-10
# [step 1/10] converged in 2 iters, ||R||=1.568e-10
# [step 1/10] converged in 2 iters, ||R||=8.389e-11
# [step 1/10] converged in 2 iters, ||R||=6.465e-11
# [step 1/10] converged in 2 iters, ||R||=5.668e-11
# [step 1/10] converged in 2 iters, ||R||=3.991e-11
# [step 1/10] converged in 2 iters, ||R||=5.815e-11
# [step 1/10] converged in 2 iters, ||R||=2.436e-10
# [step 2/10] converged in 2 iters, ||R||=3.132e-10
# [step 2/10] converged in 2 iters, ||R||=2.215e-11
# [step 2/10] converged in 2 iters, ||R||=4.467e-11
# [step 2/10] converged in 2 iters, ||R||=3.731e-10
# [step 2/10] converged in 2 iters, ||R||=5.765e-10
# [step 2/10] converged in 2 iters, ||R||=1.593e-10
# [step 2/10] converged in 2 iters, ||R||=6.487e-11
# [step 2/10] converged in 2 iters, ||R||=8.556e-11
# [step 2/10] converged in 2 iters, ||R||=5.793e-11
# [step 2/10] converged in 2 iters, ||R||=4.018e-11
# [step 2/10] converged in 2 iters, ||R||=5.897e-11
# [step 2/10] converged in 2 iters, ||R||=2.498e-10
# [step 3/10] converged in 2 iters, ||R||=3.197e-10
# [step 3/10] converged in 2 iters, ||R||=2.208e-11
# [step 3/10] converged in 2 iters, ||R||=4.541e-11
# [step 3/10] converged in 2 iters, ||R||=3.820e-10
# [step 3/10] converged in 2 iters, ||R||=5.880e-10
# [step 3/10] converged in 2 iters, ||R||=1.614e-10
# [step 3/10] converged in 2 iters, ||R||=8.669e-11
# [step 3/10] converged in 2 iters, ||R||=5.845e-11
# [step 3/10] converged in 2 iters, ||R||=6.546e-11
# [step 3/10] converged in 2 iters, ||R||=4.063e-11
# [step 3/10] converged in 2 iters, ||R||=5.943e-11
# [step 3/10] converged in 2 iters, ||R||=2.556e-10
# [step 4/10] converged in 2 iters, ||R||=3.263e-10
# [step 4/10] converged in 2 iters, ||R||=2.251e-11
# [step 4/10] converged in 2 iters, ||R||=4.583e-11
# [step 4/10] converged in 2 iters, ||R||=3.903e-10
# [step 4/10] converged in 2 iters, ||R||=5.999e-10
# [step 4/10] converged in 2 iters, ||R||=1.637e-10
# [step 4/10] converged in 2 iters, ||R||=8.807e-11
# [step 4/10] converged in 2 iters, ||R||=6.607e-11
# [step 4/10] converged in 2 iters, ||R||=5.964e-11
# [step 4/10] converged in 2 iters, ||R||=4.089e-11
# [step 4/10] converged in 2 iters, ||R||=5.999e-11
# [step 4/10] converged in 2 iters, ||R||=2.616e-10
# [step 5/10] converged in 2 iters, ||R||=3.332e-10
# [step 5/10] converged in 2 iters, ||R||=2.232e-11
# [step 5/10] converged in 2 iters, ||R||=4.685e-11
# [step 5/10] converged in 2 iters, ||R||=3.990e-10
# [step 5/10] converged in 2 iters, ||R||=6.127e-10
# [step 5/10] converged in 2 iters, ||R||=1.665e-10
# [step 5/10] converged in 2 iters, ||R||=6.689e-11
# [step 5/10] converged in 2 iters, ||R||=6.039e-11
# [step 5/10] converged in 2 iters, ||R||=8.933e-11
# [step 5/10] converged in 2 iters, ||R||=4.099e-11
# [step 5/10] converged in 2 iters, ||R||=6.102e-11
# [step 5/10] converged in 2 iters, ||R||=2.680e-10
# [step 6/10] converged in 2 iters, ||R||=3.404e-10
# [step 6/10] converged in 2 iters, ||R||=2.240e-11
# [step 6/10] converged in 2 iters, ||R||=4.760e-11
# [step 6/10] converged in 2 iters, ||R||=4.080e-10
# [step 6/10] converged in 2 iters, ||R||=6.250e-10
# [step 6/10] converged in 2 iters, ||R||=1.692e-10
# [step 6/10] converged in 2 iters, ||R||=6.798e-11
# [step 6/10] converged in 2 iters, ||R||=9.078e-11
# [step 6/10] converged in 2 iters, ||R||=6.128e-11
# [step 6/10] converged in 2 iters, ||R||=4.167e-11
# [step 6/10] converged in 2 iters, ||R||=6.170e-11
# [step 6/10] converged in 2 iters, ||R||=2.744e-10
# [step 7/10] converged in 2 iters, ||R||=3.474e-10
# [step 7/10] converged in 2 iters, ||R||=2.247e-11
# [step 7/10] converged in 2 iters, ||R||=4.822e-11
# [step 7/10] converged in 2 iters, ||R||=4.170e-10
# [step 7/10] converged in 2 iters, ||R||=6.379e-10
# [step 7/10] converged in 2 iters, ||R||=1.720e-10
# [step 7/10] converged in 2 iters, ||R||=6.890e-11
# [step 7/10] converged in 2 iters, ||R||=6.241e-11
# [step 7/10] converged in 2 iters, ||R||=9.228e-11
# [step 7/10] converged in 2 iters, ||R||=4.176e-11
# [step 7/10] converged in 2 iters, ||R||=6.245e-11
# [step 7/10] converged in 2 iters, ||R||=2.812e-10
# [step 8/10] converged in 2 iters, ||R||=3.545e-10
# [step 8/10] converged in 2 iters, ||R||=2.257e-11
# [step 8/10] converged in 2 iters, ||R||=4.886e-11
# [step 8/10] converged in 2 iters, ||R||=4.269e-10
# [step 8/10] converged in 2 iters, ||R||=6.512e-10
# [step 8/10] converged in 2 iters, ||R||=1.747e-10
# [step 8/10] converged in 2 iters, ||R||=6.975e-11
# [step 8/10] converged in 2 iters, ||R||=9.371e-11
# [step 8/10] converged in 2 iters, ||R||=6.319e-11
# [step 8/10] converged in 2 iters, ||R||=4.191e-11
# [step 8/10] converged in 2 iters, ||R||=6.304e-11
# [step 8/10] converged in 2 iters, ||R||=2.882e-10
# [step 9/10] converged in 2 iters, ||R||=3.624e-10
# [step 9/10] converged in 2 iters, ||R||=2.292e-11
# [step 9/10] converged in 2 iters, ||R||=4.980e-11
# [step 9/10] converged in 2 iters, ||R||=4.364e-10
# [step 9/10] converged in 2 iters, ||R||=1.773e-10
# [step 9/10] converged in 2 iters, ||R||=6.649e-10
# [step 9/10] converged in 2 iters, ||R||=7.014e-11
# [step 9/10] converged in 2 iters, ||R||=9.511e-11
# [step 9/10] converged in 2 iters, ||R||=6.417e-11
# [step 9/10] converged in 2 iters, ||R||=4.255e-11
# [step 9/10] converged in 2 iters, ||R||=6.410e-11
# [step 9/10] converged in 2 iters, ||R||=2.950e-10
# [step 10/10] converged in 2 iters, ||R||=3.699e-10
#   Sample 313: max displacement=7.546e-03
# [step 10/10] converged in 2 iters, ||R||=2.280e-11
#   Sample 316: max displacement=5.927e-03
# [step 10/10] converged in 2 iters, ||R||=5.043e-11
#   Sample 315: max displacement=5.493e-03
# [step 10/10] converged in 2 iters, ||R||=4.464e-10
#   Sample 314: max displacement=8.068e-03
# [step 10/10] converged in 2 iters, ||R||=1.803e-10
#   Sample 318: max displacement=5.589e-03
# [step 10/10] converged in 2 iters, ||R||=6.788e-10
#   Sample 317: max displacement=9.136e-03
# [step 10/10] converged in 2 iters, ||R||=7.113e-11
#   Sample 320: max displacement=4.297e-03
# [step 10/10] converged in 2 iters, ||R||=9.687e-11
# Completed 320/1000 samples
#   Sample 319: max displacement=5.927e-03
# [step 10/10] converged in 2 iters, ||R||=6.500e-11
#   Sample 321: max displacement=5.865e-03
# [step 10/10] converged in 2 iters, ||R||=4.266e-11
#   Sample 322: max displacement=5.187e-03
# [step 10/10] converged in 2 iters, ||R||=6.486e-11
#   Sample 323: max displacement=6.187e-03
# [step 10/10] converged in 2 iters, ||R||=3.023e-10
#   Sample 324: max displacement=8.957e-03
# [step 1/10] converged in 2 iters, ||R||=3.355e-11
# [step 1/10] converged in 2 iters, ||R||=3.563e-11
# [step 1/10] converged in 2 iters, ||R||=1.719e-11
# [step 1/10] converged in 2 iters, ||R||=8.153e-10
# [step 1/10] converged in 2 iters, ||R||=8.896e-11
# [step 1/10] converged in 2 iters, ||R||=8.808e-11
# [step 1/10] converged in 2 iters, ||R||=2.171e-10
# [step 1/10] converged in 2 iters, ||R||=2.782e-11
# [step 1/10] converged in 2 iters, ||R||=2.413e-11
# [step 1/10] converged in 2 iters, ||R||=4.768e-10
# [step 1/10] converged in 2 iters, ||R||=1.188e-11
# [step 1/10] converged in 2 iters, ||R||=8.766e-11
# [step 2/10] converged in 2 iters, ||R||=3.414e-11
# [step 2/10] converged in 2 iters, ||R||=3.614e-11
# [step 2/10] converged in 2 iters, ||R||=1.742e-11
# [step 2/10] converged in 2 iters, ||R||=8.339e-10
# [step 2/10] converged in 2 iters, ||R||=9.052e-11
# [step 2/10] converged in 2 iters, ||R||=8.894e-11
# [step 2/10] converged in 2 iters, ||R||=2.218e-10
# [step 2/10] converged in 2 iters, ||R||=2.790e-11
# [step 2/10] converged in 2 iters, ||R||=2.429e-11
# [step 2/10] converged in 2 iters, ||R||=1.190e-11
# [step 2/10] converged in 2 iters, ||R||=4.846e-10
# [step 2/10] converged in 2 iters, ||R||=8.890e-11
# [step 3/10] converged in 2 iters, ||R||=3.474e-11
# [step 3/10] converged in 2 iters, ||R||=3.659e-11
# [step 3/10] converged in 2 iters, ||R||=1.733e-11
# [step 3/10] converged in 2 iters, ||R||=8.542e-10
# [step 3/10] converged in 2 iters, ||R||=8.995e-11
# [step 3/10] converged in 2 iters, ||R||=9.262e-11
# [step 3/10] converged in 2 iters, ||R||=2.264e-10
# [step 3/10] converged in 2 iters, ||R||=2.821e-11
# [step 3/10] converged in 2 iters, ||R||=2.451e-11
# [step 3/10] converged in 2 iters, ||R||=4.934e-10
# [step 3/10] converged in 2 iters, ||R||=1.195e-11
# [step 3/10] converged in 2 iters, ||R||=9.036e-11
# [step 4/10] converged in 2 iters, ||R||=3.534e-11
# [step 4/10] converged in 2 iters, ||R||=3.695e-11
# [step 4/10] converged in 2 iters, ||R||=1.746e-11
# [step 4/10] converged in 2 iters, ||R||=8.743e-10
# [step 4/10] converged in 2 iters, ||R||=9.428e-11
# [step 4/10] converged in 2 iters, ||R||=9.103e-11
# [step 4/10] converged in 2 iters, ||R||=2.309e-10
# [step 4/10] converged in 2 iters, ||R||=2.857e-11
# [step 4/10] converged in 2 iters, ||R||=2.471e-11
# [step 4/10] converged in 2 iters, ||R||=5.016e-10
# [step 4/10] converged in 2 iters, ||R||=1.170e-11
# [step 4/10] converged in 2 iters, ||R||=9.187e-11
# [step 5/10] converged in 2 iters, ||R||=3.588e-11
# [step 5/10] converged in 2 iters, ||R||=3.737e-11
# [step 5/10] converged in 2 iters, ||R||=1.749e-11
# [step 5/10] converged in 2 iters, ||R||=8.948e-10
# [step 5/10] converged in 2 iters, ||R||=9.625e-11
# [step 5/10] converged in 2 iters, ||R||=9.177e-11
# [step 5/10] converged in 2 iters, ||R||=2.355e-10
# [step 5/10] converged in 2 iters, ||R||=2.853e-11
# [step 5/10] converged in 2 iters, ||R||=2.500e-11
# [step 5/10] converged in 2 iters, ||R||=5.104e-10
# [step 5/10] converged in 2 iters, ||R||=1.194e-11
# [step 5/10] converged in 2 iters, ||R||=9.319e-11
# [step 6/10] converged in 2 iters, ||R||=3.669e-11
# [step 6/10] converged in 2 iters, ||R||=3.771e-11
# [step 6/10] converged in 2 iters, ||R||=1.745e-11
# [step 6/10] converged in 2 iters, ||R||=9.167e-10
# [step 6/10] converged in 2 iters, ||R||=9.835e-11
# [step 6/10] converged in 2 iters, ||R||=9.321e-11
# [step 6/10] converged in 2 iters, ||R||=2.406e-10
# [step 6/10] converged in 2 iters, ||R||=2.884e-11
# [step 6/10] converged in 2 iters, ||R||=2.516e-11
# [step 6/10] converged in 2 iters, ||R||=5.185e-10
# [step 6/10] converged in 2 iters, ||R||=1.183e-11
# [step 6/10] converged in 2 iters, ||R||=9.453e-11
# [step 7/10] converged in 2 iters, ||R||=3.733e-11
# [step 7/10] converged in 2 iters, ||R||=3.818e-11
# [step 7/10] converged in 2 iters, ||R||=1.743e-11
# [step 7/10] converged in 2 iters, ||R||=9.393e-10
# [step 7/10] converged in 2 iters, ||R||=1.001e-10
# [step 7/10] converged in 2 iters, ||R||=9.417e-11
# [step 7/10] converged in 2 iters, ||R||=2.932e-11
# [step 7/10] converged in 2 iters, ||R||=2.523e-11
# [step 7/10] converged in 2 iters, ||R||=2.457e-10
# [step 7/10] converged in 2 iters, ||R||=5.280e-10
# [step 7/10] converged in 2 iters, ||R||=1.199e-11
# [step 7/10] converged in 2 iters, ||R||=9.618e-11
# [step 8/10] converged in 2 iters, ||R||=3.788e-11
# [step 8/10] converged in 2 iters, ||R||=3.873e-11
# [step 8/10] converged in 2 iters, ||R||=1.785e-11
# [step 8/10] converged in 2 iters, ||R||=9.612e-10
# [step 8/10] converged in 2 iters, ||R||=1.022e-10
# [step 8/10] converged in 2 iters, ||R||=9.521e-11
# [step 8/10] converged in 2 iters, ||R||=2.955e-11
# [step 8/10] converged in 2 iters, ||R||=2.506e-10
# [step 8/10] converged in 2 iters, ||R||=2.553e-11
# [step 8/10] converged in 2 iters, ||R||=5.371e-10
# [step 8/10] converged in 2 iters, ||R||=1.202e-11
# [step 8/10] converged in 2 iters, ||R||=9.751e-11
# [step 9/10] converged in 2 iters, ||R||=3.862e-11
# [step 9/10] converged in 2 iters, ||R||=3.918e-11
# [step 9/10] converged in 2 iters, ||R||=1.758e-11
# [step 9/10] converged in 2 iters, ||R||=9.850e-10
# [step 9/10] converged in 2 iters, ||R||=1.043e-10
# [step 9/10] converged in 2 iters, ||R||=9.652e-11
# [step 9/10] converged in 2 iters, ||R||=2.981e-11
# [step 9/10] converged in 2 iters, ||R||=2.559e-10
# [step 9/10] converged in 2 iters, ||R||=2.587e-11
# [step 9/10] converged in 2 iters, ||R||=5.464e-10
# [step 9/10] converged in 2 iters, ||R||=1.214e-11
# [step 9/10] converged in 2 iters, ||R||=9.925e-11
# [step 10/10] converged in 2 iters, ||R||=3.932e-11
#   Sample 325: max displacement=4.783e-03
# [step 10/10] converged in 2 iters, ||R||=3.956e-11
#   Sample 326: max displacement=5.422e-03
# [step 10/10] converged in 2 iters, ||R||=1.752e-11
#   Sample 327: max displacement=5.361e-03
# [step 10/10] converged in 2 iters, ||R||=1.008e-09
#   Sample 328: max displacement=9.107e-03
# [step 10/10] converged in 2 iters, ||R||=1.062e-10
#   Sample 329: max displacement=6.671e-03
# [step 10/10] converged in 2 iters, ||R||=2.616e-10
# Completed 330/1000 samples
#   Sample 331: max displacement=7.912e-03
# [step 10/10] converged in 2 iters, ||R||=3.025e-11
#   Sample 332: max displacement=4.370e-03
# [step 10/10] converged in 2 iters, ||R||=9.758e-11
#   Sample 330: max displacement=6.232e-03
# [step 10/10] converged in 2 iters, ||R||=2.610e-11
#   Sample 333: max displacement=5.172e-03
# [step 10/10] converged in 2 iters, ||R||=5.557e-10
#   Sample 334: max displacement=6.260e-03
# [step 10/10] converged in 2 iters, ||R||=1.220e-11
#   Sample 335: max displacement=4.930e-03
# [step 10/10] converged in 2 iters, ||R||=1.008e-10
#   Sample 336: max displacement=5.035e-03
# [step 1/10] converged in 2 iters, ||R||=6.324e-12
# [step 1/10] converged in 2 iters, ||R||=2.522e-10
# [step 1/10] converged in 2 iters, ||R||=9.058e-11
# [step 1/10] converged in 2 iters, ||R||=9.348e-11
# [step 1/10] converged in 2 iters, ||R||=1.187e-11
# [step 1/10] converged in 2 iters, ||R||=9.289e-10
# [step 1/10] converged in 2 iters, ||R||=5.514e-11
# [step 1/10] converged in 2 iters, ||R||=1.012e-10
# [step 1/10] converged in 2 iters, ||R||=2.617e-11
# [step 1/10] converged in 2 iters, ||R||=1.503e-10
# [step 1/10] converged in 2 iters, ||R||=5.049e-11
# [step 1/10] converged in 2 iters, ||R||=1.548e-11
# [step 2/10] converged in 2 iters, ||R||=6.291e-12
# [step 2/10] converged in 2 iters, ||R||=9.160e-11
# [step 2/10] converged in 2 iters, ||R||=2.569e-10
# [step 2/10] converged in 2 iters, ||R||=9.429e-11
# [step 2/10] converged in 2 iters, ||R||=1.192e-11
# [step 2/10] converged in 2 iters, ||R||=9.545e-10
# [step 2/10] converged in 2 iters, ||R||=5.561e-11
# [step 2/10] converged in 2 iters, ||R||=1.031e-10
# [step 2/10] converged in 2 iters, ||R||=2.628e-11
# [step 2/10] converged in 2 iters, ||R||=1.527e-10
# [step 2/10] converged in 2 iters, ||R||=5.151e-11
# [step 2/10] converged in 2 iters, ||R||=1.581e-11
# [step 3/10] converged in 2 iters, ||R||=6.210e-12
# [step 3/10] converged in 2 iters, ||R||=2.620e-10
# [step 3/10] converged in 2 iters, ||R||=9.288e-11
# [step 3/10] converged in 2 iters, ||R||=9.523e-11
# [step 3/10] converged in 2 iters, ||R||=1.189e-11
# [step 3/10] converged in 2 iters, ||R||=9.814e-10
# [step 3/10] converged in 2 iters, ||R||=1.046e-10
# [step 3/10] converged in 2 iters, ||R||=5.619e-11
# [step 3/10] converged in 2 iters, ||R||=2.649e-11
# [step 3/10] converged in 2 iters, ||R||=1.550e-10
# [step 3/10] converged in 2 iters, ||R||=5.212e-11
# [step 3/10] converged in 2 iters, ||R||=1.568e-11
# [step 4/10] converged in 2 iters, ||R||=9.409e-11
# [step 4/10] converged in 2 iters, ||R||=2.667e-10
# [step 4/10] converged in 2 iters, ||R||=6.410e-12
# [step 4/10] converged in 2 iters, ||R||=9.590e-11
# [step 4/10] converged in 2 iters, ||R||=1.200e-11
# [step 4/10] converged in 2 iters, ||R||=1.009e-09
# [step 4/10] converged in 2 iters, ||R||=1.065e-10
# [step 4/10] converged in 2 iters, ||R||=5.663e-11
# [step 4/10] converged in 2 iters, ||R||=2.643e-11
# [step 4/10] converged in 2 iters, ||R||=1.574e-10
# [step 4/10] converged in 2 iters, ||R||=5.278e-11
# [step 4/10] converged in 2 iters, ||R||=1.582e-11
# [step 5/10] converged in 2 iters, ||R||=2.721e-10
# [step 5/10] converged in 2 iters, ||R||=6.382e-12
# [step 5/10] converged in 2 iters, ||R||=9.573e-11
# [step 5/10] converged in 2 iters, ||R||=9.675e-11
# [step 5/10] converged in 2 iters, ||R||=1.211e-11
# [step 5/10] converged in 2 iters, ||R||=1.037e-09
# [step 5/10] converged in 2 iters, ||R||=1.086e-10
# [step 5/10] converged in 2 iters, ||R||=5.723e-11
# [step 5/10] converged in 2 iters, ||R||=2.647e-11
# [step 5/10] converged in 2 iters, ||R||=1.601e-10
# [step 5/10] converged in 2 iters, ||R||=5.379e-11
# [step 5/10] converged in 2 iters, ||R||=1.596e-11
# [step 6/10] converged in 2 iters, ||R||=6.297e-12
# [step 6/10] converged in 2 iters, ||R||=9.675e-11
# [step 6/10] converged in 2 iters, ||R||=2.773e-10
# [step 6/10] converged in 2 iters, ||R||=9.775e-11
# [step 6/10] converged in 2 iters, ||R||=1.240e-11
# [step 6/10] converged in 2 iters, ||R||=1.067e-09
# [step 6/10] converged in 2 iters, ||R||=5.785e-11
# [step 6/10] converged in 2 iters, ||R||=1.106e-10
# [step 6/10] converged in 2 iters, ||R||=2.668e-11
# [step 6/10] converged in 2 iters, ||R||=1.625e-10
# [step 6/10] converged in 2 iters, ||R||=5.477e-11
# [step 6/10] converged in 2 iters, ||R||=1.607e-11
# [step 7/10] converged in 2 iters, ||R||=2.826e-10
# [step 7/10] converged in 2 iters, ||R||=9.814e-11
# [step 7/10] converged in 2 iters, ||R||=6.239e-12
# [step 7/10] converged in 2 iters, ||R||=9.881e-11
# [step 7/10] converged in 2 iters, ||R||=1.239e-11
# [step 7/10] converged in 2 iters, ||R||=1.098e-09
# [step 7/10] converged in 2 iters, ||R||=1.125e-10
# [step 7/10] converged in 2 iters, ||R||=5.831e-11
# [step 7/10] converged in 2 iters, ||R||=2.664e-11
# [step 7/10] converged in 2 iters, ||R||=1.649e-10
# [step 7/10] converged in 2 iters, ||R||=5.568e-11
# [step 7/10] converged in 2 iters, ||R||=1.629e-11
# [step 8/10] converged in 2 iters, ||R||=2.879e-10
# [step 8/10] converged in 2 iters, ||R||=9.978e-11
# [step 8/10] converged in 2 iters, ||R||=6.084e-12
# [step 8/10] converged in 2 iters, ||R||=9.957e-11
# [step 8/10] converged in 2 iters, ||R||=1.235e-11
# [step 8/10] converged in 2 iters, ||R||=1.129e-09
# [step 8/10] converged in 2 iters, ||R||=1.147e-10
# [step 8/10] converged in 2 iters, ||R||=5.893e-11
# [step 8/10] converged in 2 iters, ||R||=2.671e-11
# [step 8/10] converged in 2 iters, ||R||=1.669e-10
# [step 8/10] converged in 2 iters, ||R||=5.652e-11
# [step 8/10] converged in 2 iters, ||R||=1.645e-11
# [step 9/10] converged in 2 iters, ||R||=6.324e-12
# [step 9/10] converged in 2 iters, ||R||=2.937e-10
# [step 9/10] converged in 2 iters, ||R||=1.013e-10
# [step 9/10] converged in 2 iters, ||R||=1.006e-10
# [step 9/10] converged in 2 iters, ||R||=1.224e-11
# [step 9/10] converged in 2 iters, ||R||=1.161e-09
# [step 9/10] converged in 2 iters, ||R||=1.169e-10
# [step 9/10] converged in 2 iters, ||R||=5.957e-11
# [step 9/10] converged in 2 iters, ||R||=2.690e-11
# [step 9/10] converged in 2 iters, ||R||=1.698e-10
# [step 9/10] converged in 2 iters, ||R||=5.774e-11
# [step 9/10] converged in 2 iters, ||R||=1.648e-11
# [step 10/10] converged in 2 iters, ||R||=6.211e-12
#   Sample 337: max displacement=2.075e-03
# [step 10/10] converged in 2 iters, ||R||=2.993e-10
#   Sample 338: max displacement=7.616e-03
# [step 10/10] converged in 2 iters, ||R||=1.027e-10
#   Sample 339: max displacement=6.121e-03
# [step 10/10] converged in 2 iters, ||R||=1.016e-10
# Completed 340/1000 samples
#   Sample 341: max displacement=7.702e-03
# [step 10/10] converged in 2 iters, ||R||=1.250e-11
#   Sample 340: max displacement=4.362e-03
# [step 10/10] converged in 2 iters, ||R||=1.195e-09
#   Sample 342: max displacement=1.076e-02
# [step 10/10] converged in 2 iters, ||R||=1.189e-10
#   Sample 343: max displacement=6.932e-03
# [step 10/10] converged in 2 iters, ||R||=6.037e-11
#   Sample 344: max displacement=6.602e-03
# [step 10/10] converged in 2 iters, ||R||=2.674e-11
#   Sample 345: max displacement=5.747e-03
# [step 10/10] converged in 2 iters, ||R||=1.721e-10
#   Sample 346: max displacement=4.755e-03
# [step 10/10] converged in 2 iters, ||R||=5.879e-11
#   Sample 347: max displacement=6.449e-03
# [step 10/10] converged in 2 iters, ||R||=1.681e-11
#   Sample 348: max displacement=4.300e-03
# [step 1/10] converged in 2 iters, ||R||=1.936e-11
# [step 1/10] converged in 2 iters, ||R||=3.438e-11
# [step 1/10] converged in 2 iters, ||R||=3.070e-10
# [step 1/10] converged in 2 iters, ||R||=1.536e-10
# [step 1/10] converged in 2 iters, ||R||=2.499e-11
# [step 1/10] converged in 2 iters, ||R||=4.893e-10
# [step 1/10] converged in 2 iters, ||R||=6.503e-12
# [step 1/10] converged in 2 iters, ||R||=1.233e-10
# [step 1/10] converged in 2 iters, ||R||=1.565e-10
# [step 1/10] converged in 2 iters, ||R||=9.888e-10
# [step 1/10] converged in 2 iters, ||R||=9.450e-12
# [step 1/10] converged in 2 iters, ||R||=7.005e-10
# [step 2/10] converged in 2 iters, ||R||=1.944e-11
# [step 2/10] converged in 2 iters, ||R||=3.479e-11
# [step 2/10] converged in 2 iters, ||R||=3.132e-10
# [step 2/10] converged in 2 iters, ||R||=1.576e-10
# [step 2/10] converged in 2 iters, ||R||=2.529e-11
# [step 2/10] converged in 2 iters, ||R||=5.054e-10
# [step 2/10] converged in 2 iters, ||R||=5.959e-12
# [step 2/10] converged in 2 iters, ||R||=1.258e-10
# [step 2/10] converged in 2 iters, ||R||=1.589e-10
# [step 2/10] converged in 2 iters, ||R||=1.013e-09
# [step 2/10] converged in 2 iters, ||R||=9.268e-12
# [step 2/10] converged in 2 iters, ||R||=7.149e-10
# [step 3/10] converged in 2 iters, ||R||=1.971e-11
# [step 3/10] converged in 2 iters, ||R||=3.479e-11
# [step 3/10] converged in 2 iters, ||R||=3.195e-10
# [step 3/10] converged in 2 iters, ||R||=1.613e-10
# [step 3/10] converged in 2 iters, ||R||=2.540e-11
# [step 3/10] converged in 2 iters, ||R||=5.218e-10
# [step 3/10] converged in 2 iters, ||R||=6.395e-12
# [step 3/10] converged in 2 iters, ||R||=1.288e-10
# [step 3/10] converged in 2 iters, ||R||=1.611e-10
# [step 3/10] converged in 2 iters, ||R||=1.038e-09
# [step 3/10] converged in 2 iters, ||R||=9.041e-12
# [step 3/10] converged in 2 iters, ||R||=7.286e-10
# [step 4/10] converged in 2 iters, ||R||=1.971e-11
# [step 4/10] converged in 2 iters, ||R||=3.531e-11
# [step 4/10] converged in 2 iters, ||R||=3.260e-10
# [step 4/10] converged in 2 iters, ||R||=1.653e-10
# [step 4/10] converged in 2 iters, ||R||=2.564e-11
# [step 4/10] converged in 2 iters, ||R||=5.388e-10
# [step 4/10] converged in 2 iters, ||R||=6.306e-12
# [step 4/10] converged in 2 iters, ||R||=1.315e-10
# [step 4/10] converged in 2 iters, ||R||=1.639e-10
# [step 4/10] converged in 2 iters, ||R||=1.064e-09
# [step 4/10] converged in 2 iters, ||R||=9.209e-12
# [step 4/10] converged in 2 iters, ||R||=7.431e-10
# [step 5/10] converged in 2 iters, ||R||=1.986e-11
# [step 5/10] converged in 2 iters, ||R||=3.534e-11
# [step 5/10] converged in 2 iters, ||R||=3.324e-10
# [step 5/10] converged in 2 iters, ||R||=1.692e-10
# [step 5/10] converged in 2 iters, ||R||=2.563e-11
# [step 5/10] converged in 2 iters, ||R||=5.567e-10
# [step 5/10] converged in 2 iters, ||R||=6.263e-12
# [step 5/10] converged in 2 iters, ||R||=1.344e-10
# [step 5/10] converged in 2 iters, ||R||=1.659e-10
# [step 5/10] converged in 2 iters, ||R||=1.090e-09
# [step 5/10] converged in 2 iters, ||R||=9.171e-12
# [step 5/10] converged in 2 iters, ||R||=7.579e-10
# [step 6/10] converged in 2 iters, ||R||=3.578e-11
# [step 6/10] converged in 2 iters, ||R||=1.985e-11
# [step 6/10] converged in 2 iters, ||R||=3.392e-10
# [step 6/10] converged in 2 iters, ||R||=1.735e-10
# [step 6/10] converged in 2 iters, ||R||=2.638e-11
# [step 6/10] converged in 2 iters, ||R||=6.390e-12
# [step 6/10] converged in 2 iters, ||R||=5.753e-10
# [step 6/10] converged in 2 iters, ||R||=1.374e-10
# [step 6/10] converged in 2 iters, ||R||=1.683e-10
# [step 6/10] converged in 2 iters, ||R||=1.117e-09
# [step 6/10] converged in 2 iters, ||R||=9.360e-12
# [step 6/10] converged in 2 iters, ||R||=7.725e-10
# [step 7/10] converged in 2 iters, ||R||=3.588e-11
# [step 7/10] converged in 2 iters, ||R||=2.012e-11
# [step 7/10] converged in 2 iters, ||R||=3.459e-10
# [step 7/10] converged in 2 iters, ||R||=1.780e-10
# [step 7/10] converged in 2 iters, ||R||=2.635e-11
# [step 7/10] converged in 2 iters, ||R||=6.528e-12
# [step 7/10] converged in 2 iters, ||R||=5.946e-10
# [step 7/10] converged in 2 iters, ||R||=1.407e-10
# [step 7/10] converged in 2 iters, ||R||=1.706e-10
# [step 7/10] converged in 2 iters, ||R||=1.145e-09
# [step 7/10] converged in 2 iters, ||R||=9.576e-12
# [step 7/10] converged in 2 iters, ||R||=7.880e-10
# [step 8/10] converged in 2 iters, ||R||=3.634e-11
# [step 8/10] converged in 2 iters, ||R||=2.026e-11
# [step 8/10] converged in 2 iters, ||R||=3.530e-10
# [step 8/10] converged in 2 iters, ||R||=1.824e-10
# [step 8/10] converged in 2 iters, ||R||=2.649e-11
# [step 8/10] converged in 2 iters, ||R||=6.262e-12
# [step 8/10] converged in 2 iters, ||R||=6.143e-10
# [step 8/10] converged in 2 iters, ||R||=1.439e-10
# [step 8/10] converged in 2 iters, ||R||=1.729e-10
# [step 8/10] converged in 2 iters, ||R||=1.173e-09
# [step 8/10] converged in 2 iters, ||R||=9.458e-12
# [step 8/10] converged in 2 iters, ||R||=8.039e-10
# [step 9/10] converged in 2 iters, ||R||=3.665e-11
# [step 9/10] converged in 2 iters, ||R||=2.035e-11
# [step 9/10] converged in 2 iters, ||R||=3.602e-10
# [step 9/10] converged in 2 iters, ||R||=1.873e-10
# [step 9/10] converged in 2 iters, ||R||=2.682e-11
# [step 9/10] converged in 2 iters, ||R||=6.097e-12
# [step 9/10] converged in 2 iters, ||R||=1.471e-10
# [step 9/10] converged in 2 iters, ||R||=6.352e-10
# [step 9/10] converged in 2 iters, ||R||=1.757e-10
# [step 9/10] converged in 2 iters, ||R||=1.203e-09
# ...
# [step 7/10] converged in 2 iters, ||R||=2.102e-10
# [step 7/10] converged in 2 iters, ||R||=6.875e-10
# [step 7/10] converged in 2 iters, ||R||=8.537e-12
# [step 7/10] converged in 2 iters, ||R||=8.306e-11
# [step 6/10] converged in 2 iters, ||R||=9.326e-12
# [step 7/10] converged in 2 iters, ||R||=3.269e-10
# [step 8/10] converged in 2 iters, ||R||=9.177e-11
# [step 7/10] converged in 2 iters, ||R||=2.877e-09
# [step 7/10] converged in 2 iters, ||R||=3.972e-10
# [step 7/10] converged in 2 iters, ||R||=1.259e-10
# [step 8/10] converged in 2 iters, ||R||=4.014e-11
# [step 8/10] converged in 2 iters, ||R||=8.522e-11
# [step 8/10] converged in 2 iters, ||R||=2.136e-10
# [step 8/10] converged in 2 iters, ||R||=7.016e-10
# [step 8/10] converged in 2 iters, ||R||=8.712e-12
# [step 8/10] converged in 2 iters, ||R||=8.396e-11
# [step 7/10] converged in 2 iters, ||R||=9.614e-12
# [step 8/10] converged in 2 iters, ||R||=3.318e-10
# [step 8/10] converged in 2 iters, ||R||=2.979e-09
# [step 9/10] converged in 2 iters, ||R||=9.320e-11
# [step 8/10] converged in 2 iters, ||R||=4.064e-10
# [step 8/10] converged in 2 iters, ||R||=1.277e-10
# [step 9/10] converged in 2 iters, ||R||=4.043e-11
# [step 9/10] converged in 2 iters, ||R||=8.701e-11
# [step 9/10] converged in 2 iters, ||R||=2.171e-10
# [step 9/10] converged in 2 iters, ||R||=7.158e-10
# [step 9/10] converged in 2 iters, ||R||=8.588e-12
# [step 9/10] converged in 2 iters, ||R||=8.470e-11
# [step 8/10] converged in 2 iters, ||R||=9.461e-12
# [step 9/10] converged in 2 iters, ||R||=3.374e-10
# [step 10/10] converged in 2 iters, ||R||=9.466e-11
#   Sample 685: max displacement=4.498e-03
# [step 9/10] converged in 2 iters, ||R||=4.157e-10
# [step 9/10] converged in 2 iters, ||R||=3.085e-09
# [step 9/10] converged in 2 iters, ||R||=1.294e-10
# [step 10/10] converged in 2 iters, ||R||=4.053e-11
#   Sample 686: max displacement=7.021e-03
# [step 10/10] converged in 2 iters, ||R||=8.887e-11
#   Sample 687: max displacement=6.062e-03
# [step 10/10] converged in 2 iters, ||R||=2.208e-10
#   Sample 688: max displacement=8.195e-03
# [step 10/10] converged in 2 iters, ||R||=7.305e-10
#   Sample 690: max displacement=8.156e-03
# [step 10/10] converged in 2 iters, ||R||=8.615e-12
# Completed 690/1000 samples
#   Sample 689: max displacement=3.227e-03
# [step 10/10] converged in 2 iters, ||R||=8.558e-11
#   Sample 691: max displacement=6.302e-03
# [step 9/10] converged in 2 iters, ||R||=9.409e-12
# [step 10/10] converged in 2 iters, ||R||=3.425e-10
#   Sample 692: max displacement=5.700e-03
# [step 10/10] converged in 2 iters, ||R||=3.195e-09
#   Sample 693: max displacement=1.366e-02
# [step 1/10] converged in 2 iters, ||R||=3.568e-11
# [step 10/10] converged in 2 iters, ||R||=4.252e-10
#   Sample 694: max displacement=8.422e-03
# [step 10/10] converged in 2 iters, ||R||=1.313e-10
#   Sample 695: max displacement=6.073e-03
# [step 1/10] converged in 2 iters, ||R||=9.031e-11
# [step 1/10] converged in 2 iters, ||R||=1.750e-10
# [step 1/10] converged in 2 iters, ||R||=2.057e-10
# [step 1/10] converged in 2 iters, ||R||=1.789e-10
# [step 1/10] converged in 2 iters, ||R||=2.292e-11
# [step 1/10] converged in 2 iters, ||R||=7.159e-11
# [step 10/10] converged in 2 iters, ||R||=9.592e-12
#   Sample 696: max displacement=3.002e-03
# [step 1/10] converged in 2 iters, ||R||=1.236e-10
# [step 2/10] converged in 2 iters, ||R||=3.588e-11
# [step 1/10] converged in 2 iters, ||R||=3.096e-11
# [step 1/10] converged in 2 iters, ||R||=2.533e-10
# [step 1/10] converged in 2 iters, ||R||=1.863e-11
# [step 2/10] converged in 2 iters, ||R||=9.141e-11
# [step 2/10] converged in 2 iters, ||R||=1.782e-10
# [step 2/10] converged in 2 iters, ||R||=2.090e-10
# [step 2/10] converged in 2 iters, ||R||=1.830e-10
# [step 2/10] converged in 2 iters, ||R||=2.299e-11
# [step 2/10] converged in 2 iters, ||R||=7.251e-11
# [step 1/10] converged in 2 iters, ||R||=1.706e-10
# [step 2/10] converged in 2 iters, ||R||=1.258e-10
# [step 2/10] converged in 2 iters, ||R||=3.139e-11
# [step 3/10] converged in 2 iters, ||R||=3.621e-11
# [step 2/10] converged in 2 iters, ||R||=2.585e-10
# [step 2/10] converged in 2 iters, ||R||=1.898e-11
# [step 3/10] converged in 2 iters, ||R||=9.195e-11
# [step 3/10] converged in 2 iters, ||R||=2.127e-10
# [step 3/10] converged in 2 iters, ||R||=1.811e-10
# [step 3/10] converged in 2 iters, ||R||=1.873e-10
# [step 3/10] converged in 2 iters, ||R||=2.275e-11
# [step 3/10] converged in 2 iters, ||R||=7.385e-11
# [step 2/10] converged in 2 iters, ||R||=1.745e-10
# [step 3/10] converged in 2 iters, ||R||=1.282e-10
# [step 4/10] converged in 2 iters, ||R||=3.687e-11
# [step 3/10] converged in 2 iters, ||R||=2.635e-10
# [step 3/10] converged in 2 iters, ||R||=3.169e-11
# [step 3/10] converged in 2 iters, ||R||=1.898e-11
# [step 4/10] converged in 2 iters, ||R||=9.293e-11
# [step 4/10] converged in 2 iters, ||R||=2.161e-10
# [step 4/10] converged in 2 iters, ||R||=1.847e-10
# [step 4/10] converged in 2 iters, ||R||=1.918e-10
# [step 4/10] converged in 2 iters, ||R||=2.310e-11
# [step 4/10] converged in 2 iters, ||R||=7.523e-11
# [step 3/10] converged in 2 iters, ||R||=1.780e-10
# [step 4/10] converged in 2 iters, ||R||=1.314e-10
# [step 4/10] converged in 2 iters, ||R||=2.687e-10
# [step 4/10] converged in 2 iters, ||R||=3.226e-11
# [step 5/10] converged in 2 iters, ||R||=3.698e-11
# [step 4/10] converged in 2 iters, ||R||=1.891e-11
# [step 5/10] converged in 2 iters, ||R||=9.408e-11
# [step 5/10] converged in 2 iters, ||R||=2.198e-10
# [step 5/10] converged in 2 iters, ||R||=1.878e-10
# [step 5/10] converged in 2 iters, ||R||=1.964e-10
# [step 5/10] converged in 2 iters, ||R||=2.287e-11
# [step 5/10] converged in 2 iters, ||R||=7.637e-11
# [step 4/10] converged in 2 iters, ||R||=1.819e-10
# [step 5/10] converged in 2 iters, ||R||=1.333e-10
# [step 5/10] converged in 2 iters, ||R||=2.740e-10
# [step 6/10] converged in 2 iters, ||R||=3.807e-11
# [step 5/10] converged in 2 iters, ||R||=3.215e-11
# [step 5/10] converged in 2 iters, ||R||=1.921e-11
# [step 6/10] converged in 2 iters, ||R||=9.472e-11
# [step 6/10] converged in 2 iters, ||R||=2.234e-10
# [step 6/10] converged in 2 iters, ||R||=1.918e-10
# [step 6/10] converged in 2 iters, ||R||=2.012e-10
# [step 6/10] converged in 2 iters, ||R||=2.312e-11
# [step 6/10] converged in 2 iters, ||R||=7.761e-11
# [step 5/10] converged in 2 iters, ||R||=1.856e-10
# [step 6/10] converged in 2 iters, ||R||=1.364e-10
# [step 6/10] converged in 2 iters, ||R||=2.797e-10
# [step 7/10] converged in 2 iters, ||R||=3.811e-11
# [step 6/10] converged in 2 iters, ||R||=3.291e-11
# [step 6/10] converged in 2 iters, ||R||=1.871e-11
# [step 7/10] converged in 2 iters, ||R||=9.535e-11
# [step 7/10] converged in 2 iters, ||R||=2.273e-10
# [step 7/10] converged in 2 iters, ||R||=1.950e-10
# [step 7/10] converged in 2 iters, ||R||=2.057e-10
# [step 7/10] converged in 2 iters, ||R||=2.310e-11
# [step 7/10] converged in 2 iters, ||R||=7.891e-11
# [step 6/10] converged in 2 iters, ||R||=1.894e-10
# [step 7/10] converged in 2 iters, ||R||=1.389e-10
# [step 7/10] converged in 2 iters, ||R||=2.856e-10
# [step 7/10] converged in 2 iters, ||R||=3.297e-11
# [step 8/10] converged in 2 iters, ||R||=3.909e-11
# [step 7/10] converged in 2 iters, ||R||=1.906e-11
# [step 8/10] converged in 2 iters, ||R||=9.692e-11
# [step 8/10] converged in 2 iters, ||R||=2.312e-10
# [step 8/10] converged in 2 iters, ||R||=1.985e-10
# [step 8/10] converged in 2 iters, ||R||=2.322e-11
# [step 8/10] converged in 2 iters, ||R||=2.107e-10
# [step 8/10] converged in 2 iters, ||R||=8.019e-11
# [step 7/10] converged in 2 iters, ||R||=1.939e-10
# [step 8/10] converged in 2 iters, ||R||=1.417e-10
# [step 8/10] converged in 2 iters, ||R||=2.913e-10
# [step 8/10] converged in 2 iters, ||R||=3.356e-11
# [step 9/10] converged in 2 iters, ||R||=3.917e-11
# [step 8/10] converged in 2 iters, ||R||=1.928e-11
# [step 9/10] converged in 2 iters, ||R||=9.754e-11
# [step 9/10] converged in 2 iters, ||R||=2.353e-10
# [step 9/10] converged in 2 iters, ||R||=2.022e-10
# [step 9/10] converged in 2 iters, ||R||=2.158e-10
# [step 9/10] converged in 2 iters, ||R||=2.310e-11
# [step 9/10] converged in 2 iters, ||R||=8.152e-11
# [step 8/10] converged in 2 iters, ||R||=1.982e-10
# [step 9/10] converged in 2 iters, ||R||=1.448e-10
# [step 9/10] converged in 2 iters, ||R||=2.972e-10
# [step 9/10] converged in 2 iters, ||R||=3.415e-11
# [step 10/10] converged in 2 iters, ||R||=3.979e-11
#   Sample 697: max displacement=4.352e-03
# [step 9/10] converged in 2 iters, ||R||=1.945e-11
# [step 10/10] converged in 2 iters, ||R||=9.852e-11
#   Sample 698: max displacement=5.210e-03
# [step 10/10] converged in 2 iters, ||R||=2.395e-10
#   Sample 700: max displacement=7.116e-03
# [step 10/10] converged in 2 iters, ||R||=2.059e-10
# Completed 700/1000 samples
#   Sample 699: max displacement=7.394e-03
# [step 10/10] converged in 2 iters, ||R||=2.313e-11
#   Sample 702: max displacement=4.727e-03
# [step 10/10] converged in 2 iters, ||R||=2.209e-10
#   Sample 701: max displacement=7.538e-03
# [step 10/10] converged in 2 iters, ||R||=8.299e-11
#   Sample 703: max displacement=5.767e-03
# [step 9/10] converged in 2 iters, ||R||=2.020e-10
# [step 10/10] converged in 2 iters, ||R||=1.481e-10
#   Sample 704: max displacement=7.700e-03
# [step 10/10] converged in 2 iters, ||R||=3.032e-10
#   Sample 706: max displacement=7.800e-03
# [step 1/10] converged in 2 iters, ||R||=2.088e-10
# [step 10/10] converged in 2 iters, ||R||=3.443e-11
#   Sample 705: max displacement=5.115e-03
# [step 10/10] converged in 2 iters, ||R||=1.941e-11
#   Sample 707: max displacement=4.943e-03
# [step 1/10] converged in 2 iters, ||R||=4.235e-10
# [step 1/10] converged in 2 iters, ||R||=2.134e-11
# [step 1/10] converged in 2 iters, ||R||=4.198e-11
# [step 1/10] converged in 2 iters, ||R||=2.748e-10
# [step 1/10] converged in 2 iters, ||R||=4.701e-11
# [step 1/10] converged in 2 iters, ||R||=8.612e-11
# [step 10/10] converged in 2 iters, ||R||=2.065e-10
#   Sample 708: max displacement=6.995e-03
# [step 1/10] converged in 2 iters, ||R||=2.218e-11
# [step 1/10] converged in 2 iters, ||R||=7.695e-11
# [step 2/10] converged in 2 iters, ||R||=2.119e-10
# [step 1/10] converged in 2 iters, ||R||=4.693e-10
# [step 1/10] converged in 2 iters, ||R||=5.259e-10
# [step 2/10] converged in 2 iters, ||R||=4.332e-10
# [step 2/10] converged in 2 iters, ||R||=2.170e-11
# [step 2/10] converged in 2 iters, ||R||=4.282e-11
# [step 2/10] converged in 2 iters, ||R||=2.802e-10
# [step 2/10] converged in 2 iters, ||R||=4.805e-11
# [step 2/10] converged in 2 iters, ||R||=8.770e-11
# [step 1/10] converged in 2 iters, ||R||=1.282e-10
# [step 2/10] converged in 2 iters, ||R||=2.234e-11
# [step 2/10] converged in 2 iters, ||R||=7.816e-11
# [step 3/10] converged in 2 iters, ||R||=2.150e-10
# [step 2/10] converged in 2 iters, ||R||=4.778e-10
# [step 2/10] converged in 2 iters, ||R||=5.401e-10
# [step 3/10] converged in 2 iters, ||R||=4.431e-10
# [step 3/10] converged in 2 iters, ||R||=2.155e-11
# [step 3/10] converged in 2 iters, ||R||=4.348e-11
# [step 3/10] converged in 2 iters, ||R||=2.850e-10
# [step 3/10] converged in 2 iters, ||R||=4.883e-11
# [step 3/10] converged in 2 iters, ||R||=8.912e-11
# [step 2/10] converged in 2 iters, ||R||=1.305e-10
# [step 3/10] converged in 2 iters, ||R||=2.294e-11
# [step 3/10] converged in 2 iters, ||R||=7.859e-11
# [step 4/10] converged in 2 iters, ||R||=2.182e-10
# [step 3/10] converged in 2 iters, ||R||=4.865e-10
# [step 3/10] converged in 2 iters, ||R||=5.548e-10
# [step 4/10] converged in 2 iters, ||R||=4.534e-10
# [step 4/10] converged in 2 iters, ||R||=4.389e-11
# [step 4/10] converged in 2 iters, ||R||=2.169e-11
# [step 4/10] converged in 2 iters, ||R||=2.902e-10
# [step 4/10] converged in 2 iters, ||R||=4.976e-11
# [step 4/10] converged in 2 iters, ||R||=9.086e-11
# [step 3/10] converged in 2 iters, ||R||=1.329e-10
# [step 4/10] converged in 2 iters, ||R||=2.304e-11
# [step 4/10] converged in 2 iters, ||R||=8.001e-11
# [step 5/10] converged in 2 iters, ||R||=2.218e-10
# [step 4/10] converged in 2 iters, ||R||=4.960e-10
# [step 4/10] converged in 2 iters, ||R||=5.701e-10
# [step 5/10] converged in 2 iters, ||R||=4.638e-10
# [step 5/10] converged in 2 iters, ||R||=2.152e-11
# [step 5/10] converged in 2 iters, ||R||=4.437e-11
# [step 5/10] converged in 2 iters, ||R||=2.954e-10
# [step 5/10] converged in 2 iters, ||R||=5.057e-11
# [step 5/10] converged in 2 iters, ||R||=9.228e-11
# [step 4/10] converged in 2 iters, ||R||=1.354e-10
# [step 5/10] converged in 2 iters, ||R||=2.310e-11
# [step 5/10] converged in 2 iters, ||R||=8.077e-11
# [step 6/10] converged in 2 iters, ||R||=2.253e-10
# [step 5/10] converged in 2 iters, ||R||=5.052e-10
# [step 5/10] converged in 2 iters, ||R||=5.856e-10
# [step 6/10] converged in 2 iters, ||R||=4.742e-10
# [step 6/10] converged in 2 iters, ||R||=2.148e-11
# [step 6/10] converged in 2 iters, ||R||=4.514e-11
# [step 6/10] converged in 2 iters, ||R||=3.008e-10
# [step 6/10] converged in 2 iters, ||R||=5.141e-11
# [step 6/10] converged in 2 iters, ||R||=9.386e-11
# [step 5/10] converged in 2 iters, ||R||=1.380e-10
# [step 6/10] converged in 2 iters, ||R||=2.353e-11
# [step 6/10] converged in 2 iters, ||R||=8.182e-11
# [step 7/10] converged in 2 iters, ||R||=2.291e-10
# [step 6/10] converged in 2 iters, ||R||=5.144e-10
# [step 6/10] converged in 2 iters, ||R||=6.017e-10
# [step 7/10] converged in 2 iters, ||R||=4.848e-10
# [step 7/10] converged in 2 iters, ||R||=2.164e-11
# [step 7/10] converged in 2 iters, ||R||=4.595e-11
# [step 7/10] converged in 2 iters, ||R||=3.064e-10
# [step 7/10] converged in 2 iters, ||R||=5.242e-11
# [step 7/10] converged in 2 iters, ||R||=9.542e-11
# [step 6/10] converged in 2 iters, ||R||=1.404e-10
# [step 7/10] converged in 2 iters, ||R||=2.379e-11
# [step 7/10] converged in 2 iters, ||R||=8.313e-11
# [step 8/10] converged in 2 iters, ||R||=2.326e-10
# [step 7/10] converged in 2 iters, ||R||=5.244e-10
# [step 7/10] converged in 2 iters, ||R||=6.186e-10
# [step 8/10] converged in 2 iters, ||R||=4.962e-10
# [step 8/10] converged in 2 iters, ||R||=2.202e-11
# [step 8/10] converged in 2 iters, ||R||=5.320e-11
# [step 8/10] converged in 2 iters, ||R||=3.124e-10
# [step 8/10] converged in 2 iters, ||R||=4.636e-11
# [step 8/10] converged in 2 iters, ||R||=9.728e-11
# [step 7/10] converged in 2 iters, ||R||=1.430e-10
# [step 8/10] converged in 2 iters, ||R||=2.410e-11
# [step 8/10] converged in 2 iters, ||R||=8.411e-11
# [step 9/10] converged in 2 iters, ||R||=2.364e-10
# [step 8/10] converged in 2 iters, ||R||=5.341e-10
# [step 8/10] converged in 2 iters, ||R||=6.357e-10
# [step 9/10] converged in 2 iters, ||R||=5.079e-10
# [step 9/10] converged in 2 iters, ||R||=2.186e-11
# [step 9/10] converged in 2 iters, ||R||=5.435e-11
# [step 9/10] converged in 2 iters, ||R||=3.179e-10
# [step 9/10] converged in 2 iters, ||R||=4.693e-11
# [step 9/10] converged in 2 iters, ||R||=9.897e-11
# [step 8/10] converged in 2 iters, ||R||=1.458e-10
# [step 9/10] converged in 2 iters, ||R||=2.445e-11
# [step 10/10] converged in 2 iters, ||R||=2.401e-10
# [step 9/10] converged in 2 iters, ||R||=8.580e-11
#   Sample 709: max displacement=8.312e-03
# [step 9/10] converged in 2 iters, ||R||=5.442e-10
# [step 9/10] converged in 2 iters, ||R||=6.535e-10
# [step 10/10] converged in 2 iters, ||R||=5.197e-10
# Completed 710/1000 samples
#   Sample 710: max displacement=8.560e-03
# [step 10/10] converged in 2 iters, ||R||=2.177e-11
#   Sample 711: max displacement=5.160e-03
# [step 10/10] converged in 2 iters, ||R||=5.497e-11
#   Sample 714: max displacement=6.381e-03
# [step 10/10] converged in 2 iters, ||R||=3.236e-10
#   Sample 713: max displacement=6.984e-03
# [step 10/10] converged in 2 iters, ||R||=4.776e-11
#   Sample 712: max displacement=5.088e-03
# [step 10/10] converged in 2 iters, ||R||=1.009e-10
#   Sample 715: max displacement=7.474e-03
# [step 9/10] converged in 2 iters, ||R||=1.486e-10
# [step 10/10] converged in 2 iters, ||R||=2.459e-11
#   Sample 716: max displacement=4.861e-03
# [step 1/10] converged in 2 iters, ||R||=1.444e-10
# [step 10/10] converged in 2 iters, ||R||=8.669e-11
#   Sample 717: max displacement=4.877e-03
# [step 10/10] converged in 2 iters, ||R||=5.547e-10
#   Sample 718: max displacement=7.943e-03
# [step 10/10] converged in 2 iters, ||R||=6.718e-10
#   Sample 719: max displacement=8.984e-03
# [step 1/10] converged in 2 iters, ||R||=4.115e-10
# [step 1/10] converged in 2 iters, ||R||=1.508e-10

# %% [markdown]
# ## Cell 13 - Zip and download all results (optional)
#
# Results already live on Google Drive (`RESULTS_DIR`), so this is just a
# convenience if you want a local zip copy too -- not required for safety.

# %%
import shutil
from google.colab import files

archive_path = shutil.make_archive('/content/pfem_results', 'zip', RESULTS_DIR)
print(f"Archived {RESULTS_DIR} -> {archive_path}")
files.download(archive_path)
